# %% [markdown]
# # 02a – 2. Experiment: Stage-2-Fine-Tuning: Erweitertes Training auf MCoRec

# %% [markdown]
# ## Hypothese
#
# BL4 (AV-HuBERT Cocktail, MCoRec-feingetunet) wurde bereits auf einem Multi-Corpus-Mix
# aus LRS2, Vox2, AVYT, AVYT-mix und MCoRec trainiert (~400 k Schritte, LR 1·10⁻⁴).
# Kann ein zweites, gezieltes Fine-Tuning (**Stage 2**) mit niedrigerer Lernrate
# und weniger Schritten die Domänenanpassung weiter verbessern?
#
# ## Vorgehen
#
# Stage-2-Checkpoint `avsr_cocktail_mcorec_stage2_lr5e-5_30k`:
# - **Ausgangspunkt:** BL4-Checkpoint (`avsr_cocktail_mcorec_finetune`)
# - **Lernrate:** 5·10⁻⁵ (halbiert gegenüber Stage 1)
# - **Schritte:** 30 000 (statt 400 000) – moderates Nachtraining
# - **Datenmix:** gleicher Streaming-Mix mit `--include_mcorec`
#
# ## Ergebnis (Vorschau)
#
# Das Stage-2-Modell ist **konsistent schlechter** als BL4 (WER +0.036–0.037, JER +0.018).
# Das zusätzliche Training hat das Modell überanpasst und von der besser generalisierenden
# BL4-Lösung wegoptimiert. → Stage-2-Ansatz wird nicht weiterverfolgt.
#
# **Hinweis zum Bugfix:** Dieser Lauf wurde **vor dem Bugfix** in `segmentation.py` durchgeführt (`min_duration_off` las fälschlicherweise den Wert von `min_duration_on`). Das ist **gewollt**: Der Bugfix wurde erst nach Abschluss der LLM- und Hyperparameter-Experimente entdeckt. Da der Bugfix allein die WER zunächst verschlechterte, wurde erst in `02j_`/`02k_` die Kombination aus Bugfix + `min_duration`-Optimierung erarbeitet, die schließlich das beste Ergebnis lieferte.

# %% [markdown]
# ## 1 – Setup: Arbeitsverzeichnis & Imports

# %%
import os, sys
from pathlib import Path

# Pfad anpassen, falls nötig
project_baseline_path = Path("/home/josch080/Projektgruppe/mcorec_baseline")
os.chdir(project_baseline_path)
print("CWD:", os.getcwd())

# Repo-Root in sys.path aufnehmen, damit projektinterne Module importierbar sind
if str(project_baseline_path) not in sys.path:
    sys.path.append(str(project_baseline_path))
# Out:
# CWD: /home/josch080/Projektgruppe/mcorec_baseline

# %% [markdown]
# ## 2 – GPU-Auswahl

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# ## 3 – CUDA-Verifikation

# %%
import torch
print("n_gpu:", torch.cuda.device_count())
# sollte 1 ausgeben
# Out:
# n_gpu: 1

# %% [markdown]
# ## 4 – Stage-2-Training
#
# Das Training wird als Subprocess gestartet. Die Argumente spiegeln das Stage-2-Setup
# wider: niedrigere Lernrate, weniger Schritte, gleicher Datenmix wie Stage 1.
#
# **Hinweis:** `subprocess.run(cmd)` ist bereits ausgeführt; der Checkpoint liegt unter
# `model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000`.

# %%
cmd = [
    sys.executable, "script/train.py",
    "--streaming_dataset", # Daten werden on-the-fly geladen (kein vollständiges Preprocessing nötig)
    "--include_mcorec", # MCoRec-Daten in den Trainingsmix aufnehmen
    "--batch_size", "4",
    "--max_steps", "30000", # Weniger Schritte als Stage 1 (400k)
    "--gradient_accumulation_steps", "2", # Effektive Batch-Größe = 4 × 2 = 8
    "--save_steps", "2000", # Checkpoint alle 2000 Schritte sichern
    "--eval_steps", "2000", # Validation-Loss alle 2000 Schritte berechnen
    "--log_interval", "25",
    "--learning_rate", "5e-5", # Halbierte LR gegenüber Stage 1 (1e-4)
    "--warmup_steps", "3000", # Linearer LR-Warmup über die ersten 3000 Schritte
    "--checkpoint_name", "avsr_cocktail_mcorec_stage2_lr5e-5_30k", # Name des Ausgabe-Checkpoints
    "--model_name_or_path", "./model-bin/avsr_cocktail_mcorec_finetune", # Startpunkt: BL4
    "--output_dir", "./model-bin",
    "--report_to", "none", # Kein Logging an W&B o.ä.
]
print(" ".join(cmd)) # Vollständigen Befehl zur Verifikation ausgeben
# Out:
# /home/josch080/Projektgruppe/mcorec_train/bin/python script/train.py --streaming_dataset --include_mcorec --batch_size 4 --max_steps 30000 --gradient_accumulation_steps 2 --save_steps 2000 --eval_steps 2000 --log_interval 25 --learning_rate 5e-5 --warmup_steps 3000 --checkpoint_name avsr_cocktail_mcorec_stage2_lr5e-5_30k --model_name_or_path ./model-bin/avsr_cocktail_mcorec_finetune --output_dir ./model-bin --report_to none

# %%
import subprocess
# Training als Subprocess starten – Ausgabe erscheint direkt im Notebook
subprocess.run(cmd)
# Out:
# Loading pretrained model from ./model-bin/avsr_cocktail_mcorec_finetune
# Loading MCoRec dataset
# map_datasets
#  {'lrs2': {'probabilities': 0.25, 'dataset': {'train': IterableDataset({
#     features: ['label', 'length', 'sample_id', 'video'],
#     num_shards: 10
# }), 'valid': None}}, 'vox2': {'probabilities': 0.1, 'dataset': {'train': IterableDataset({
#     features: ['label', 'length', 'sample_id', 'video'],
#     num_shards: 53
# }), 'valid': None}}, 'avyt': {'probabilities': 0.2, 'dataset': {'train': IterableDataset({
#     features: ['label', 'length', 'sample_id', 'video'],
#     num_shards: 16
# }), 'valid': None}}, 'avyt-mix': {'probabilities': 0.25, 'dataset': {'train': IterableDataset({
#     features: ['label', 'length', 'sample_id', 'video'],
#     num_shards: 664
# }), 'valid': None}}, 'mcorec': {'probabilities': 0.2, 'dataset': {'train': IterableDataset({
#     features: ['label', 'length', 'sample_id', 'video'],
#     num_shards: 48
# }), 'valid': IterableDataset({
#     features: ['label', 'length', 'sample_id', 'video'],
#     num_shards: 3
# })}}}
# Loading interference speech dataset. Actual file around 10GB need to download. This may take a while...
# train_dataset
#  IterableDataset({
#     features: Unknown,
#     num_shards: 10
# })
# valid_dataset
#  IterableDataset({
#     features: Unknown,
#     num_shards: 3
# })
# =====================================================================================
# Layer (type:depth-idx)                                       Param #
# =====================================================================================
# ├─E2E: 1-1                                                   --
# |    └─AVHubertModel: 2-1                                    --
# |    |    └─SubModel: 3-1                                    107,520
# |    |    └─SubModel: 3-2                                    11,712,000
# |    |    └─Linear: 3-3                                      2,098,176
# |    |    └─Dropout: 3-4                                     --
# |    |    └─Dropout: 3-5                                     --
# |    |    └─AVHubertEncoder: 3-6                             310,701,184
# |    |    └─LayerNorm: 3-7                                   4,096
# |    └─Decoder: 2-2                                          --
# |    |    └─Sequential: 3-8                                  5,170,176
# |    |    └─MultiSequential: 3-9                             88,190,976
# |    |    └─LayerNorm: 3-10                                  2,048
# |    |    └─Linear: 3-11                                     5,175,225
# |    └─LabelSmoothingLoss: 2-3                               --
# |    |    └─KLDivLoss: 3-12                                  --
# |    └─CTC: 2-4                                              --
# |    |    └─Linear: 3-13                                     5,175,225
# |    |    └─Dropout: 3-14                                    --
# |    |    └─CTCLoss: 3-15                                    --
# =====================================================================================
# Total params: 428,336,626
# Trainable params: 428,336,626
# Non-trainable params: 0
# =====================================================================================
# /home/josch080/Projektgruppe/mcorec_baseline/src/custom_trainer.py:26: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `AVSRTrainer.__init__`. Use `processing_class` instead.
#   super().__init__(
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#   0%|          | 25/30000 [00:19<4:11:33,  1.99it/s]
# {'loss': 17.3312, 'grad_norm': 71.00940704345703, 'learning_rate': 3.5000000000000004e-07, 'epoch': 0.0}
#   0%|          | 50/30000 [00:31<4:02:24,  2.06it/s]
# {'loss': 14.2914, 'grad_norm': 15.612455368041992, 'learning_rate': 7.666666666666667e-07, 'epoch': 0.0}
#   0%|          | 75/30000 [00:44<3:54:11,  2.13it/s]
# {'loss': 13.6917, 'grad_norm': 16.764677047729492, 'learning_rate': 1.1833333333333334e-06, 'epoch': 0.0}
#   0%|          | 100/30000 [00:55<3:54:57,  2.12it/s]
# {'loss': 12.6155, 'grad_norm': 27.925941467285156, 'learning_rate': 1.6000000000000001e-06, 'epoch': 0.0}
#   0%|          | 125/30000 [01:08<4:15:11,  1.95it/s]
# {'loss': 19.2985, 'grad_norm': 28.92288589477539, 'learning_rate': 2.0166666666666667e-06, 'epoch': 0.0}
#   0%|          | 150/30000 [01:20<4:17:01,  1.94it/s]
# {'loss': 14.9646, 'grad_norm': 60.98441696166992, 'learning_rate': 2.4333333333333335e-06, 'epoch': 0.01}
#   1%|          | 175/30000 [01:32<4:10:50,  1.98it/s]
# {'loss': 23.0048, 'grad_norm': 66.44439697265625, 'learning_rate': 2.8333333333333335e-06, 'epoch': 0.01}
#   1%|          | 200/30000 [01:45<4:14:12,  1.95it/s]
# {'loss': 19.794, 'grad_norm': 30.48972511291504, 'learning_rate': 3.2500000000000002e-06, 'epoch': 0.01}
#   1%|          | 225/30000 [01:57<4:11:36,  1.97it/s]
# {'loss': 23.434, 'grad_norm': 62.91205596923828, 'learning_rate': 3.666666666666667e-06, 'epoch': 0.01}
#   1%|          | 250/30000 [02:10<3:36:18,  2.29it/s]
# {'loss': 18.9943, 'grad_norm': 29.91696548461914, 'learning_rate': 4.083333333333334e-06, 'epoch': 0.01}
#   1%|          | 275/30000 [02:21<3:30:37,  2.35it/s]
# {'loss': 10.9403, 'grad_norm': 27.176530838012695, 'learning_rate': 4.5e-06, 'epoch': 0.01}
#   1%|          | 300/30000 [02:33<3:47:19,  2.18it/s]
# {'loss': 11.5666, 'grad_norm': 19.913427352905273, 'learning_rate': 4.9166666666666665e-06, 'epoch': 0.01}
#   1%|          | 325/30000 [02:45<4:08:39,  1.99it/s]
# {'loss': 15.5754, 'grad_norm': 58.23151779174805, 'learning_rate': 5.333333333333334e-06, 'epoch': 0.01}
#   1%|          | 350/30000 [02:57<3:32:36,  2.32it/s]
# {'loss': 13.8308, 'grad_norm': 88.8888931274414, 'learning_rate': 5.750000000000001e-06, 'epoch': 0.01}
#   1%|▏         | 375/30000 [03:09<3:35:50,  2.29it/s]
# {'loss': 14.628, 'grad_norm': 44.540672302246094, 'learning_rate': 6.166666666666667e-06, 'epoch': 0.01}
#   1%|▏         | 400/30000 [03:21<4:08:35,  1.98it/s]
# {'loss': 19.8694, 'grad_norm': 58.85300064086914, 'learning_rate': 6.583333333333333e-06, 'epoch': 0.01}
#   1%|▏         | 425/30000 [03:33<4:11:25,  1.96it/s]
# {'loss': 19.7465, 'grad_norm': 61.64405822753906, 'learning_rate': 7.000000000000001e-06, 'epoch': 0.01}
#   2%|▏         | 450/30000 [03:45<4:12:19,  1.95it/s]
# {'loss': 15.1813, 'grad_norm': 41.8242301940918, 'learning_rate': 7.416666666666668e-06, 'epoch': 0.01}
#   2%|▏         | 475/30000 [03:56<3:24:25,  2.41it/s]
# {'loss': 13.0993, 'grad_norm': 22.02269172668457, 'learning_rate': 7.833333333333333e-06, 'epoch': 0.02}
#   2%|▏         | 500/30000 [04:09<4:19:57,  1.89it/s]
# {'loss': 18.5771, 'grad_norm': 50.633445739746094, 'learning_rate': 8.25e-06, 'epoch': 0.02}
#   2%|▏         | 525/30000 [04:21<3:43:35,  2.20it/s]
# {'loss': 16.6158, 'grad_norm': 16.82877540588379, 'learning_rate': 8.666666666666668e-06, 'epoch': 0.02}
#   2%|▏         | 550/30000 [04:33<3:49:10,  2.14it/s]
# {'loss': 18.139, 'grad_norm': 35.00023651123047, 'learning_rate': 9.083333333333333e-06, 'epoch': 0.02}
#   2%|▏         | 575/30000 [04:45<3:36:43,  2.26it/s]
# {'loss': 17.2456, 'grad_norm': 61.128929138183594, 'learning_rate': 9.5e-06, 'epoch': 0.02}
#   2%|▏         | 600/30000 [04:56<3:28:49,  2.35it/s]
# {'loss': 11.2404, 'grad_norm': 32.10109329223633, 'learning_rate': 9.916666666666668e-06, 'epoch': 0.02}
#   2%|▏         | 625/30000 [05:08<4:10:57,  1.95it/s]
# {'loss': 15.8525, 'grad_norm': 26.56573486328125, 'learning_rate': 1.0333333333333333e-05, 'epoch': 0.02}
#   2%|▏         | 650/30000 [05:20<4:06:21,  1.99it/s]
# {'loss': 19.5963, 'grad_norm': 81.76909637451172, 'learning_rate': 1.075e-05, 'epoch': 0.02}
#   2%|▏         | 675/30000 [05:32<4:12:53,  1.93it/s]
# {'loss': 18.121, 'grad_norm': 22.9056396484375, 'learning_rate': 1.1166666666666668e-05, 'epoch': 0.02}
#   2%|▏         | 700/30000 [05:44<3:11:10,  2.55it/s]
# {'loss': 13.572, 'grad_norm': 22.447370529174805, 'learning_rate': 1.1583333333333333e-05, 'epoch': 0.02}
#   2%|▏         | 725/30000 [05:56<4:08:49,  1.96it/s]
# {'loss': 14.3483, 'grad_norm': 27.274768829345703, 'learning_rate': 1.2e-05, 'epoch': 0.02}
#   2%|▎         | 750/30000 [06:08<3:53:31,  2.09it/s]
# {'loss': 18.0872, 'grad_norm': 51.99196243286133, 'learning_rate': 1.2416666666666667e-05, 'epoch': 0.03}
#   3%|▎         | 775/30000 [06:19<4:04:58,  1.99it/s]
# {'loss': 14.1611, 'grad_norm': 50.653465270996094, 'learning_rate': 1.2833333333333333e-05, 'epoch': 0.03}
#   3%|▎         | 800/30000 [06:31<4:04:34,  1.99it/s]
# {'loss': 20.0291, 'grad_norm': 52.49267578125, 'learning_rate': 1.3250000000000002e-05, 'epoch': 0.03}
#   3%|▎         | 825/30000 [06:44<4:03:28,  2.00it/s]
# {'loss': 16.6426, 'grad_norm': 30.468233108520508, 'learning_rate': 1.3666666666666666e-05, 'epoch': 0.03}
#   3%|▎         | 850/30000 [06:55<4:02:14,  2.01it/s]
# {'loss': 17.1329, 'grad_norm': 33.73909378051758, 'learning_rate': 1.4083333333333335e-05, 'epoch': 0.03}
#   3%|▎         | 875/30000 [07:07<3:35:16,  2.25it/s]
# {'loss': 15.3856, 'grad_norm': 41.35885238647461, 'learning_rate': 1.45e-05, 'epoch': 0.03}
#   3%|▎         | 900/30000 [07:19<3:28:24,  2.33it/s]
# {'loss': 20.9155, 'grad_norm': 39.216983795166016, 'learning_rate': 1.4916666666666667e-05, 'epoch': 0.03}
#   3%|▎         | 925/30000 [07:32<4:09:12,  1.94it/s]
# {'loss': 20.1126, 'grad_norm': 32.35628890991211, 'learning_rate': 1.5333333333333334e-05, 'epoch': 0.03}
#   3%|▎         | 950/30000 [07:43<4:02:18,  2.00it/s]
# {'loss': 16.0119, 'grad_norm': 37.96964645385742, 'learning_rate': 1.575e-05, 'epoch': 0.03}
#   3%|▎         | 975/30000 [07:55<4:06:10,  1.97it/s]
# {'loss': 19.9917, 'grad_norm': 34.199974060058594, 'learning_rate': 1.6166666666666665e-05, 'epoch': 0.03}
#   3%|▎         | 1000/30000 [08:07<3:29:49,  2.30it/s]
# {'loss': 20.1834, 'grad_norm': 37.08354949951172, 'learning_rate': 1.6583333333333334e-05, 'epoch': 0.03}
#   3%|▎         | 1025/30000 [08:20<3:53:59,  2.06it/s]
# {'loss': 18.8966, 'grad_norm': 61.63634490966797, 'learning_rate': 1.7000000000000003e-05, 'epoch': 0.03}
#   4%|▎         | 1050/30000 [08:32<4:00:38,  2.01it/s]
# {'loss': 20.8369, 'grad_norm': 87.92446899414062, 'learning_rate': 1.741666666666667e-05, 'epoch': 0.04}
#   4%|▎         | 1075/30000 [08:44<3:50:23,  2.09it/s]
# {'loss': 19.8394, 'grad_norm': 64.042236328125, 'learning_rate': 1.7833333333333334e-05, 'epoch': 0.04}
#   4%|▎         | 1100/30000 [08:56<3:17:55,  2.43it/s]
# {'loss': 16.2662, 'grad_norm': 28.386716842651367, 'learning_rate': 1.825e-05, 'epoch': 0.04}
#   4%|▍         | 1125/30000 [09:07<3:58:40,  2.02it/s]
# {'loss': 14.4158, 'grad_norm': 45.88051986694336, 'learning_rate': 1.866666666666667e-05, 'epoch': 0.04}
#   4%|▍         | 1150/30000 [09:20<3:57:48,  2.02it/s]
# {'loss': 19.7009, 'grad_norm': 78.97460174560547, 'learning_rate': 1.9083333333333334e-05, 'epoch': 0.04}
#   4%|▍         | 1175/30000 [09:32<4:07:37,  1.94it/s]
# {'loss': 17.2208, 'grad_norm': 42.034645080566406, 'learning_rate': 1.9500000000000003e-05, 'epoch': 0.04}
#   4%|▍         | 1200/30000 [09:43<4:01:16,  1.99it/s]
# {'loss': 21.579, 'grad_norm': 55.21867370605469, 'learning_rate': 1.9916666666666665e-05, 'epoch': 0.04}
#   4%|▍         | 1225/30000 [09:56<3:27:09,  2.32it/s]
# {'loss': 21.6571, 'grad_norm': 39.98133850097656, 'learning_rate': 2.0333333333333334e-05, 'epoch': 0.04}
#   4%|▍         | 1250/30000 [10:09<4:07:28,  1.94it/s]
# {'loss': 17.38, 'grad_norm': 28.673797607421875, 'learning_rate': 2.075e-05, 'epoch': 0.04}
#   4%|▍         | 1275/30000 [10:21<4:02:05,  1.98it/s]
# {'loss': 21.658, 'grad_norm': 58.537132263183594, 'learning_rate': 2.116666666666667e-05, 'epoch': 0.04}
#   4%|▍         | 1300/30000 [10:32<2:54:37,  2.74it/s]
# {'loss': 16.4793, 'grad_norm': 35.77513885498047, 'learning_rate': 2.1583333333333334e-05, 'epoch': 0.04}
#   4%|▍         | 1325/30000 [10:44<3:57:12,  2.01it/s]
# {'loss': 19.9648, 'grad_norm': 68.52244567871094, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.04}
#   4%|▍         | 1350/30000 [10:56<3:17:12,  2.42it/s]
# {'loss': 14.4986, 'grad_norm': 35.37556457519531, 'learning_rate': 2.2416666666666665e-05, 'epoch': 0.04}
#   5%|▍         | 1375/30000 [11:08<3:28:41,  2.29it/s]
# {'loss': 20.3668, 'grad_norm': 29.858572006225586, 'learning_rate': 2.2833333333333334e-05, 'epoch': 0.05}
#   5%|▍         | 1400/30000 [11:21<4:19:53,  1.83it/s]
# {'loss': 22.7666, 'grad_norm': 46.11834716796875, 'learning_rate': 2.3250000000000003e-05, 'epoch': 0.05}
#   5%|▍         | 1425/30000 [11:33<4:06:10,  1.93it/s]
# {'loss': 16.3119, 'grad_norm': 55.18647384643555, 'learning_rate': 2.3666666666666668e-05, 'epoch': 0.05}
#   5%|▍         | 1450/30000 [11:46<4:10:54,  1.90it/s]
# {'loss': 20.6022, 'grad_norm': 56.05821990966797, 'learning_rate': 2.4083333333333337e-05, 'epoch': 0.05}
#   5%|▍         | 1475/30000 [11:58<4:07:18,  1.92it/s]
# {'loss': 15.2809, 'grad_norm': 32.359107971191406, 'learning_rate': 2.45e-05, 'epoch': 0.05}
#   5%|▌         | 1500/30000 [12:11<4:14:14,  1.87it/s]
# {'loss': 18.4959, 'grad_norm': 51.5662956237793, 'learning_rate': 2.4916666666666668e-05, 'epoch': 0.05}
#   5%|▌         | 1525/30000 [12:23<4:03:01,  1.95it/s]
# {'loss': 18.9244, 'grad_norm': 46.71903610229492, 'learning_rate': 2.5333333333333337e-05, 'epoch': 0.05}
#   5%|▌         | 1550/30000 [12:36<3:33:53,  2.22it/s]
# {'loss': 28.0429, 'grad_norm': 56.01412582397461, 'learning_rate': 2.5750000000000002e-05, 'epoch': 0.05}
#   5%|▌         | 1575/30000 [12:49<3:29:03,  2.27it/s]
# {'loss': 18.3593, 'grad_norm': 40.899322509765625, 'learning_rate': 2.6166666666666668e-05, 'epoch': 0.05}
#   5%|▌         | 1600/30000 [13:01<3:54:04,  2.02it/s]
# {'loss': 20.2859, 'grad_norm': 56.436317443847656, 'learning_rate': 2.6583333333333333e-05, 'epoch': 0.05}
#   5%|▌         | 1625/30000 [13:12<2:58:39,  2.65it/s]
# {'loss': 14.3731, 'grad_norm': 25.855138778686523, 'learning_rate': 2.7000000000000002e-05, 'epoch': 0.05}
#   6%|▌         | 1650/30000 [13:25<3:58:47,  1.98it/s]
# {'loss': 18.3222, 'grad_norm': 34.41569137573242, 'learning_rate': 2.7416666666666668e-05, 'epoch': 0.06}
#   6%|▌         | 1675/30000 [13:36<3:25:49,  2.29it/s]
# {'loss': 13.4559, 'grad_norm': 22.869075775146484, 'learning_rate': 2.7833333333333333e-05, 'epoch': 0.06}
#   6%|▌         | 1700/30000 [13:48<3:22:20,  2.33it/s]
# {'loss': 25.3491, 'grad_norm': 29.589744567871094, 'learning_rate': 2.825e-05, 'epoch': 0.06}
#   6%|▌         | 1725/30000 [13:59<3:21:18,  2.34it/s]
# {'loss': 16.8254, 'grad_norm': 45.938621520996094, 'learning_rate': 2.8666666666666668e-05, 'epoch': 0.06}
#   6%|▌         | 1750/30000 [14:12<3:52:27,  2.03it/s]
# {'loss': 18.1454, 'grad_norm': 42.662803649902344, 'learning_rate': 2.9083333333333333e-05, 'epoch': 0.06}
#   6%|▌         | 1775/30000 [14:24<3:52:45,  2.02it/s]
# {'loss': 18.7537, 'grad_norm': 54.05384063720703, 'learning_rate': 2.95e-05, 'epoch': 0.06}
#   6%|▌         | 1800/30000 [14:35<3:50:01,  2.04it/s]
# {'loss': 15.2807, 'grad_norm': 36.34051513671875, 'learning_rate': 2.991666666666667e-05, 'epoch': 0.06}
#   6%|▌         | 1825/30000 [14:47<3:27:56,  2.26it/s]
# {'loss': 18.4973, 'grad_norm': 33.69395446777344, 'learning_rate': 3.0333333333333337e-05, 'epoch': 0.06}
#   6%|▌         | 1850/30000 [14:59<3:32:04,  2.21it/s]
# {'loss': 20.1352, 'grad_norm': 27.058490753173828, 'learning_rate': 3.075e-05, 'epoch': 0.06}
#   6%|▋         | 1875/30000 [15:12<3:50:07,  2.04it/s]
# {'loss': 23.3058, 'grad_norm': 53.92612075805664, 'learning_rate': 3.116666666666667e-05, 'epoch': 0.06}
#   6%|▋         | 1900/30000 [15:25<3:36:10,  2.17it/s]
# {'loss': 15.2464, 'grad_norm': 40.980125427246094, 'learning_rate': 3.158333333333334e-05, 'epoch': 0.06}
#   6%|▋         | 1925/30000 [15:37<3:57:10,  1.97it/s]
# {'loss': 19.5127, 'grad_norm': 44.42938232421875, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.06}
#   6%|▋         | 1950/30000 [15:49<3:18:13,  2.36it/s]
# {'loss': 17.4068, 'grad_norm': 30.93537712097168, 'learning_rate': 3.2416666666666664e-05, 'epoch': 0.07}
#   7%|▋         | 1975/30000 [16:02<3:58:32,  1.96it/s]
# {'loss': 29.3811, 'grad_norm': 47.147552490234375, 'learning_rate': 3.283333333333333e-05, 'epoch': 0.07}
#   7%|▋         | 2000/30000 [16:13<3:53:09,  2.00it/s]
# {'loss': 12.8964, 'grad_norm': 46.747657775878906, 'learning_rate': 3.325e-05, 'epoch': 0.07}
# Too many dataloader workers: 10 (max is dataset.num_shards=3). Stopping 7 dataloader workers.
#   7%|▋         | 2000/30000 [19:10<3:53:09,  2.00it/s]
# {'eval_loss': 28.17624282836914, 'eval_runtime': 177.3195, 'eval_samples_per_second': 21.949, 'eval_steps_per_second': 5.487, 'epoch': 0.07}
#   7%|▋         | 2025/30000 [19:30<3:54:51,  1.99it/s]
# {'loss': 15.2431, 'grad_norm': 47.072444915771484, 'learning_rate': 3.366666666666667e-05, 'epoch': 0.07}
#   7%|▋         | 2050/30000 [19:42<3:24:29,  2.28it/s]
# {'loss': 19.5806, 'grad_norm': 27.6933650970459, 'learning_rate': 3.408333333333333e-05, 'epoch': 0.07}
#   7%|▋         | 2075/30000 [19:54<4:00:31,  1.93it/s]
# {'loss': 16.4841, 'grad_norm': 66.80195617675781, 'learning_rate': 3.45e-05, 'epoch': 0.07}
#   7%|▋         | 2100/30000 [20:06<3:14:47,  2.39it/s]
# {'loss': 16.1435, 'grad_norm': 16.617084503173828, 'learning_rate': 3.491666666666667e-05, 'epoch': 0.07}
#   7%|▋         | 2125/30000 [20:17<3:16:30,  2.36it/s]
# {'loss': 19.2917, 'grad_norm': 41.30341720581055, 'learning_rate': 3.5333333333333336e-05, 'epoch': 0.07}
#   7%|▋         | 2150/30000 [20:29<3:49:43,  2.02it/s]
# {'loss': 13.7086, 'grad_norm': 26.246660232543945, 'learning_rate': 3.575e-05, 'epoch': 0.07}
#   7%|▋         | 2175/30000 [20:42<3:18:27,  2.34it/s]
# {'loss': 16.7288, 'grad_norm': 32.548641204833984, 'learning_rate': 3.6166666666666674e-05, 'epoch': 0.07}
#   7%|▋         | 2200/30000 [20:53<3:09:32,  2.44it/s]
# {'loss': 13.276, 'grad_norm': 24.635089874267578, 'learning_rate': 3.658333333333334e-05, 'epoch': 0.07}
#   7%|▋         | 2225/30000 [21:05<3:45:44,  2.05it/s]
# {'loss': 17.6287, 'grad_norm': 38.5001106262207, 'learning_rate': 3.7e-05, 'epoch': 0.07}
#   8%|▊         | 2250/30000 [21:17<3:20:24,  2.31it/s]
# {'loss': 18.7036, 'grad_norm': 38.27681350708008, 'learning_rate': 3.7416666666666664e-05, 'epoch': 0.07}
#   8%|▊         | 2275/30000 [21:30<3:55:26,  1.96it/s]
# {'loss': 16.7197, 'grad_norm': 48.6198844909668, 'learning_rate': 3.7833333333333336e-05, 'epoch': 0.08}
#   8%|▊         | 2300/30000 [21:42<4:01:38,  1.91it/s]
# {'loss': 16.7139, 'grad_norm': 51.51292037963867, 'learning_rate': 3.825e-05, 'epoch': 0.08}
#   8%|▊         | 2325/30000 [21:55<3:57:13,  1.94it/s]
# {'loss': 20.7062, 'grad_norm': 27.385961532592773, 'learning_rate': 3.866666666666667e-05, 'epoch': 0.08}
#   8%|▊         | 2350/30000 [22:06<4:05:39,  1.88it/s]
# {'loss': 15.8657, 'grad_norm': 66.13665771484375, 'learning_rate': 3.906666666666667e-05, 'epoch': 0.08}
#   8%|▊         | 2375/30000 [22:19<4:01:13,  1.91it/s]
# {'loss': 20.7345, 'grad_norm': 55.007354736328125, 'learning_rate': 3.9483333333333335e-05, 'epoch': 0.08}
#   8%|▊         | 2400/30000 [22:31<3:55:47,  1.95it/s]
# {'loss': 23.3238, 'grad_norm': 61.91250991821289, 'learning_rate': 3.99e-05, 'epoch': 0.08}
#   8%|▊         | 2425/30000 [22:44<3:53:35,  1.97it/s]
# {'loss': 17.7407, 'grad_norm': 33.03654861450195, 'learning_rate': 4.0316666666666666e-05, 'epoch': 0.08}
#   8%|▊         | 2450/30000 [22:57<3:38:18,  2.10it/s]
# {'loss': 15.6627, 'grad_norm': 32.973567962646484, 'learning_rate': 4.073333333333333e-05, 'epoch': 0.08}
#   8%|▊         | 2475/30000 [23:10<3:56:25,  1.94it/s]
# {'loss': 18.0797, 'grad_norm': 26.24540901184082, 'learning_rate': 4.115e-05, 'epoch': 0.08}
#   8%|▊         | 2500/30000 [23:22<3:57:41,  1.93it/s]
# {'loss': 20.2257, 'grad_norm': 48.01731491088867, 'learning_rate': 4.156666666666667e-05, 'epoch': 0.08}
#   8%|▊         | 2505/30000 [23:24<3:55:02,  1.95it/s]'(ProtocolError('Connection aborted.', BrokenPipeError(32, 'Broken pipe')), '(Request ID: 184cb6e5-21d9-44e0-84ce-9b9f9a4d1536)')' thrown while requesting GET https://huggingface.co/datasets/nguyenvulebinh/AVYT/resolve/e6c6bf6f40e698b82215d269cfc0a0d65a7a2372/vox2/vox2-dev-000001.tar
# Retrying in 1s [Retry 1/5].
#   8%|▊         | 2525/30000 [23:34<3:52:57,  1.97it/s]
# {'loss': 16.1858, 'grad_norm': 50.2606086730957, 'learning_rate': 4.1983333333333335e-05, 'epoch': 0.08}
#   8%|▊         | 2550/30000 [23:46<3:42:44,  2.05it/s]
# {'loss': 20.4322, 'grad_norm': 54.27219009399414, 'learning_rate': 4.24e-05, 'epoch': 0.09}
#   9%|▊         | 2575/30000 [23:59<3:54:20,  1.95it/s]
# {'loss': 17.1194, 'grad_norm': 39.40780258178711, 'learning_rate': 4.2816666666666666e-05, 'epoch': 0.09}
#   9%|▊         | 2600/30000 [24:11<4:04:30,  1.87it/s]
# {'loss': 14.5468, 'grad_norm': 17.392757415771484, 'learning_rate': 4.323333333333334e-05, 'epoch': 0.09}
#   9%|▉         | 2625/30000 [24:23<4:00:43,  1.90it/s]
# {'loss': 17.6046, 'grad_norm': 44.33537292480469, 'learning_rate': 4.3650000000000004e-05, 'epoch': 0.09}
#   9%|▉         | 2650/30000 [24:35<3:10:36,  2.39it/s]
# {'loss': 16.2522, 'grad_norm': 37.58259963989258, 'learning_rate': 4.406666666666667e-05, 'epoch': 0.09}
#   9%|▉         | 2675/30000 [24:47<3:47:02,  2.01it/s]
# {'loss': 17.7248, 'grad_norm': 47.34408950805664, 'learning_rate': 4.4483333333333335e-05, 'epoch': 0.09}
#   9%|▉         | 2700/30000 [24:59<3:16:50,  2.31it/s]
# {'loss': 15.1748, 'grad_norm': 33.853641510009766, 'learning_rate': 4.49e-05, 'epoch': 0.09}
#   9%|▉         | 2725/30000 [25:11<4:01:25,  1.88it/s]
# {'loss': 15.6938, 'grad_norm': 79.88500213623047, 'learning_rate': 4.5316666666666666e-05, 'epoch': 0.09}
#   9%|▉         | 2750/30000 [25:23<3:53:24,  1.95it/s]
# {'loss': 19.9844, 'grad_norm': 48.52936935424805, 'learning_rate': 4.573333333333333e-05, 'epoch': 0.09}
#   9%|▉         | 2775/30000 [25:35<3:43:21,  2.03it/s]
# {'loss': 16.4202, 'grad_norm': 43.097049713134766, 'learning_rate': 4.6150000000000004e-05, 'epoch': 0.09}
#   9%|▉         | 2800/30000 [25:48<3:57:21,  1.91it/s]
# {'loss': 16.9427, 'grad_norm': 44.06317138671875, 'learning_rate': 4.656666666666667e-05, 'epoch': 0.09}
#   9%|▉         | 2825/30000 [26:01<3:53:52,  1.94it/s]
# {'loss': 22.7557, 'grad_norm': 47.66730880737305, 'learning_rate': 4.6983333333333335e-05, 'epoch': 0.09}
#  10%|▉         | 2850/30000 [26:13<3:26:51,  2.19it/s]
# {'loss': 14.2364, 'grad_norm': 43.55778121948242, 'learning_rate': 4.74e-05, 'epoch': 0.1}
#  10%|▉         | 2875/30000 [26:24<3:09:58,  2.38it/s]
# {'loss': 14.715, 'grad_norm': 40.1729850769043, 'learning_rate': 4.781666666666667e-05, 'epoch': 0.1}
#  10%|▉         | 2900/30000 [26:36<3:52:06,  1.95it/s]
# {'loss': 13.5983, 'grad_norm': 26.32107925415039, 'learning_rate': 4.823333333333334e-05, 'epoch': 0.1}
#  10%|▉         | 2925/30000 [26:49<3:55:43,  1.91it/s]
# {'loss': 18.1017, 'grad_norm': 31.99476432800293, 'learning_rate': 4.8650000000000003e-05, 'epoch': 0.1}
#  10%|▉         | 2950/30000 [27:01<3:42:59,  2.02it/s]
# {'loss': 17.3263, 'grad_norm': 85.69903564453125, 'learning_rate': 4.906666666666667e-05, 'epoch': 0.1}
#  10%|▉         | 2975/30000 [27:13<3:11:25,  2.35it/s]
# {'loss': 13.8482, 'grad_norm': 35.472389221191406, 'learning_rate': 4.9483333333333334e-05, 'epoch': 0.1}
#  10%|█         | 3000/30000 [27:25<3:48:39,  1.97it/s]
# {'loss': 21.7097, 'grad_norm': 34.8327522277832, 'learning_rate': 4.99e-05, 'epoch': 0.1}
#  10%|█         | 3025/30000 [27:37<3:00:41,  2.49it/s]
# {'loss': 10.6001, 'grad_norm': 13.190470695495605, 'learning_rate': 4.996481481481482e-05, 'epoch': 0.1}
#  10%|█         | 3050/30000 [27:49<3:17:50,  2.27it/s]
# {'loss': 17.1302, 'grad_norm': 45.75181579589844, 'learning_rate': 4.991851851851852e-05, 'epoch': 0.1}
#  10%|█         | 3075/30000 [28:01<3:04:21,  2.43it/s]
# {'loss': 19.7415, 'grad_norm': 33.37633514404297, 'learning_rate': 4.9872222222222225e-05, 'epoch': 0.1}
#  10%|█         | 3100/30000 [28:14<3:50:00,  1.95it/s]
# {'loss': 17.0819, 'grad_norm': 28.064006805419922, 'learning_rate': 4.982592592592592e-05, 'epoch': 0.1}
#  10%|█         | 3125/30000 [28:25<3:33:11,  2.10it/s]
# {'loss': 21.0091, 'grad_norm': 35.46098709106445, 'learning_rate': 4.977962962962963e-05, 'epoch': 0.1}
#  10%|█         | 3150/30000 [28:38<3:59:51,  1.87it/s]
# {'loss': 16.9858, 'grad_norm': 24.328083038330078, 'learning_rate': 4.973333333333334e-05, 'epoch': 0.1}
#  11%|█         | 3175/30000 [28:50<3:00:46,  2.47it/s]
# {'loss': 21.1534, 'grad_norm': 22.701208114624023, 'learning_rate': 4.968703703703704e-05, 'epoch': 0.11}
#  11%|█         | 3200/30000 [29:03<3:45:58,  1.98it/s]
# {'loss': 18.4471, 'grad_norm': 19.105220794677734, 'learning_rate': 4.9640740740740744e-05, 'epoch': 0.11}
#  11%|█         | 3225/30000 [29:16<3:53:02,  1.91it/s]
# {'loss': 17.8963, 'grad_norm': 47.936241149902344, 'learning_rate': 4.959444444444445e-05, 'epoch': 0.11}
#  11%|█         | 3250/30000 [29:27<3:43:58,  1.99it/s]
# {'loss': 14.0106, 'grad_norm': 48.442047119140625, 'learning_rate': 4.954814814814815e-05, 'epoch': 0.11}
#  11%|█         | 3275/30000 [29:39<3:47:44,  1.96it/s]
# {'loss': 19.3764, 'grad_norm': 59.10612106323242, 'learning_rate': 4.9501851851851854e-05, 'epoch': 0.11}
#  11%|█         | 3300/30000 [29:51<2:50:44,  2.61it/s]
# {'loss': 18.7346, 'grad_norm': 38.538795471191406, 'learning_rate': 4.945555555555556e-05, 'epoch': 0.11}
#  11%|█         | 3325/30000 [30:03<3:44:50,  1.98it/s]
# {'loss': 16.2711, 'grad_norm': 64.82545471191406, 'learning_rate': 4.940925925925926e-05, 'epoch': 0.11}
#  11%|█         | 3350/30000 [30:15<3:35:11,  2.06it/s]
# {'loss': 16.3156, 'grad_norm': 91.93931579589844, 'learning_rate': 4.936296296296297e-05, 'epoch': 0.11}
#  11%|█▏        | 3375/30000 [30:27<3:11:19,  2.32it/s]
# {'loss': 18.3682, 'grad_norm': 32.892242431640625, 'learning_rate': 4.931666666666667e-05, 'epoch': 0.11}
#  11%|█▏        | 3400/30000 [30:38<3:05:56,  2.38it/s]
# {'loss': 17.2827, 'grad_norm': 32.833961486816406, 'learning_rate': 4.9270370370370374e-05, 'epoch': 0.11}
#  11%|█▏        | 3425/30000 [30:51<3:46:45,  1.95it/s]
# {'loss': 21.0335, 'grad_norm': 45.503021240234375, 'learning_rate': 4.922407407407408e-05, 'epoch': 0.11}
#  12%|█▏        | 3450/30000 [31:03<3:39:32,  2.02it/s]
# {'loss': 15.7656, 'grad_norm': 17.38704490661621, 'learning_rate': 4.917777777777778e-05, 'epoch': 0.12}
#  12%|█▏        | 3475/30000 [31:16<3:47:04,  1.95it/s]
# {'loss': 14.9186, 'grad_norm': 26.426761627197266, 'learning_rate': 4.913148148148148e-05, 'epoch': 0.12}
#  12%|█▏        | 3500/30000 [31:27<3:06:03,  2.37it/s]
# {'loss': 15.3008, 'grad_norm': 50.95805740356445, 'learning_rate': 4.908518518518519e-05, 'epoch': 0.12}
#  12%|█▏        | 3525/30000 [31:40<3:50:01,  1.92it/s]
# {'loss': 13.8678, 'grad_norm': 37.995361328125, 'learning_rate': 4.903888888888889e-05, 'epoch': 0.12}
#  12%|█▏        | 3550/30000 [31:53<3:41:26,  1.99it/s]
# {'loss': 25.266, 'grad_norm': 34.77388000488281, 'learning_rate': 4.89925925925926e-05, 'epoch': 0.12}
#  12%|█▏        | 3575/30000 [32:03<3:24:44,  2.15it/s]
# {'loss': 8.5745, 'grad_norm': 21.738466262817383, 'learning_rate': 4.8946296296296304e-05, 'epoch': 0.12}
#  12%|█▏        | 3600/30000 [32:15<2:49:24,  2.60it/s]
# {'loss': 22.1572, 'grad_norm': 11.232606887817383, 'learning_rate': 4.89e-05, 'epoch': 0.12}
#  12%|█▏        | 3625/30000 [32:28<3:51:10,  1.90it/s]
# {'loss': 20.7341, 'grad_norm': 52.21577072143555, 'learning_rate': 4.885370370370371e-05, 'epoch': 0.12}
#  12%|█▏        | 3650/30000 [32:40<3:38:09,  2.01it/s]
# {'loss': 15.2986, 'grad_norm': 42.12381362915039, 'learning_rate': 4.880740740740741e-05, 'epoch': 0.12}
#  12%|█▏        | 3675/30000 [32:51<3:39:46,  2.00it/s]
# {'loss': 13.5757, 'grad_norm': 38.01112365722656, 'learning_rate': 4.876111111111111e-05, 'epoch': 0.12}
#  12%|█▏        | 3700/30000 [33:04<3:41:48,  1.98it/s]
# {'loss': 17.2453, 'grad_norm': 70.89056396484375, 'learning_rate': 4.871481481481482e-05, 'epoch': 0.12}
#  12%|█▏        | 3725/30000 [33:17<3:46:53,  1.93it/s]
# {'loss': 17.2477, 'grad_norm': 44.20790481567383, 'learning_rate': 4.8668518518518516e-05, 'epoch': 0.12}
#  12%|█▎        | 3750/30000 [33:29<4:00:25,  1.82it/s]
# {'loss': 19.6534, 'grad_norm': 25.02775001525879, 'learning_rate': 4.862222222222222e-05, 'epoch': 0.12}
#  13%|█▎        | 3775/30000 [33:41<3:15:47,  2.23it/s]
# {'loss': 16.8242, 'grad_norm': 31.761756896972656, 'learning_rate': 4.857592592592593e-05, 'epoch': 0.13}
#  13%|█▎        | 3800/30000 [33:54<3:36:09,  2.02it/s]
# {'loss': 15.7955, 'grad_norm': 27.70638656616211, 'learning_rate': 4.852962962962963e-05, 'epoch': 0.13}
#  13%|█▎        | 3825/30000 [34:05<3:33:31,  2.04it/s]
# {'loss': 12.2506, 'grad_norm': 40.06996154785156, 'learning_rate': 4.848333333333334e-05, 'epoch': 0.13}
#  13%|█▎        | 3850/30000 [34:18<3:38:40,  1.99it/s]
# {'loss': 18.4189, 'grad_norm': 30.229658126831055, 'learning_rate': 4.843703703703704e-05, 'epoch': 0.13}
#  13%|█▎        | 3875/30000 [34:31<3:29:58,  2.07it/s]
# {'loss': 19.0975, 'grad_norm': 42.69168472290039, 'learning_rate': 4.839074074074074e-05, 'epoch': 0.13}
#  13%|█▎        | 3900/30000 [34:42<3:40:30,  1.97it/s]
# {'loss': 14.6278, 'grad_norm': 37.505882263183594, 'learning_rate': 4.8344444444444447e-05, 'epoch': 0.13}
#  13%|█▎        | 3925/30000 [34:55<3:38:17,  1.99it/s]
# {'loss': 16.9248, 'grad_norm': 41.43263626098633, 'learning_rate': 4.8298148148148145e-05, 'epoch': 0.13}
#  13%|█▎        | 3950/30000 [35:07<3:50:17,  1.89it/s]
# {'loss': 24.364, 'grad_norm': 57.813446044921875, 'learning_rate': 4.825185185185185e-05, 'epoch': 0.13}
#  13%|█▎        | 3975/30000 [35:19<3:32:11,  2.04it/s]
# {'loss': 18.8224, 'grad_norm': 60.66712951660156, 'learning_rate': 4.820555555555556e-05, 'epoch': 0.13}
#  13%|█▎        | 4000/30000 [35:31<3:43:22,  1.94it/s]
# {'loss': 14.1124, 'grad_norm': 35.98902893066406, 'learning_rate': 4.815925925925926e-05, 'epoch': 0.13}
# Too many dataloader workers: 10 (max is dataset.num_shards=3). Stopping 7 dataloader workers.
#  13%|█▎        | 4000/30000 [38:32<3:43:22,  1.94it/s]
# {'eval_loss': 29.022287368774414, 'eval_runtime': 181.3287, 'eval_samples_per_second': 21.464, 'eval_steps_per_second': 5.366, 'epoch': 0.13}
#  13%|█▎        | 4025/30000 [38:52<3:52:41,  1.86it/s]
# {'loss': 13.6175, 'grad_norm': 57.35700225830078, 'learning_rate': 4.8112962962962966e-05, 'epoch': 0.13}
#  14%|█▎        | 4050/30000 [39:04<2:57:59,  2.43it/s]
# {'loss': 15.8332, 'grad_norm': 17.545730590820312, 'learning_rate': 4.806666666666667e-05, 'epoch': 0.14}
#  14%|█▎        | 4075/30000 [39:16<3:05:47,  2.33it/s]
# {'loss': 15.1068, 'grad_norm': 33.67498779296875, 'learning_rate': 4.802037037037037e-05, 'epoch': 0.14}
#  14%|█▎        | 4100/30000 [39:27<3:09:11,  2.28it/s]
# {'loss': 13.4778, 'grad_norm': 53.151214599609375, 'learning_rate': 4.7974074074074076e-05, 'epoch': 0.14}
#  14%|█▍        | 4125/30000 [39:39<3:40:52,  1.95it/s]
# {'loss': 19.5387, 'grad_norm': 62.021240234375, 'learning_rate': 4.792777777777778e-05, 'epoch': 0.14}
#  14%|█▍        | 4150/30000 [39:51<3:07:42,  2.30it/s]
# {'loss': 12.9157, 'grad_norm': 30.475574493408203, 'learning_rate': 4.788148148148148e-05, 'epoch': 0.14}
#  14%|█▍        | 4175/30000 [40:02<2:59:10,  2.40it/s]
# {'loss': 15.8153, 'grad_norm': 17.95908546447754, 'learning_rate': 4.783518518518519e-05, 'epoch': 0.14}
#  14%|█▍        | 4200/30000 [40:15<3:06:09,  2.31it/s]
# {'loss': 19.1894, 'grad_norm': 62.913063049316406, 'learning_rate': 4.778888888888889e-05, 'epoch': 0.14}
#  14%|█▍        | 4225/30000 [40:26<3:44:30,  1.91it/s]
# {'loss': 15.4821, 'grad_norm': 58.250606536865234, 'learning_rate': 4.7742592592592596e-05, 'epoch': 0.14}
#  14%|█▍        | 4250/30000 [40:39<3:51:31,  1.85it/s]
# {'loss': 24.649, 'grad_norm': 28.157302856445312, 'learning_rate': 4.76962962962963e-05, 'epoch': 0.14}
#  14%|█▍        | 4275/30000 [40:52<3:40:28,  1.94it/s]
# {'loss': 15.3717, 'grad_norm': 34.92318344116211, 'learning_rate': 4.765e-05, 'epoch': 0.14}
#  14%|█▍        | 4300/30000 [41:04<3:35:36,  1.99it/s]
# {'loss': 18.6014, 'grad_norm': 47.54502487182617, 'learning_rate': 4.7603703703703705e-05, 'epoch': 0.14}
#  14%|█▍        | 4325/30000 [41:15<3:34:02,  2.00it/s]
# {'loss': 13.5914, 'grad_norm': 29.95307731628418, 'learning_rate': 4.755740740740741e-05, 'epoch': 0.14}
#  14%|█▍        | 4350/30000 [41:27<3:41:01,  1.93it/s]
# {'loss': 16.7452, 'grad_norm': 40.48641586303711, 'learning_rate': 4.751111111111111e-05, 'epoch': 0.14}
#  15%|█▍        | 4375/30000 [41:40<3:36:59,  1.97it/s]
# {'loss': 16.7788, 'grad_norm': 49.83125305175781, 'learning_rate': 4.746481481481482e-05, 'epoch': 0.15}
#  15%|█▍        | 4400/30000 [41:51<3:25:06,  2.08it/s]
# {'loss': 16.2961, 'grad_norm': 46.861873626708984, 'learning_rate': 4.742037037037037e-05, 'epoch': 0.15}
#  15%|█▍        | 4425/30000 [42:04<3:35:46,  1.98it/s]
# {'loss': 17.6394, 'grad_norm': 41.24041748046875, 'learning_rate': 4.7374074074074075e-05, 'epoch': 0.15}
#  15%|█▍        | 4450/30000 [42:17<3:36:52,  1.96it/s]
# {'loss': 27.244, 'grad_norm': 64.98941040039062, 'learning_rate': 4.732777777777778e-05, 'epoch': 0.15}
#  15%|█▍        | 4475/30000 [42:29<3:39:48,  1.94it/s]
# {'loss': 21.6392, 'grad_norm': 39.62762451171875, 'learning_rate': 4.7281481481481485e-05, 'epoch': 0.15}
#  15%|█▌        | 4500/30000 [42:41<2:56:20,  2.41it/s]
# {'loss': 19.1883, 'grad_norm': 21.145402908325195, 'learning_rate': 4.723518518518519e-05, 'epoch': 0.15}
#  15%|█▌        | 4525/30000 [42:53<3:22:16,  2.10it/s]
# {'loss': 15.0927, 'grad_norm': 45.778480529785156, 'learning_rate': 4.7188888888888896e-05, 'epoch': 0.15}
#  15%|█▌        | 4550/30000 [43:06<3:35:30,  1.97it/s]
# {'loss': 21.8076, 'grad_norm': 25.397558212280273, 'learning_rate': 4.7142592592592595e-05, 'epoch': 0.15}
#  15%|█▌        | 4575/30000 [43:17<3:00:43,  2.34it/s]
# {'loss': 16.1304, 'grad_norm': 27.2319278717041, 'learning_rate': 4.70962962962963e-05, 'epoch': 0.15}
#  15%|█▌        | 4600/30000 [43:29<3:29:27,  2.02it/s]
# {'loss': 17.1538, 'grad_norm': 45.20541763305664, 'learning_rate': 4.705e-05, 'epoch': 0.15}
#  15%|█▌        | 4625/30000 [43:40<2:49:41,  2.49it/s]
# {'loss': 17.5584, 'grad_norm': 32.486053466796875, 'learning_rate': 4.7003703703703704e-05, 'epoch': 0.15}
#  16%|█▌        | 4650/30000 [43:51<3:34:23,  1.97it/s]
# {'loss': 15.6187, 'grad_norm': 45.574703216552734, 'learning_rate': 4.695740740740741e-05, 'epoch': 0.15}
#  16%|█▌        | 4675/30000 [44:03<3:34:46,  1.97it/s]
# {'loss': 16.2329, 'grad_norm': 36.11827850341797, 'learning_rate': 4.6911111111111114e-05, 'epoch': 0.16}
#  16%|█▌        | 4700/30000 [44:16<3:35:01,  1.96it/s]
# {'loss': 26.005, 'grad_norm': 43.788143157958984, 'learning_rate': 4.686481481481482e-05, 'epoch': 0.16}
#  16%|█▌        | 4725/30000 [44:28<3:40:27,  1.91it/s]
# {'loss': 19.6136, 'grad_norm': 47.29106140136719, 'learning_rate': 4.6818518518518525e-05, 'epoch': 0.16}
#  16%|█▌        | 4750/30000 [44:40<3:36:33,  1.94it/s]
# {'loss': 19.8389, 'grad_norm': 44.14997863769531, 'learning_rate': 4.6772222222222224e-05, 'epoch': 0.16}
#  16%|█▌        | 4775/30000 [44:52<3:37:02,  1.94it/s]
# {'loss': 18.3579, 'grad_norm': 31.957895278930664, 'learning_rate': 4.672592592592593e-05, 'epoch': 0.16}
#  16%|█▌        | 4800/30000 [45:05<3:36:58,  1.94it/s]
# {'loss': 24.7826, 'grad_norm': 69.87605285644531, 'learning_rate': 4.6679629629629634e-05, 'epoch': 0.16}
#  16%|█▌        | 4825/30000 [45:16<2:58:26,  2.35it/s]
# {'loss': 19.4108, 'grad_norm': 36.94178771972656, 'learning_rate': 4.663333333333333e-05, 'epoch': 0.16}
#  16%|█▌        | 4850/30000 [45:28<3:23:23,  2.06it/s]
# {'loss': 17.7596, 'grad_norm': 36.55371856689453, 'learning_rate': 4.658703703703704e-05, 'epoch': 0.16}
#  16%|█▋        | 4875/30000 [45:40<3:24:21,  2.05it/s]
# {'loss': 21.4059, 'grad_norm': 53.33694076538086, 'learning_rate': 4.6540740740740744e-05, 'epoch': 0.16}
#  16%|█▋        | 4900/30000 [45:52<3:46:34,  1.85it/s]
# {'loss': 16.6781, 'grad_norm': 35.69208908081055, 'learning_rate': 4.649444444444445e-05, 'epoch': 0.16}
#  16%|█▋        | 4925/30000 [46:04<3:35:58,  1.94it/s]
# {'loss': 16.5291, 'grad_norm': 45.16056823730469, 'learning_rate': 4.6448148148148154e-05, 'epoch': 0.16}
#  16%|█▋        | 4950/30000 [46:16<2:51:52,  2.43it/s]
# {'loss': 20.6508, 'grad_norm': 10.941885948181152, 'learning_rate': 4.640185185185185e-05, 'epoch': 0.17}
#  17%|█▋        | 4975/30000 [46:27<2:49:55,  2.45it/s]
# {'loss': 15.4771, 'grad_norm': 33.7725715637207, 'learning_rate': 4.635555555555556e-05, 'epoch': 0.17}
#  17%|█▋        | 5000/30000 [46:40<3:32:58,  1.96it/s]
# {'loss': 19.8166, 'grad_norm': 56.73935317993164, 'learning_rate': 4.6309259259259264e-05, 'epoch': 0.17}
#  17%|█▋        | 5025/30000 [46:52<3:30:35,  1.98it/s]
# {'loss': 18.8655, 'grad_norm': 51.022403717041016, 'learning_rate': 4.626296296296296e-05, 'epoch': 0.17}
#  17%|█▋        | 5050/30000 [47:03<3:37:15,  1.91it/s]
# {'loss': 15.903, 'grad_norm': 35.30324935913086, 'learning_rate': 4.621666666666667e-05, 'epoch': 0.17}
#  17%|█▋        | 5075/30000 [47:16<3:49:55,  1.81it/s]
# {'loss': 17.4056, 'grad_norm': 28.52605628967285, 'learning_rate': 4.617037037037037e-05, 'epoch': 0.17}
#  17%|█▋        | 5100/30000 [47:29<3:15:36,  2.12it/s]
# {'loss': 19.2186, 'grad_norm': 58.127540588378906, 'learning_rate': 4.612407407407408e-05, 'epoch': 0.17}
#  17%|█▋        | 5125/30000 [47:41<3:45:21,  1.84it/s]
# {'loss': 16.5307, 'grad_norm': 51.28739929199219, 'learning_rate': 4.6077777777777783e-05, 'epoch': 0.17}
#  17%|█▋        | 5150/30000 [47:53<3:02:54,  2.26it/s]
# {'loss': 12.7429, 'grad_norm': 18.857452392578125, 'learning_rate': 4.603148148148148e-05, 'epoch': 0.17}
#  17%|█▋        | 5175/30000 [48:05<3:41:24,  1.87it/s]
# {'loss': 18.4396, 'grad_norm': 103.70193481445312, 'learning_rate': 4.598518518518519e-05, 'epoch': 0.17}
#  17%|█▋        | 5200/30000 [48:18<3:05:03,  2.23it/s]
# {'loss': 14.218, 'grad_norm': 23.822595596313477, 'learning_rate': 4.593888888888889e-05, 'epoch': 0.17}
#  17%|█▋        | 5225/30000 [48:31<3:39:23,  1.88it/s]
# {'loss': 19.5997, 'grad_norm': 42.40589141845703, 'learning_rate': 4.589259259259259e-05, 'epoch': 0.17}
#  18%|█▊        | 5250/30000 [48:45<3:46:06,  1.82it/s]
# {'loss': 14.4512, 'grad_norm': 31.370622634887695, 'learning_rate': 4.5846296296296297e-05, 'epoch': 0.17}
#  18%|█▊        | 5275/30000 [48:59<3:59:57,  1.72it/s]
# {'loss': 19.2615, 'grad_norm': 31.041746139526367, 'learning_rate': 4.58e-05, 'epoch': 0.18}
#  18%|█▊        | 5300/30000 [49:12<3:46:27,  1.82it/s]
# {'loss': 18.1107, 'grad_norm': 41.325103759765625, 'learning_rate': 4.575370370370371e-05, 'epoch': 0.18}
#  18%|█▊        | 5325/30000 [49:24<2:53:13,  2.37it/s]
# {'loss': 15.3175, 'grad_norm': 45.89544677734375, 'learning_rate': 4.570740740740741e-05, 'epoch': 0.18}
#  18%|█▊        | 5350/30000 [49:37<3:00:19,  2.28it/s]
# {'loss': 18.2191, 'grad_norm': 29.707054138183594, 'learning_rate': 4.566111111111112e-05, 'epoch': 0.18}
#  18%|█▊        | 5375/30000 [49:48<2:55:25,  2.34it/s]
# {'loss': 15.1771, 'grad_norm': 36.12180709838867, 'learning_rate': 4.5614814814814817e-05, 'epoch': 0.18}
#  18%|█▊        | 5400/30000 [49:59<2:54:57,  2.34it/s]
# {'loss': 13.02, 'grad_norm': 33.5576171875, 'learning_rate': 4.556851851851852e-05, 'epoch': 0.18}
#  18%|█▊        | 5425/30000 [50:12<3:23:10,  2.02it/s]
# {'loss': 18.3651, 'grad_norm': 44.85825729370117, 'learning_rate': 4.552222222222222e-05, 'epoch': 0.18}
#  18%|█▊        | 5450/30000 [50:23<3:32:18,  1.93it/s]
# {'loss': 17.8957, 'grad_norm': 103.42386627197266, 'learning_rate': 4.5475925925925926e-05, 'epoch': 0.18}
#  18%|█▊        | 5475/30000 [50:36<3:32:35,  1.92it/s]
# {'loss': 18.1513, 'grad_norm': 44.772727966308594, 'learning_rate': 4.542962962962963e-05, 'epoch': 0.18}
#  18%|█▊        | 5500/30000 [50:49<3:32:12,  1.92it/s]
# {'loss': 19.9577, 'grad_norm': 42.84458541870117, 'learning_rate': 4.5383333333333336e-05, 'epoch': 0.18}
#  18%|█▊        | 5525/30000 [51:01<2:57:29,  2.30it/s]
# {'loss': 16.7361, 'grad_norm': 29.729793548583984, 'learning_rate': 4.533703703703704e-05, 'epoch': 0.18}
#  18%|█▊        | 5550/30000 [51:15<4:06:23,  1.65it/s]
# {'loss': 22.2088, 'grad_norm': 71.18746185302734, 'learning_rate': 4.529074074074075e-05, 'epoch': 0.18}
#  19%|█▊        | 5575/30000 [51:28<3:22:44,  2.01it/s]
# {'loss': 12.9099, 'grad_norm': 20.254457473754883, 'learning_rate': 4.5244444444444446e-05, 'epoch': 0.19}
#  19%|█▊        | 5600/30000 [51:42<3:55:50,  1.72it/s]
# {'loss': 16.9867, 'grad_norm': 32.32893753051758, 'learning_rate': 4.519814814814815e-05, 'epoch': 0.19}
#  19%|█▉        | 5625/30000 [51:56<4:04:04,  1.66it/s]
# {'loss': 17.0368, 'grad_norm': 24.132667541503906, 'learning_rate': 4.5151851851851856e-05, 'epoch': 0.19}
#  19%|█▉        | 5650/30000 [52:09<3:52:21,  1.75it/s]
# {'loss': 13.5152, 'grad_norm': 32.37455368041992, 'learning_rate': 4.5105555555555555e-05, 'epoch': 0.19}
#  19%|█▉        | 5675/30000 [52:23<3:18:55,  2.04it/s]
# {'loss': 21.6962, 'grad_norm': 18.58466148376465, 'learning_rate': 4.505925925925926e-05, 'epoch': 0.19}
#  19%|█▉        | 5700/30000 [52:36<3:28:11,  1.95it/s]
# {'loss': 16.9126, 'grad_norm': 38.70191192626953, 'learning_rate': 4.5012962962962966e-05, 'epoch': 0.19}
#  19%|█▉        | 5725/30000 [52:50<3:12:46,  2.10it/s]
# {'loss': 16.8766, 'grad_norm': 25.637556076049805, 'learning_rate': 4.496666666666667e-05, 'epoch': 0.19}
#  19%|█▉        | 5750/30000 [53:05<3:54:34,  1.72it/s]
# {'loss': 25.4366, 'grad_norm': 36.06661605834961, 'learning_rate': 4.4920370370370376e-05, 'epoch': 0.19}
#  19%|█▉        | 5775/30000 [53:19<3:41:40,  1.82it/s]
# {'loss': 17.5677, 'grad_norm': 82.25835418701172, 'learning_rate': 4.4874074074074075e-05, 'epoch': 0.19}
#  19%|█▉        | 5800/30000 [53:32<4:07:21,  1.63it/s]
# {'loss': 14.8649, 'grad_norm': 35.15450668334961, 'learning_rate': 4.482777777777778e-05, 'epoch': 0.19}
#  19%|█▉        | 5825/30000 [53:45<3:21:55,  2.00it/s]
# {'loss': 18.0373, 'grad_norm': 31.085952758789062, 'learning_rate': 4.4781481481481486e-05, 'epoch': 0.19}
#  20%|█▉        | 5850/30000 [53:59<3:30:17,  1.91it/s]
# {'loss': 19.857, 'grad_norm': 82.31710052490234, 'learning_rate': 4.4735185185185184e-05, 'epoch': 0.2}
#  20%|█▉        | 5875/30000 [54:13<3:59:49,  1.68it/s]
# {'loss': 18.2909, 'grad_norm': 46.69183349609375, 'learning_rate': 4.468888888888889e-05, 'epoch': 0.2}
#  20%|█▉        | 5900/30000 [54:28<3:47:03,  1.77it/s]
# {'loss': 19.5341, 'grad_norm': 66.7958984375, 'learning_rate': 4.4642592592592595e-05, 'epoch': 0.2}
#  20%|█▉        | 5925/30000 [54:42<3:47:51,  1.76it/s]
# {'loss': 24.0393, 'grad_norm': 39.62435531616211, 'learning_rate': 4.45962962962963e-05, 'epoch': 0.2}
#  20%|█▉        | 5950/30000 [54:57<4:03:23,  1.65it/s]
# {'loss': 25.288, 'grad_norm': 68.63208770751953, 'learning_rate': 4.4550000000000005e-05, 'epoch': 0.2}
#  20%|█▉        | 5975/30000 [55:10<3:04:57,  2.16it/s]
# {'loss': 18.2677, 'grad_norm': 25.001840591430664, 'learning_rate': 4.450370370370371e-05, 'epoch': 0.2}
#  20%|██        | 6000/30000 [55:24<3:18:49,  2.01it/s]
# {'loss': 20.2862, 'grad_norm': 42.09543228149414, 'learning_rate': 4.445740740740741e-05, 'epoch': 0.2}
# Too many dataloader workers: 10 (max is dataset.num_shards=3). Stopping 7 dataloader workers.
#  20%|██        | 6000/30000 [58:25<3:18:49,  2.01it/s]
# {'eval_loss': 29.104970932006836, 'eval_runtime': 180.9972, 'eval_samples_per_second': 21.503, 'eval_steps_per_second': 5.376, 'epoch': 0.2}
#  20%|██        | 6025/30000 [58:46<3:29:56,  1.90it/s]
# {'loss': 15.8287, 'grad_norm': 36.72803497314453, 'learning_rate': 4.4411111111111115e-05, 'epoch': 0.2}
#  20%|██        | 6050/30000 [58:58<3:01:25,  2.20it/s]
# {'loss': 17.948, 'grad_norm': 26.055095672607422, 'learning_rate': 4.436481481481481e-05, 'epoch': 0.2}
#  20%|██        | 6075/30000 [59:10<3:23:57,  1.96it/s]
# {'loss': 16.8921, 'grad_norm': 23.586381912231445, 'learning_rate': 4.431851851851852e-05, 'epoch': 0.2}
#  20%|██        | 6100/30000 [59:22<3:22:33,  1.97it/s]
# {'loss': 15.62, 'grad_norm': 53.15266799926758, 'learning_rate': 4.4272222222222224e-05, 'epoch': 0.2}
#  20%|██        | 6125/30000 [59:34<3:13:45,  2.05it/s]
# {'loss': 25.2939, 'grad_norm': 59.84363555908203, 'learning_rate': 4.422592592592593e-05, 'epoch': 0.2}
#  20%|██        | 6150/30000 [59:46<3:20:45,  1.98it/s]
# {'loss': 19.6536, 'grad_norm': 65.3487548828125, 'learning_rate': 4.4179629629629635e-05, 'epoch': 0.2}
#  21%|██        | 6175/30000 [59:58<3:14:00,  2.05it/s]
# {'loss': 14.1602, 'grad_norm': 17.494779586791992, 'learning_rate': 4.413333333333334e-05, 'epoch': 0.21}
#  21%|██        | 6200/30000 [1:00:10<3:25:18,  1.93it/s]
# {'loss': 18.2495, 'grad_norm': 49.8433723449707, 'learning_rate': 4.408703703703704e-05, 'epoch': 0.21}
#  21%|██        | 6225/30000 [1:00:22<3:17:18,  2.01it/s]
# {'loss': 20.7039, 'grad_norm': 48.14457702636719, 'learning_rate': 4.4042592592592594e-05, 'epoch': 0.21}
#  21%|██        | 6250/30000 [1:00:33<2:49:01,  2.34it/s]
# {'loss': 19.0023, 'grad_norm': 35.20683670043945, 'learning_rate': 4.39962962962963e-05, 'epoch': 0.21}
#  21%|██        | 6275/30000 [1:00:46<3:17:31,  2.00it/s]
# {'loss': 21.3614, 'grad_norm': 36.352394104003906, 'learning_rate': 4.3950000000000004e-05, 'epoch': 0.21}
#  21%|██        | 6300/30000 [1:00:58<2:56:48,  2.23it/s]
# {'loss': 20.6148, 'grad_norm': 56.06901168823242, 'learning_rate': 4.390370370370371e-05, 'epoch': 0.21}
#  21%|██        | 6325/30000 [1:01:11<3:04:45,  2.14it/s]
# {'loss': 23.3395, 'grad_norm': 29.13734245300293, 'learning_rate': 4.385740740740741e-05, 'epoch': 0.21}
#  21%|██        | 6350/30000 [1:01:22<3:13:19,  2.04it/s]
# {'loss': 18.6844, 'grad_norm': 35.358863830566406, 'learning_rate': 4.3811111111111114e-05, 'epoch': 0.21}
#  21%|██▏       | 6375/30000 [1:01:33<3:22:56,  1.94it/s]
# {'loss': 13.1175, 'grad_norm': 54.81475067138672, 'learning_rate': 4.376481481481482e-05, 'epoch': 0.21}
#  21%|██▏       | 6400/30000 [1:01:46<3:21:05,  1.96it/s]
# {'loss': 20.4848, 'grad_norm': 59.07655715942383, 'learning_rate': 4.371851851851852e-05, 'epoch': 0.21}
#  21%|██▏       | 6425/30000 [1:01:58<3:21:44,  1.95it/s]
# {'loss': 24.5246, 'grad_norm': 45.95403289794922, 'learning_rate': 4.367222222222222e-05, 'epoch': 0.21}
#  22%|██▏       | 6450/30000 [1:02:10<2:52:36,  2.27it/s]
# {'loss': 17.5259, 'grad_norm': 39.47509002685547, 'learning_rate': 4.362592592592593e-05, 'epoch': 0.21}
#  22%|██▏       | 6475/30000 [1:02:23<3:18:06,  1.98it/s]
# {'loss': 17.2353, 'grad_norm': 50.076332092285156, 'learning_rate': 4.3579629629629634e-05, 'epoch': 0.22}
#  22%|██▏       | 6500/30000 [1:02:34<2:43:05,  2.40it/s]
# {'loss': 19.9636, 'grad_norm': 15.701350212097168, 'learning_rate': 4.353333333333334e-05, 'epoch': 0.22}
#  22%|██▏       | 6525/30000 [1:02:46<3:19:25,  1.96it/s]
# {'loss': 21.7949, 'grad_norm': 75.74345397949219, 'learning_rate': 4.348703703703704e-05, 'epoch': 0.22}
#  22%|██▏       | 6550/30000 [1:02:58<3:16:02,  1.99it/s]
# {'loss': 18.0053, 'grad_norm': 24.224790573120117, 'learning_rate': 4.344074074074074e-05, 'epoch': 0.22}
#  22%|██▏       | 6575/30000 [1:03:10<3:23:43,  1.92it/s]
# {'loss': 16.1367, 'grad_norm': 45.726680755615234, 'learning_rate': 4.339444444444445e-05, 'epoch': 0.22}
#  22%|██▏       | 6600/30000 [1:03:23<3:15:07,  2.00it/s]
# {'loss': 21.1735, 'grad_norm': 41.60273361206055, 'learning_rate': 4.334814814814815e-05, 'epoch': 0.22}
#  22%|██▏       | 6625/30000 [1:03:34<2:49:53,  2.29it/s]
# {'loss': 19.6231, 'grad_norm': 37.92676544189453, 'learning_rate': 4.330185185185185e-05, 'epoch': 0.22}
#  22%|██▏       | 6650/30000 [1:03:46<3:19:18,  1.95it/s]
# {'loss': 14.7755, 'grad_norm': 84.082275390625, 'learning_rate': 4.325555555555556e-05, 'epoch': 0.22}
#  22%|██▏       | 6675/30000 [1:03:58<2:46:57,  2.33it/s]
# {'loss': 13.2358, 'grad_norm': 47.05772018432617, 'learning_rate': 4.320925925925926e-05, 'epoch': 0.22}
#  22%|██▏       | 6700/30000 [1:04:09<3:12:09,  2.02it/s]
# {'loss': 14.5919, 'grad_norm': 68.79151916503906, 'learning_rate': 4.316296296296297e-05, 'epoch': 0.22}
#  22%|██▏       | 6725/30000 [1:04:22<3:29:56,  1.85it/s]
# {'loss': 18.7821, 'grad_norm': 33.050594329833984, 'learning_rate': 4.311666666666667e-05, 'epoch': 0.22}
#  22%|██▎       | 6750/30000 [1:04:33<2:27:17,  2.63it/s]
# {'loss': 22.1312, 'grad_norm': 34.93065643310547, 'learning_rate': 4.307037037037037e-05, 'epoch': 0.23}
#  23%|██▎       | 6775/30000 [1:04:45<3:10:00,  2.04it/s]
# {'loss': 17.7941, 'grad_norm': 50.494380950927734, 'learning_rate': 4.302407407407408e-05, 'epoch': 0.23}
#  23%|██▎       | 6800/30000 [1:04:57<3:12:59,  2.00it/s]
# {'loss': 16.4499, 'grad_norm': 37.0106201171875, 'learning_rate': 4.2977777777777776e-05, 'epoch': 0.23}
# ...
#  93%|█████████▎| 27875/30000 [4:27:15<14:35,  2.43it/s]
# {'loss': 13.4813, 'grad_norm': 49.53357696533203, 'learning_rate': 3.962962962962963e-06, 'epoch': 0.93}
#  93%|█████████▎| 27900/30000 [4:27:27<17:53,  1.96it/s]
# {'loss': 17.3197, 'grad_norm': 36.43801498413086, 'learning_rate': 3.916666666666667e-06, 'epoch': 0.93}
#  93%|█████████▎| 27925/30000 [4:27:40<17:47,  1.94it/s]
# {'loss': 19.9199, 'grad_norm': 45.25344467163086, 'learning_rate': 3.87037037037037e-06, 'epoch': 0.93}
#  93%|█████████▎| 27950/30000 [4:27:51<18:12,  1.88it/s]
# {'loss': 14.5439, 'grad_norm': 38.95186996459961, 'learning_rate': 3.824074074074074e-06, 'epoch': 0.93}
#  93%|█████████▎| 27975/30000 [4:28:04<17:19,  1.95it/s]
# {'loss': 24.094, 'grad_norm': 72.46165466308594, 'learning_rate': 3.777777777777778e-06, 'epoch': 0.93}
#  93%|█████████▎| 28000/30000 [4:28:16<14:05,  2.36it/s]
# {'loss': 15.6524, 'grad_norm': 39.430076599121094, 'learning_rate': 3.7314814814814817e-06, 'epoch': 0.93}
# Too many dataloader workers: 10 (max is dataset.num_shards=3). Stopping 7 dataloader workers.
#  93%|█████████▎| 28000/30000 [4:31:16<14:05,  2.36it/s]
# {'eval_loss': 27.75004005432129, 'eval_runtime': 180.1605, 'eval_samples_per_second': 21.603, 'eval_steps_per_second': 5.401, 'epoch': 0.93}
#  93%|█████████▎| 28025/30000 [4:31:38<18:33,  1.77it/s]
# {'loss': 15.456, 'grad_norm': 52.88685989379883, 'learning_rate': 3.6851851851851854e-06, 'epoch': 0.93}
#  94%|█████████▎| 28050/30000 [4:31:50<16:41,  1.95it/s]
# {'loss': 21.873, 'grad_norm': 57.07524871826172, 'learning_rate': 3.638888888888889e-06, 'epoch': 0.94}
#  94%|█████████▎| 28075/30000 [4:32:02<14:11,  2.26it/s]
# {'loss': 14.9934, 'grad_norm': 28.62950897216797, 'learning_rate': 3.5925925925925927e-06, 'epoch': 0.94}
#  94%|█████████▎| 28100/30000 [4:32:14<15:17,  2.07it/s]
# {'loss': 15.803, 'grad_norm': 31.34559440612793, 'learning_rate': 3.5462962962962963e-06, 'epoch': 0.94}
#  94%|█████████▍| 28125/30000 [4:32:27<14:41,  2.13it/s]
# {'loss': 19.7348, 'grad_norm': 69.83973693847656, 'learning_rate': 3.5000000000000004e-06, 'epoch': 0.94}
#  94%|█████████▍| 28150/30000 [4:32:39<14:00,  2.20it/s]
# {'loss': 16.4288, 'grad_norm': 27.528636932373047, 'learning_rate': 3.453703703703704e-06, 'epoch': 0.94}
#  94%|█████████▍| 28175/30000 [4:32:52<15:35,  1.95it/s]
# {'loss': 22.7377, 'grad_norm': 150.14553833007812, 'learning_rate': 3.4092592592592592e-06, 'epoch': 0.94}
#  94%|█████████▍| 28200/30000 [4:33:04<15:04,  1.99it/s]
# {'loss': 21.0733, 'grad_norm': 59.89854431152344, 'learning_rate': 3.362962962962963e-06, 'epoch': 0.94}
#  94%|█████████▍| 28225/30000 [4:33:17<14:18,  2.07it/s]
# {'loss': 21.392, 'grad_norm': 50.738555908203125, 'learning_rate': 3.3166666666666665e-06, 'epoch': 0.94}
#  94%|█████████▍| 28250/30000 [4:33:29<15:17,  1.91it/s]
# {'loss': 15.1276, 'grad_norm': 49.10731506347656, 'learning_rate': 3.270370370370371e-06, 'epoch': 0.94}
#  94%|█████████▍| 28275/30000 [4:33:42<13:10,  2.18it/s]
# {'loss': 17.9709, 'grad_norm': 25.73773956298828, 'learning_rate': 3.2240740740740747e-06, 'epoch': 0.94}
#  94%|█████████▍| 28300/30000 [4:33:54<14:08,  2.00it/s]
# {'loss': 17.4557, 'grad_norm': 33.74159240722656, 'learning_rate': 3.1777777777777783e-06, 'epoch': 0.94}
#  94%|█████████▍| 28325/30000 [4:34:06<14:35,  1.91it/s]
# {'loss': 19.0094, 'grad_norm': 58.6474609375, 'learning_rate': 3.131481481481482e-06, 'epoch': 0.94}
#  94%|█████████▍| 28350/30000 [4:34:19<13:50,  1.99it/s]
# {'loss': 20.6716, 'grad_norm': 48.25708770751953, 'learning_rate': 3.0851851851851856e-06, 'epoch': 0.94}
#  95%|█████████▍| 28375/30000 [4:34:32<11:56,  2.27it/s]
# {'loss': 17.8792, 'grad_norm': 34.918575286865234, 'learning_rate': 3.038888888888889e-06, 'epoch': 0.95}
#  95%|█████████▍| 28400/30000 [4:34:43<11:17,  2.36it/s]
# {'loss': 16.5813, 'grad_norm': 32.56999206542969, 'learning_rate': 2.9925925925925925e-06, 'epoch': 0.95}
#  95%|█████████▍| 28425/30000 [4:34:56<11:22,  2.31it/s]
# {'loss': 17.9289, 'grad_norm': 40.73421096801758, 'learning_rate': 2.946296296296296e-06, 'epoch': 0.95}
#  95%|█████████▍| 28450/30000 [4:35:08<12:57,  1.99it/s]
# {'loss': 19.604, 'grad_norm': 36.0300407409668, 'learning_rate': 2.9e-06, 'epoch': 0.95}
#  95%|█████████▍| 28475/30000 [4:35:20<12:35,  2.02it/s]
# {'loss': 20.8105, 'grad_norm': 60.077091217041016, 'learning_rate': 2.853703703703704e-06, 'epoch': 0.95}
#  95%|█████████▌| 28500/30000 [4:35:32<10:49,  2.31it/s]
# {'loss': 18.9435, 'grad_norm': 24.545120239257812, 'learning_rate': 2.8074074074074075e-06, 'epoch': 0.95}
#  95%|█████████▌| 28525/30000 [4:35:44<12:18,  2.00it/s]
# {'loss': 17.8083, 'grad_norm': 41.56490707397461, 'learning_rate': 2.761111111111111e-06, 'epoch': 0.95}
#  95%|█████████▌| 28550/30000 [4:35:56<10:50,  2.23it/s]
# {'loss': 15.9834, 'grad_norm': 39.15068054199219, 'learning_rate': 2.7148148148148148e-06, 'epoch': 0.95}
#  95%|█████████▌| 28575/30000 [4:36:08<11:59,  1.98it/s]
# {'loss': 17.0116, 'grad_norm': 25.49711036682129, 'learning_rate': 2.668518518518519e-06, 'epoch': 0.95}
#  95%|█████████▌| 28600/30000 [4:36:21<11:34,  2.01it/s]
# {'loss': 21.2883, 'grad_norm': 64.05098724365234, 'learning_rate': 2.6240740740740745e-06, 'epoch': 0.95}
#  95%|█████████▌| 28612/30000 [4:36:27<10:30,  2.20it/s]'(ProtocolError('Connection aborted.', BrokenPipeError(32, 'Broken pipe')), '(Request ID: 04add555-6630-4e69-bd39-904d4f97eb5d)')' thrown while requesting GET https://huggingface.co/datasets/nguyenvulebinh/AVYT/resolve/e6c6bf6f40e698b82215d269cfc0a0d65a7a2372/vox2/vox2-dev-000006.tar
# Retrying in 1s [Retry 1/5].
#  95%|█████████▌| 28625/30000 [4:36:33<12:01,  1.91it/s]
# {'loss': 16.6968, 'grad_norm': 42.177284240722656, 'learning_rate': 2.5777777777777777e-06, 'epoch': 0.95}
#  96%|█████████▌| 28650/30000 [4:36:46<09:51,  2.28it/s]
# {'loss': 18.2826, 'grad_norm': 51.1025505065918, 'learning_rate': 2.5314814814814814e-06, 'epoch': 0.95}
#  96%|█████████▌| 28675/30000 [4:36:58<11:12,  1.97it/s]
# {'loss': 13.2276, 'grad_norm': 23.910921096801758, 'learning_rate': 2.485185185185185e-06, 'epoch': 0.96}
#  96%|█████████▌| 28700/30000 [4:37:09<10:43,  2.02it/s]
# {'loss': 14.0299, 'grad_norm': 35.1053581237793, 'learning_rate': 2.438888888888889e-06, 'epoch': 0.96}
#  96%|█████████▌| 28725/30000 [4:37:22<11:18,  1.88it/s]
# {'loss': 21.6292, 'grad_norm': 42.184234619140625, 'learning_rate': 2.3925925925925927e-06, 'epoch': 0.96}
#  96%|█████████▌| 28750/30000 [4:37:34<09:11,  2.27it/s]
# {'loss': 20.4304, 'grad_norm': 34.8933219909668, 'learning_rate': 2.3462962962962964e-06, 'epoch': 0.96}
#  96%|█████████▌| 28752/30000 [4:37:35<09:49,  2.12it/s]'(ProtocolError('Connection aborted.', BrokenPipeError(32, 'Broken pipe')), '(Request ID: 53339afa-a226-4a9b-af73-f124fe8f3b13)')' thrown while requesting GET https://huggingface.co/datasets/nguyenvulebinh/AVYT/resolve/e6c6bf6f40e698b82215d269cfc0a0d65a7a2372/vox2/vox2-dev-000005.tar
# Retrying in 1s [Retry 1/5].
#  96%|█████████▌| 28775/30000 [4:37:46<09:10,  2.23it/s]
# {'loss': 22.4924, 'grad_norm': 30.467620849609375, 'learning_rate': 2.3e-06, 'epoch': 0.96}
#  96%|█████████▌| 28800/30000 [4:37:58<08:49,  2.26it/s]
# {'loss': 24.2596, 'grad_norm': 32.9532356262207, 'learning_rate': 2.2537037037037036e-06, 'epoch': 0.96}
#  96%|█████████▌| 28825/30000 [4:38:10<09:35,  2.04it/s]
# {'loss': 21.8301, 'grad_norm': 36.95344924926758, 'learning_rate': 2.2074074074074073e-06, 'epoch': 0.96}
#  96%|█████████▌| 28850/30000 [4:38:22<09:46,  1.96it/s]
# {'loss': 20.9172, 'grad_norm': 35.52144241333008, 'learning_rate': 2.1611111111111114e-06, 'epoch': 0.96}
#  96%|█████████▋| 28875/30000 [4:38:35<09:24,  1.99it/s]
# {'loss': 22.7316, 'grad_norm': 24.254199981689453, 'learning_rate': 2.114814814814815e-06, 'epoch': 0.96}
#  96%|█████████▋| 28900/30000 [4:38:47<09:43,  1.89it/s]
# {'loss': 21.2101, 'grad_norm': 43.43735122680664, 'learning_rate': 2.0685185185185187e-06, 'epoch': 0.96}
#  96%|█████████▋| 28925/30000 [4:38:59<08:37,  2.08it/s]
# {'loss': 21.7539, 'grad_norm': 51.93722152709961, 'learning_rate': 2.0222222222222223e-06, 'epoch': 0.96}
#  96%|█████████▋| 28950/30000 [4:39:10<07:47,  2.25it/s]
# {'loss': 13.9933, 'grad_norm': 34.59150695800781, 'learning_rate': 1.975925925925926e-06, 'epoch': 0.96}
#  97%|█████████▋| 28975/30000 [4:39:23<08:54,  1.92it/s]
# {'loss': 20.8057, 'grad_norm': 46.20816421508789, 'learning_rate': 1.92962962962963e-06, 'epoch': 0.97}
#  97%|█████████▋| 29000/30000 [4:39:35<08:11,  2.04it/s]
# {'loss': 16.7021, 'grad_norm': 42.583980560302734, 'learning_rate': 1.8833333333333334e-06, 'epoch': 0.97}
#  97%|█████████▋| 29025/30000 [4:39:48<08:23,  1.94it/s]
# {'loss': 23.9584, 'grad_norm': 47.828125, 'learning_rate': 1.837037037037037e-06, 'epoch': 0.97}
#  97%|█████████▋| 29050/30000 [4:40:01<08:18,  1.90it/s]
# {'loss': 19.2597, 'grad_norm': 53.22992706298828, 'learning_rate': 1.7907407407407407e-06, 'epoch': 0.97}
#  97%|█████████▋| 29075/30000 [4:40:14<07:28,  2.06it/s]
# {'loss': 22.0427, 'grad_norm': 22.44475555419922, 'learning_rate': 1.7444444444444444e-06, 'epoch': 0.97}
#  97%|█████████▋| 29100/30000 [4:40:27<06:48,  2.20it/s]
# {'loss': 22.7226, 'grad_norm': 22.357852935791016, 'learning_rate': 1.6981481481481484e-06, 'epoch': 0.97}
#  97%|█████████▋| 29125/30000 [4:40:40<08:59,  1.62it/s]
# {'loss': 23.2294, 'grad_norm': 53.86505126953125, 'learning_rate': 1.651851851851852e-06, 'epoch': 0.97}
#  97%|█████████▋| 29150/30000 [4:40:52<06:20,  2.23it/s]
# {'loss': 20.1378, 'grad_norm': 91.98261260986328, 'learning_rate': 1.6055555555555557e-06, 'epoch': 0.97}
#  97%|█████████▋| 29175/30000 [4:41:04<05:49,  2.36it/s]
# {'loss': 15.0334, 'grad_norm': 26.62936019897461, 'learning_rate': 1.5592592592592592e-06, 'epoch': 0.97}
#  97%|█████████▋| 29200/30000 [4:41:17<06:49,  1.95it/s]
# {'loss': 22.3648, 'grad_norm': 31.239818572998047, 'learning_rate': 1.512962962962963e-06, 'epoch': 0.97}
#  97%|█████████▋| 29225/30000 [4:41:28<05:38,  2.29it/s]
# {'loss': 19.1091, 'grad_norm': 42.17718505859375, 'learning_rate': 1.4666666666666667e-06, 'epoch': 0.97}
#  98%|█████████▊| 29250/30000 [4:41:40<05:39,  2.21it/s]
# {'loss': 19.0516, 'grad_norm': 24.672372817993164, 'learning_rate': 1.4203703703703705e-06, 'epoch': 0.97}
#  98%|█████████▊| 29275/30000 [4:41:52<05:09,  2.34it/s]
# {'loss': 16.627, 'grad_norm': 34.102447509765625, 'learning_rate': 1.3740740740740742e-06, 'epoch': 0.98}
#  98%|█████████▊| 29300/30000 [4:42:04<05:48,  2.01it/s]
# {'loss': 22.4665, 'grad_norm': 44.04630661010742, 'learning_rate': 1.3277777777777778e-06, 'epoch': 0.98}
#  98%|█████████▊| 29325/30000 [4:42:16<04:46,  2.35it/s]
# {'loss': 16.8635, 'grad_norm': 47.85992431640625, 'learning_rate': 1.2814814814814817e-06, 'epoch': 0.98}
#  98%|█████████▊| 29350/30000 [4:42:29<04:53,  2.22it/s]
# {'loss': 21.7066, 'grad_norm': 93.58183288574219, 'learning_rate': 1.2351851851851853e-06, 'epoch': 0.98}
#  98%|█████████▊| 29375/30000 [4:42:41<04:12,  2.47it/s]
# {'loss': 19.3995, 'grad_norm': 56.25837326049805, 'learning_rate': 1.188888888888889e-06, 'epoch': 0.98}
#  98%|█████████▊| 29400/30000 [4:42:52<04:15,  2.35it/s]
# {'loss': 19.1771, 'grad_norm': 27.8082275390625, 'learning_rate': 1.1425925925925926e-06, 'epoch': 0.98}
#  98%|█████████▊| 29425/30000 [4:43:05<04:49,  1.99it/s]
# {'loss': 16.8538, 'grad_norm': 33.702457427978516, 'learning_rate': 1.0962962962962963e-06, 'epoch': 0.98}
#  98%|█████████▊| 29450/30000 [4:43:17<04:08,  2.22it/s]
# {'loss': 24.2938, 'grad_norm': 60.97801971435547, 'learning_rate': 1.0500000000000001e-06, 'epoch': 0.98}
#  98%|█████████▊| 29475/30000 [4:43:29<04:20,  2.01it/s]
# {'loss': 18.1812, 'grad_norm': 49.18142318725586, 'learning_rate': 1.0037037037037038e-06, 'epoch': 0.98}
#  98%|█████████▊| 29500/30000 [4:43:41<03:47,  2.19it/s]
# {'loss': 24.137, 'grad_norm': 50.088932037353516, 'learning_rate': 9.574074074074074e-07, 'epoch': 0.98}
#  98%|█████████▊| 29525/30000 [4:43:53<03:24,  2.33it/s]
# {'loss': 23.5973, 'grad_norm': 27.50471305847168, 'learning_rate': 9.111111111111112e-07, 'epoch': 0.98}
#  98%|█████████▊| 29550/30000 [4:44:06<03:46,  1.99it/s]
# {'loss': 17.5811, 'grad_norm': 50.030555725097656, 'learning_rate': 8.648148148148148e-07, 'epoch': 0.98}
#  99%|█████████▊| 29575/30000 [4:44:17<02:53,  2.44it/s]
# {'loss': 16.2084, 'grad_norm': 35.434783935546875, 'learning_rate': 8.185185185185187e-07, 'epoch': 0.99}
#  99%|█████████▊| 29600/30000 [4:44:30<03:25,  1.95it/s]
# {'loss': 21.5474, 'grad_norm': 65.88105010986328, 'learning_rate': 7.722222222222223e-07, 'epoch': 0.99}
#  99%|█████████▉| 29625/30000 [4:44:41<03:08,  1.99it/s]
# {'loss': 20.371, 'grad_norm': 46.471656799316406, 'learning_rate': 7.259259259259259e-07, 'epoch': 0.99}
#  99%|█████████▉| 29650/30000 [4:44:54<02:54,  2.01it/s]
# {'loss': 25.9244, 'grad_norm': 58.42923355102539, 'learning_rate': 6.796296296296296e-07, 'epoch': 0.99}
#  99%|█████████▉| 29675/30000 [4:45:06<02:25,  2.23it/s]
# {'loss': 18.1311, 'grad_norm': 38.1458854675293, 'learning_rate': 6.333333333333333e-07, 'epoch': 0.99}
#  99%|█████████▉| 29700/30000 [4:45:18<02:24,  2.08it/s]
# {'loss': 20.0344, 'grad_norm': 32.802669525146484, 'learning_rate': 5.870370370370371e-07, 'epoch': 0.99}
#  99%|█████████▉| 29725/30000 [4:45:30<01:53,  2.41it/s]
# {'loss': 20.155, 'grad_norm': 30.632627487182617, 'learning_rate': 5.407407407407408e-07, 'epoch': 0.99}
#  99%|█████████▉| 29750/30000 [4:45:43<02:11,  1.91it/s]
# {'loss': 26.6391, 'grad_norm': 134.69117736816406, 'learning_rate': 4.944444444444444e-07, 'epoch': 0.99}
#  99%|█████████▉| 29775/30000 [4:45:55<01:55,  1.96it/s]
# {'loss': 21.9612, 'grad_norm': 48.57712936401367, 'learning_rate': 4.4814814814814813e-07, 'epoch': 0.99}
#  99%|█████████▉| 29800/30000 [4:46:07<01:37,  2.04it/s]
# {'loss': 25.1518, 'grad_norm': 57.82143020629883, 'learning_rate': 4.018518518518519e-07, 'epoch': 0.99}
#  99%|█████████▉| 29825/30000 [4:46:19<01:17,  2.25it/s]
# {'loss': 22.9466, 'grad_norm': 67.0403060913086, 'learning_rate': 3.555555555555556e-07, 'epoch': 0.99}
# 100%|█████████▉| 29850/30000 [4:46:31<01:18,  1.91it/s]
# {'loss': 17.0783, 'grad_norm': 30.277482986450195, 'learning_rate': 3.092592592592593e-07, 'epoch': 0.99}
# 100%|█████████▉| 29875/30000 [4:46:45<01:07,  1.86it/s]
# {'loss': 26.2936, 'grad_norm': 29.67350196838379, 'learning_rate': 2.62962962962963e-07, 'epoch': 1.0}
# 100%|█████████▉| 29900/30000 [4:46:57<00:48,  2.06it/s]
# {'loss': 16.4536, 'grad_norm': 21.441110610961914, 'learning_rate': 2.1666666666666667e-07, 'epoch': 1.0}
# 100%|█████████▉| 29925/30000 [4:47:10<00:38,  1.97it/s]
# {'loss': 20.4643, 'grad_norm': 37.836631774902344, 'learning_rate': 1.703703703703704e-07, 'epoch': 1.0}
# 100%|█████████▉| 29950/30000 [4:47:21<00:24,  2.01it/s]
# {'loss': 23.7461, 'grad_norm': 66.31090545654297, 'learning_rate': 1.240740740740741e-07, 'epoch': 1.0}
# 100%|█████████▉| 29975/30000 [4:47:33<00:12,  1.96it/s]
# {'loss': 17.0543, 'grad_norm': 35.56364059448242, 'learning_rate': 7.777777777777778e-08, 'epoch': 1.0}
# 100%|██████████| 30000/30000 [4:47:45<00:00,  2.31it/s]
# {'loss': 22.8197, 'grad_norm': 49.814903259277344, 'learning_rate': 3.148148148148148e-08, 'epoch': 1.0}
# Too many dataloader workers: 10 (max is dataset.num_shards=3). Stopping 7 dataloader workers.
# 100%|██████████| 30000/30000 [4:50:36<00:00,  2.31it/s]
# {'eval_loss': 27.49915313720703, 'eval_runtime': 170.7197, 'eval_samples_per_second': 22.798, 'eval_steps_per_second': 5.699, 'epoch': 1.0}
# {'train_runtime': 17445.3793, 'train_samples_per_second': 13.757, 'train_steps_per_second': 1.72, 'train_loss': 17.871614496358237, 'epoch': 1.0}
# 100%|██████████| 30000/30000 [4:50:45<00:00,  1.72it/s]
# CompletedProcess(args=['/home/josch080/Projektgruppe/mcorec_train/bin/python', 'script/train.py', '--streaming_dataset', '--include_mcorec', '--batch_size', '4', '--max_steps', '30000', '--gradient_accumulation_steps', '2', '--save_steps', '2000', '--eval_steps', '2000', '--log_interval', '25', '--learning_rate', '5e-5', '--warmup_steps', '3000', '--checkpoint_name', 'avsr_cocktail_mcorec_stage2_lr5e-5_30k', '--model_name_or_path', './model-bin/avsr_cocktail_mcorec_finetune', '--output_dir', './model-bin', '--report_to', 'none'], returncode=0)

# %% [markdown]
# ## 5 – Inference-Setup
#
# Experiment-Utilities neu laden, da oben ggf. CWD geändert wurde.

# %%
import os, sys
import pandas as pd

# Arbeitsverzeichnis auf Repo-Root setzen (Voraussetzung für alle relativen Pfade)
project_baseline_path = "/home/josch080/Projektgruppe/mcorec_baseline"
os.chdir(project_baseline_path)

# Repo-Root in sys.path, damit projektinterne Module importierbar sind
if project_baseline_path not in sys.path:
    sys.path.append(project_baseline_path)

from script.pg_utils_experiments import run_inference_for_experiment, run_eval_and_log, append_eval_results_for_experiments

# %% [markdown]
# ## 6 – Modell-Definitionen
#
# Zwei Modelle im Vergleich: BL4 als Referenz und das neue Stage-2-Modell.
# Der Checkpoint-Pfad zeigt auf den letzten gespeicherten Step (30 000).

# %%
MODELS = {
    # BL4: Referenzmodell aus vorherigen Experimenten
    "cocktail_finetuned": {
        "model_type": "avsr_cocktail",
        "chkpt": "model-bin/avsr_cocktail_mcorec_finetune",
        "out": "output_avsr_cocktail_finetuned",
    },
    # Stage-2-Modell: BL4 + 30k weiterer Trainingsschritte
    "cocktail_stage2": {
        "model_type": "avsr_cocktail",
        "chkpt": "model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000",
        "out": "output_avsr_cocktail_stage2",
    },
}

# %% [markdown]
# ## 7 – Sessions & Experimente
#
# Gleiches 5-Session-Subset wie in `02_`. Drei Experimente testen das Stage-2-Modell
# mit den Baseline-Parametern (E11) und den bisher besten Parametern (E12, E13).

# %%
# Gleiches Dev-Subset wie in 02_ für direkte Vergleichbarkeit
SESSION_IDS = ["session_40", "session_43", "session_49", "session_50", "session_54"]

# %%
EXPERIMENTS = {
    "E11_stage2_bs3_len15": {
        "base_model": "cocktail_stage2",
        "beam_size": 3,
        "max_length": 15,
        "comment": "Stage-2-Modell, beam=3, len=15",
    },
    "E12_stage2_bs12_len20": {
        "base_model": "cocktail_stage2",
        "beam_size": 12,
        "max_length": 20,
        "comment": "Stage-2-Modell, beam=12, len=20 (beste Konfiguration)",
    },
    "E13_stage2_bs8_len20": {
        "base_model": "cocktail_stage2",
        "beam_size": 8,
        "max_length": 20,
        "comment": "Stage-2-Modell, beam=8, len=20",
    },
}

# %% [markdown]
# ## 8 – Inference
#
# 3 Experimente × 5 Sessions = 15 Läufe. Ergebnisse liegen bereits vor.

# %%
for sid in SESSION_IDS:
    session_dir = f"data-bin/dev/{sid}"
    print(f"\n########## Starte Experimente für {sid} ##########")

    for exp_name in EXPERIMENTS:
        run_inference_for_experiment(
            exp_name=exp_name,
            base_models=MODELS,
            experiments=EXPERIMENTS,
            session_dir=session_dir,
        )
# Out:
# ########## Starte Experimente für session_40 ##########
#
# =========================
# Starte Inference für Experiment: E11_stage2_bs3_len15
#   base_model      = cocktail_stage2
#   model_type      = avsr_cocktail
#   checkpoint_path = model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000
#   beam_size       = 3
#   max_length      = 15
#   output_dir_name = output_E11_stage2_bs3_len15
#   session_dir     = data-bin/dev_without_central_videos/dev/session_40
#   comment         = Stage-2-Modell, beam=3, len=15
# Loading avsr_cocktail model...
# Loading model from model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000
# avsr_cocktail model loaded successfully!
# Inferring 1 sessions using avsr_cocktail model
# Processing session session_40
# Processing speakers:   0%|          | 0/6 [00:00<?, ?it/s]
# cessing speaker spk_0 track 1 of 1:   0%|          | 0/35 [00:00<?, ?it/s]
# cessing speaker spk_0 track 1 of 1:   3%|▎         | 1/35 [00:02<01:11,  2.11s/it]
# cessing speaker spk_0 track 1 of 1:   6%|▌         | 2/35 [00:02<00:35,  1.09s/it]
# cessing speaker spk_0 track 1 of 1:   9%|▊         | 3/35 [00:02<00:22,  1.41it/s]
# cessing speaker spk_0 track 1 of 1:  11%|█▏        | 4/35 [00:03<00:17,  1.77it/s]
# cessing speaker spk_0 track 1 of 1:  14%|█▍        | 5/35 [00:03<00:13,  2.15it/s]
# cessing speaker spk_0 track 1 of 1:  17%|█▋        | 6/35 [00:04<00:19,  1.47it/s]
# cessing speaker spk_0 track 1 of 1:  20%|██        | 7/35 [00:07<00:42,  1.53s/it]
# cessing speaker spk_0 track 1 of 1:  23%|██▎       | 8/35 [00:08<00:32,  1.21s/it]
# cessing speaker spk_0 track 1 of 1:  26%|██▌       | 9/35 [00:09<00:32,  1.24s/it]
# cessing speaker spk_0 track 1 of 1:  29%|██▊       | 10/35 [00:10<00:26,  1.07s/it]
# cessing speaker spk_0 track 1 of 1:  31%|███▏      | 11/35 [00:10<00:22,  1.05it/s]
# cessing speaker spk_0 track 1 of 1:  34%|███▍      | 12/35 [00:11<00:18,  1.23it/s]
# cessing speaker spk_0 track 1 of 1:  37%|███▋      | 13/35 [00:13<00:23,  1.08s/it]
# cessing speaker spk_0 track 1 of 1:  40%|████      | 14/35 [00:13<00:18,  1.14it/s]
# cessing speaker spk_0 track 1 of 1:  43%|████▎     | 15/35 [00:14<00:15,  1.31it/s]
# cessing speaker spk_0 track 1 of 1:  46%|████▌     | 16/35 [00:14<00:11,  1.65it/s]
# cessing speaker spk_0 track 1 of 1:  49%|████▊     | 17/35 [00:14<00:10,  1.80it/s]
# cessing speaker spk_0 track 1 of 1:  51%|█████▏    | 18/35 [00:15<00:09,  1.71it/s]
# cessing speaker spk_0 track 1 of 1:  54%|█████▍    | 19/35 [00:16<00:11,  1.41it/s]
# cessing speaker spk_0 track 1 of 1:  57%|█████▋    | 20/35 [00:16<00:09,  1.59it/s]
# cessing speaker spk_0 track 1 of 1:  60%|██████    | 21/35 [00:17<00:09,  1.43it/s]
# cessing speaker spk_0 track 1 of 1:  63%|██████▎   | 22/35 [00:18<00:08,  1.59it/s]
# cessing speaker spk_0 track 1 of 1:  66%|██████▌   | 23/35 [00:18<00:07,  1.67it/s]
# cessing speaker spk_0 track 1 of 1:  69%|██████▊   | 24/35 [00:19<00:06,  1.63it/s]
# cessing speaker spk_0 track 1 of 1:  71%|███████▏  | 25/35 [00:19<00:05,  1.71it/s]
# cessing speaker spk_0 track 1 of 1:  74%|███████▍  | 26/35 [00:21<00:07,  1.13it/s]
# cessing speaker spk_0 track 1 of 1:  77%|███████▋  | 27/35 [00:21<00:06,  1.32it/s]
# cessing speaker spk_0 track 1 of 1:  80%|████████  | 28/35 [00:22<00:05,  1.30it/s]
# cessing speaker spk_0 track 1 of 1:  83%|████████▎ | 29/35 [00:23<00:04,  1.32it/s]
# cessing speaker spk_0 track 1 of 1:  86%|████████▌ | 30/35 [00:25<00:06,  1.28s/it]
# cessing speaker spk_0 track 1 of 1:  89%|████████▊ | 31/35 [00:26<00:04,  1.00s/it]
# cessing speaker spk_0 track 1 of 1:  91%|█████████▏| 32/35 [00:27<00:03,  1.20s/it]
# cessing speaker spk_0 track 1 of 1:  94%|█████████▍| 33/35 [00:32<00:04,  2.16s/it]
# cessing speaker spk_0 track 1 of 1:  97%|█████████▋| 34/35 [00:35<00:02,  2.51s/it]
# Processing speaker spk_0 track 1 of 1: 100%|██████████| 35/35 [00:36<00:00,  1.03s/it]
# Processing speakers:  17%|█▋        | 1/6 [00:36<03:01, 36.24s/it]
# cessing speaker spk_1 track 1 of 1:   0%|          | 0/42 [00:00<?, ?it/s]
# cessing speaker spk_1 track 1 of 1:   2%|▏         | 1/42 [00:01<01:04,  1.58s/it]
# cessing speaker spk_1 track 1 of 1:   5%|▍         | 2/42 [00:02<00:44,  1.11s/it]
# cessing speaker spk_1 track 1 of 1:   7%|▋         | 3/42 [00:03<00:35,  1.10it/s]
# cessing speaker spk_1 track 1 of 1:  10%|▉         | 4/42 [00:03<00:29,  1.29it/s]
# cessing speaker spk_1 track 1 of 1:  12%|█▏        | 5/42 [00:04<00:30,  1.21it/s]
# cessing speaker spk_1 track 1 of 1:  14%|█▍        | 6/42 [00:05<00:28,  1.28it/s]
# cessing speaker spk_1 track 1 of 1:  17%|█▋        | 7/42 [00:05<00:24,  1.45it/s]
# cessing speaker spk_1 track 1 of 1:  19%|█▉        | 8/42 [00:06<00:21,  1.59it/s]
# cessing speaker spk_1 track 1 of 1:  21%|██▏       | 9/42 [00:06<00:18,  1.76it/s]
# cessing speaker spk_1 track 1 of 1:  24%|██▍       | 10/42 [00:07<00:19,  1.63it/s]
# cessing speaker spk_1 track 1 of 1:  26%|██▌       | 11/42 [00:07<00:16,  1.90it/s]
# cessing speaker spk_1 track 1 of 1:  29%|██▊       | 12/42 [00:08<00:17,  1.68it/s]
# cessing speaker spk_1 track 1 of 1:  31%|███       | 13/42 [00:09<00:18,  1.60it/s]
# cessing speaker spk_1 track 1 of 1:  33%|███▎      | 14/42 [00:09<00:17,  1.59it/s]
# cessing speaker spk_1 track 1 of 1:  36%|███▌      | 15/42 [00:10<00:17,  1.56it/s]
# cessing speaker spk_1 track 1 of 1:  38%|███▊      | 16/42 [00:10<00:15,  1.72it/s]
# cessing speaker spk_1 track 1 of 1:  40%|████      | 17/42 [00:13<00:28,  1.13s/it]
# cessing speaker spk_1 track 1 of 1:  43%|████▎     | 18/42 [00:16<00:39,  1.63s/it]
# cessing speaker spk_1 track 1 of 1:  45%|████▌     | 19/42 [00:17<00:32,  1.42s/it]
# cessing speaker spk_1 track 1 of 1:  48%|████▊     | 20/42 [00:17<00:24,  1.14s/it]
# cessing speaker spk_1 track 1 of 1:  50%|█████     | 21/42 [00:18<00:19,  1.06it/s]
# cessing speaker spk_1 track 1 of 1:  52%|█████▏    | 22/42 [00:18<00:17,  1.16it/s]
# cessing speaker spk_1 track 1 of 1:  55%|█████▍    | 23/42 [00:20<00:19,  1.01s/it]
# cessing speaker spk_1 track 1 of 1:  57%|█████▋    | 24/42 [00:23<00:30,  1.68s/it]
# cessing speaker spk_1 track 1 of 1:  60%|█████▉    | 25/42 [00:26<00:35,  2.07s/it]
# cessing speaker spk_1 track 1 of 1:  62%|██████▏   | 26/42 [00:27<00:31,  1.96s/it]
# cessing speaker spk_1 track 1 of 1:  64%|██████▍   | 27/42 [00:32<00:43,  2.87s/it]
# cessing speaker spk_1 track 1 of 1:  67%|██████▋   | 28/42 [00:34<00:32,  2.34s/it]
# cessing speaker spk_1 track 1 of 1:  69%|██████▉   | 29/42 [00:38<00:40,  3.10s/it]
# cessing speaker spk_1 track 1 of 1:  71%|███████▏  | 30/42 [00:44<00:44,  3.72s/it]
# cessing speaker spk_1 track 1 of 1:  74%|███████▍  | 31/42 [00:50<00:49,  4.46s/it]
# cessing speaker spk_1 track 1 of 1:  76%|███████▌  | 32/42 [00:51<00:36,  3.61s/it]
# cessing speaker spk_1 track 1 of 1:  79%|███████▊  | 33/42 [00:52<00:25,  2.85s/it]
# cessing speaker spk_1 track 1 of 1:  81%|████████  | 34/42 [00:54<00:20,  2.53s/it]
# cessing speaker spk_1 track 1 of 1:  83%|████████▎ | 35/42 [00:55<00:13,  1.98s/it]
# cessing speaker spk_1 track 1 of 1:  86%|████████▌ | 36/42 [00:59<00:15,  2.59s/it]
# cessing speaker spk_1 track 1 of 1:  88%|████████▊ | 37/42 [01:00<00:11,  2.27s/it]
# cessing speaker spk_1 track 1 of 1:  90%|█████████ | 38/42 [01:01<00:07,  1.82s/it]
# cessing speaker spk_1 track 1 of 1:  93%|█████████▎| 39/42 [01:02<00:04,  1.47s/it]
# cessing speaker spk_1 track 1 of 1:  95%|█████████▌| 40/42 [01:06<00:04,  2.41s/it]
# cessing speaker spk_1 track 1 of 1:  98%|█████████▊| 41/42 [01:10<00:02,  2.79s/it]
# Processing speaker spk_1 track 1 of 1: 100%|██████████| 42/42 [01:12<00:00,  1.72s/it]
# Processing speakers:  33%|███▎      | 2/6 [01:48<03:49, 57.31s/it]
# Processing speaker spk_2 track 1 of 3: 0it [00:00, ?it/s]
#
# cessing speaker spk_2 track 2 of 3:   0%|          | 0/14 [00:00<?, ?it/s]
# cessing speaker spk_2 track 2 of 3:   7%|▋         | 1/14 [00:00<00:06,  2.01it/s]
# cessing speaker spk_2 track 2 of 3:  14%|█▍        | 2/14 [00:01<00:09,  1.30it/s]
# cessing speaker spk_2 track 2 of 3:  21%|██▏       | 3/14 [00:02<00:11,  1.01s/it]
# cessing speaker spk_2 track 2 of 3:  29%|██▊       | 4/14 [00:06<00:22,  2.26s/it]
# cessing speaker spk_2 track 2 of 3:  36%|███▌      | 5/14 [00:07<00:15,  1.76s/it]
# cessing speaker spk_2 track 2 of 3:  43%|████▎     | 6/14 [00:10<00:16,  2.05s/it]
# cessing speaker spk_2 track 2 of 3:  50%|█████     | 7/14 [00:14<00:18,  2.66s/it]
# cessing speaker spk_2 track 2 of 3:  57%|█████▋    | 8/14 [00:22<00:26,  4.34s/it]
# cessing speaker spk_2 track 2 of 3:  64%|██████▍   | 9/14 [00:23<00:16,  3.23s/it]
# cessing speaker spk_2 track 2 of 3:  71%|███████▏  | 10/14 [00:27<00:14,  3.74s/it]
# cessing speaker spk_2 track 2 of 3:  79%|███████▊  | 11/14 [00:31<00:11,  3.67s/it]
# cessing speaker spk_2 track 2 of 3:  86%|████████▌ | 12/14 [00:35<00:07,  3.75s/it]
# cessing speaker spk_2 track 2 of 3:  93%|█████████▎| 13/14 [00:38<00:03,  3.51s/it]
# Processing speaker spk_2 track 2 of 3: 100%|██████████| 14/14 [00:38<00:00,  2.78s/it]
#
# cessing speaker spk_2 track 3 of 3:   0%|          | 0/13 [00:00<?, ?it/s]
# cessing speaker spk_2 track 3 of 3:   8%|▊         | 1/13 [00:00<00:11,  1.07it/s]
# cessing speaker spk_2 track 3 of 3:  15%|█▌        | 2/13 [00:01<00:09,  1.18it/s]
# cessing speaker spk_2 track 3 of 3:  23%|██▎       | 3/13 [00:06<00:27,  2.74s/it]
# cessing speaker spk_2 track 3 of 3:  31%|███       | 4/13 [00:11<00:31,  3.55s/it]
# cessing speaker spk_2 track 3 of 3:  38%|███▊      | 5/13 [00:15<00:28,  3.61s/it]
# cessing speaker spk_2 track 3 of 3:  46%|████▌     | 6/13 [00:18<00:25,  3.66s/it]
# cessing speaker spk_2 track 3 of 3:  54%|█████▍    | 7/13 [00:20<00:17,  2.84s/it]
# cessing speaker spk_2 track 3 of 3:  62%|██████▏   | 8/13 [00:23<00:15,  3.12s/it]
# cessing speaker spk_2 track 3 of 3:  69%|██████▉   | 9/13 [00:25<00:10,  2.54s/it]
# cessing speaker spk_2 track 3 of 3:  77%|███████▋  | 10/13 [00:26<00:06,  2.20s/it]
# cessing speaker spk_2 track 3 of 3:  85%|████████▍ | 11/13 [00:30<00:05,  2.71s/it]
# cessing speaker spk_2 track 3 of 3:  92%|█████████▏| 12/13 [00:31<00:02,  2.13s/it]
# Processing speaker spk_2 track 3 of 3: 100%|██████████| 13/13 [00:32<00:00,  2.51s/it]
# Processing speakers:  50%|█████     | 3/6 [02:59<03:11, 63.84s/it]
# cessing speaker spk_3 track 1 of 2:   0%|          | 0/18 [00:00<?, ?it/s]
# cessing speaker spk_3 track 1 of 2:   6%|▌         | 1/18 [00:00<00:11,  1.45it/s]
# cessing speaker spk_3 track 1 of 2:  11%|█         | 2/18 [00:01<00:08,  1.78it/s]
# cessing speaker spk_3 track 1 of 2:  17%|█▋        | 3/18 [00:05<00:35,  2.38s/it]
# cessing speaker spk_3 track 1 of 2:  22%|██▏       | 4/18 [00:07<00:30,  2.17s/it]
# cessing speaker spk_3 track 1 of 2:  28%|██▊       | 5/18 [00:11<00:36,  2.82s/it]
# cessing speaker spk_3 track 1 of 2:  33%|███▎      | 6/18 [00:12<00:25,  2.16s/it]
# cessing speaker spk_3 track 1 of 2:  39%|███▉      | 7/18 [00:16<00:30,  2.74s/it]
# cessing speaker spk_3 track 1 of 2:  44%|████▍     | 8/18 [00:18<00:26,  2.69s/it]
# cessing speaker spk_3 track 1 of 2:  50%|█████     | 9/18 [00:22<00:26,  2.90s/it]
# cessing speaker spk_3 track 1 of 2:  56%|█████▌    | 10/18 [00:22<00:17,  2.21s/it]
# cessing speaker spk_3 track 1 of 2:  61%|██████    | 11/18 [00:23<00:12,  1.78s/it]
# cessing speaker spk_3 track 1 of 2:  67%|██████▋   | 12/18 [00:24<00:09,  1.54s/it]
# cessing speaker spk_3 track 1 of 2:  72%|███████▏  | 13/18 [00:28<00:11,  2.22s/it]
# cessing speaker spk_3 track 1 of 2:  78%|███████▊  | 14/18 [00:31<00:10,  2.53s/it]
# cessing speaker spk_3 track 1 of 2:  83%|████████▎ | 15/18 [00:34<00:08,  2.69s/it]
# cessing speaker spk_3 track 1 of 2:  89%|████████▉ | 16/18 [00:35<00:04,  2.14s/it]
# cessing speaker spk_3 track 1 of 2:  94%|█████████▍| 17/18 [00:37<00:01,  1.98s/it]
# Processing speaker spk_3 track 1 of 2: 100%|██████████| 18/18 [00:38<00:00,  2.12s/it]
#
# cessing speaker spk_3 track 2 of 2:   0%|          | 0/14 [00:00<?, ?it/s]
# cessing speaker spk_3 track 2 of 2:   7%|▋         | 1/14 [00:02<00:32,  2.48s/it]
# cessing speaker spk_3 track 2 of 2:  14%|█▍        | 2/14 [00:04<00:23,  1.95s/it]
# cessing speaker spk_3 track 2 of 2:  21%|██▏       | 3/14 [00:04<00:14,  1.32s/it]
# cessing speaker spk_3 track 2 of 2:  29%|██▊       | 4/14 [00:04<00:09,  1.08it/s]
# cessing speaker spk_3 track 2 of 2:  36%|███▌      | 5/14 [00:05<00:07,  1.24it/s]
# cessing speaker spk_3 track 2 of 2:  43%|████▎     | 6/14 [00:06<00:06,  1.19it/s]
# cessing speaker spk_3 track 2 of 2:  50%|█████     | 7/14 [00:10<00:13,  1.89s/it]
# cessing speaker spk_3 track 2 of 2:  57%|█████▋    | 8/14 [00:11<00:10,  1.67s/it]
# cessing speaker spk_3 track 2 of 2:  64%|██████▍   | 9/14 [00:12<00:06,  1.29s/it]
# cessing speaker spk_3 track 2 of 2:  71%|███████▏  | 10/14 [00:12<00:04,  1.06s/it]
# cessing speaker spk_3 track 2 of 2:  79%|███████▊  | 11/14 [00:13<00:02,  1.12it/s]
# cessing speaker spk_3 track 2 of 2:  86%|████████▌ | 12/14 [00:19<00:04,  2.41s/it]
# cessing speaker spk_3 track 2 of 2:  93%|█████████▎| 13/14 [00:20<00:02,  2.16s/it]
# Processing speaker spk_3 track 2 of 2: 100%|██████████| 14/14 [00:21<00:00,  1.52s/it]
# Processing speakers:  67%|██████▋   | 4/6 [03:59<02:04, 62.10s/it]
# cessing speaker spk_4 track 1 of 1:   0%|          | 0/29 [00:00<?, ?it/s]
# cessing speaker spk_4 track 1 of 1:   3%|▎         | 1/29 [00:02<01:00,  2.18s/it]
# cessing speaker spk_4 track 1 of 1:   7%|▋         | 2/29 [00:03<00:38,  1.44s/it]
# cessing speaker spk_4 track 1 of 1:  10%|█         | 3/29 [00:06<00:56,  2.16s/it]
# cessing speaker spk_4 track 1 of 1:  14%|█▍        | 4/29 [00:08<00:55,  2.23s/it]
# cessing speaker spk_4 track 1 of 1:  17%|█▋        | 5/29 [00:12<01:08,  2.84s/it]
# cessing speaker spk_4 track 1 of 1:  21%|██        | 6/29 [00:15<01:08,  2.98s/it]
# cessing speaker spk_4 track 1 of 1:  24%|██▍       | 7/29 [00:17<00:59,  2.70s/it]
# cessing speaker spk_4 track 1 of 1:  28%|██▊       | 8/29 [00:19<00:51,  2.47s/it]
# cessing speaker spk_4 track 1 of 1:  31%|███       | 9/29 [00:21<00:44,  2.23s/it]
# cessing speaker spk_4 track 1 of 1:  34%|███▍      | 10/29 [00:23<00:41,  2.18s/it]
# cessing speaker spk_4 track 1 of 1:  38%|███▊      | 11/29 [00:25<00:39,  2.17s/it]
# cessing speaker spk_4 track 1 of 1:  41%|████▏     | 12/29 [00:27<00:35,  2.08s/it]
# cessing speaker spk_4 track 1 of 1:  45%|████▍     | 13/29 [00:29<00:32,  2.01s/it]
# cessing speaker spk_4 track 1 of 1:  48%|████▊     | 14/29 [00:30<00:25,  1.70s/it]
# cessing speaker spk_4 track 1 of 1:  52%|█████▏    | 15/29 [00:30<00:18,  1.32s/it]
# cessing speaker spk_4 track 1 of 1:  55%|█████▌    | 16/29 [00:31<00:14,  1.10s/it]
# cessing speaker spk_4 track 1 of 1:  59%|█████▊    | 17/29 [00:34<00:18,  1.56s/it]
# cessing speaker spk_4 track 1 of 1:  62%|██████▏   | 18/29 [00:35<00:15,  1.44s/it]
# cessing speaker spk_4 track 1 of 1:  66%|██████▌   | 19/29 [00:36<00:12,  1.29s/it]
# cessing speaker spk_4 track 1 of 1:  69%|██████▉   | 20/29 [00:37<00:12,  1.43s/it]
# cessing speaker spk_4 track 1 of 1:  72%|███████▏  | 21/29 [00:40<00:14,  1.86s/it]
# cessing speaker spk_4 track 1 of 1:  76%|███████▌  | 22/29 [00:41<00:10,  1.48s/it]
# cessing speaker spk_4 track 1 of 1:  79%|███████▉  | 23/29 [00:42<00:08,  1.50s/it]
# cessing speaker spk_4 track 1 of 1:  83%|████████▎ | 24/29 [00:43<00:06,  1.25s/it]
# cessing speaker spk_4 track 1 of 1:  86%|████████▌ | 25/29 [00:44<00:04,  1.06s/it]
# cessing speaker spk_4 track 1 of 1:  90%|████████▉ | 26/29 [00:44<00:02,  1.11it/s]
# cessing speaker spk_4 track 1 of 1:  93%|█████████▎| 27/29 [00:45<00:01,  1.20it/s]
# cessing speaker spk_4 track 1 of 1:  97%|█████████▋| 28/29 [00:47<00:01,  1.36s/it]
# Processing speaker spk_4 track 1 of 1: 100%|██████████| 29/29 [00:50<00:00,  1.73s/it]
# Processing speakers:  83%|████████▎ | 5/6 [04:49<00:57, 57.79s/it]
# cessing speaker spk_5 track 1 of 1:   0%|          | 0/33 [00:00<?, ?it/s]
# cessing speaker spk_5 track 1 of 1:   3%|▎         | 1/33 [00:00<00:27,  1.15it/s]
# cessing speaker spk_5 track 1 of 1:   6%|▌         | 2/33 [00:04<01:09,  2.25s/it]
# cessing speaker spk_5 track 1 of 1:   9%|▉         | 3/33 [00:05<00:55,  1.87s/it]
# cessing speaker spk_5 track 1 of 1:  12%|█▏        | 4/33 [00:08<01:02,  2.17s/it]
# cessing speaker spk_5 track 1 of 1:  15%|█▌        | 5/33 [00:08<00:45,  1.64s/it]
# cessing speaker spk_5 track 1 of 1:  18%|█▊        | 6/33 [00:10<00:48,  1.79s/it]
# cessing speaker spk_5 track 1 of 1:  21%|██        | 7/33 [00:11<00:39,  1.50s/it]
# cessing speaker spk_5 track 1 of 1:  24%|██▍       | 8/33 [00:13<00:36,  1.47s/it]
# cessing speaker spk_5 track 1 of 1:  27%|██▋       | 9/33 [00:14<00:36,  1.53s/it]
# cessing speaker spk_5 track 1 of 1:  30%|███       | 10/33 [00:16<00:38,  1.68s/it]
# cessing speaker spk_5 track 1 of 1:  33%|███▎      | 11/33 [00:19<00:44,  2.03s/it]
# cessing speaker spk_5 track 1 of 1:  36%|███▋      | 12/33 [00:22<00:46,  2.22s/it]
# cessing speaker spk_5 track 1 of 1:  39%|███▉      | 13/33 [00:24<00:44,  2.24s/it]
# cessing speaker spk_5 track 1 of 1:  42%|████▏     | 14/33 [00:26<00:40,  2.13s/it]
# cessing speaker spk_5 track 1 of 1:  45%|████▌     | 15/33 [00:27<00:30,  1.69s/it]
# cessing speaker spk_5 track 1 of 1:  48%|████▊     | 16/33 [00:27<00:23,  1.40s/it]
# cessing speaker spk_5 track 1 of 1:  52%|█████▏    | 17/33 [00:29<00:22,  1.43s/it]
# cessing speaker spk_5 track 1 of 1:  55%|█████▍    | 18/33 [00:31<00:22,  1.49s/it]
# cessing speaker spk_5 track 1 of 1:  58%|█████▊    | 19/33 [00:32<00:19,  1.39s/it]
# cessing speaker spk_5 track 1 of 1:  61%|██████    | 20/33 [00:32<00:14,  1.13s/it]
# cessing speaker spk_5 track 1 of 1:  64%|██████▎   | 21/33 [00:33<00:12,  1.08s/it]
# cessing speaker spk_5 track 1 of 1:  67%|██████▋   | 22/33 [00:39<00:27,  2.47s/it]
# cessing speaker spk_5 track 1 of 1:  70%|██████▉   | 23/33 [00:44<00:32,  3.21s/it]
# cessing speaker spk_5 track 1 of 1:  73%|███████▎  | 24/33 [00:48<00:30,  3.44s/it]
# cessing speaker spk_5 track 1 of 1:  76%|███████▌  | 25/33 [00:49<00:21,  2.65s/it]
# cessing speaker spk_5 track 1 of 1:  79%|███████▉  | 26/33 [00:49<00:13,  2.00s/it]
# cessing speaker spk_5 track 1 of 1:  82%|████████▏ | 27/33 [00:52<00:13,  2.20s/it]
# cessing speaker spk_5 track 1 of 1:  85%|████████▍ | 28/33 [00:53<00:08,  1.79s/it]
# cessing speaker spk_5 track 1 of 1:  88%|████████▊ | 29/33 [00:53<00:05,  1.48s/it]
# cessing speaker spk_5 track 1 of 1:  91%|█████████ | 30/33 [00:57<00:06,  2.23s/it]
# cessing speaker spk_5 track 1 of 1:  94%|█████████▍| 31/33 [01:00<00:04,  2.27s/it]
# cessing speaker spk_5 track 1 of 1:  97%|█████████▋| 32/33 [01:00<00:01,  1.79s/it]
# Processing speaker spk_5 track 1 of 1: 100%|██████████| 33/33 [01:02<00:00,  1.89s/it]
# Processing speakers: 100%|██████████| 6/6 [05:51<00:00, 58.63s/it]
# =========================
# Starte Inference für Experiment: E12_stage2_bs12_len20
#   base_model      = cocktail_stage2
#   model_type      = avsr_cocktail
#   checkpoint_path = model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000
#   beam_size       = 12
#   max_length      = 20
#   output_dir_name = output_E12_stage2_bs12_len20
#   session_dir     = data-bin/dev_without_central_videos/dev/session_40
#   comment         = Stage-2-Modell, beam=12, len=20 (beste Konfiguration)
# Loading avsr_cocktail model...
# Loading model from model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000
# avsr_cocktail model loaded successfully!
# Inferring 1 sessions using avsr_cocktail model
# Processing session session_40
# Processing speakers:   0%|          | 0/6 [00:00<?, ?it/s]
# cessing speaker spk_0 track 1 of 1:   0%|          | 0/35 [00:00<?, ?it/s]
# cessing speaker spk_0 track 1 of 1:   3%|▎         | 1/35 [00:00<00:24,  1.42it/s]
# cessing speaker spk_0 track 1 of 1:   6%|▌         | 2/35 [00:01<00:19,  1.71it/s]
# cessing speaker spk_0 track 1 of 1:   9%|▊         | 3/35 [00:01<00:20,  1.54it/s]
# cessing speaker spk_0 track 1 of 1:  11%|█▏        | 4/35 [00:02<00:18,  1.72it/s]
# cessing speaker spk_0 track 1 of 1:  14%|█▍        | 5/35 [00:02<00:16,  1.84it/s]
# cessing speaker spk_0 track 1 of 1:  17%|█▋        | 6/35 [00:04<00:23,  1.24it/s]
# cessing speaker spk_0 track 1 of 1:  20%|██        | 7/35 [00:08<00:55,  2.00s/it]
# cessing speaker spk_0 track 1 of 1:  23%|██▎       | 8/35 [00:09<00:44,  1.66s/it]
# cessing speaker spk_0 track 1 of 1:  26%|██▌       | 9/35 [00:11<00:42,  1.64s/it]
# cessing speaker spk_0 track 1 of 1:  29%|██▊       | 10/35 [00:12<00:35,  1.41s/it]
# cessing speaker spk_0 track 1 of 1:  31%|███▏      | 11/35 [00:12<00:29,  1.24s/it]
# cessing speaker spk_0 track 1 of 1:  34%|███▍      | 12/35 [00:13<00:23,  1.04s/it]
# cessing speaker spk_0 track 1 of 1:  37%|███▋      | 13/35 [00:15<00:30,  1.41s/it]
# cessing speaker spk_0 track 1 of 1:  40%|████      | 14/35 [00:16<00:25,  1.23s/it]
# cessing speaker spk_0 track 1 of 1:  43%|████▎     | 15/35 [00:17<00:21,  1.05s/it]
# cessing speaker spk_0 track 1 of 1:  46%|████▌     | 16/35 [00:17<00:16,  1.12it/s]
# cessing speaker spk_0 track 1 of 1:  49%|████▊     | 17/35 [00:18<00:15,  1.18it/s]
# cessing speaker spk_0 track 1 of 1:  51%|█████▏    | 18/35 [00:19<00:15,  1.09it/s]
# cessing speaker spk_0 track 1 of 1:  54%|█████▍    | 19/35 [00:20<00:16,  1.02s/it]
# cessing speaker spk_0 track 1 of 1:  57%|█████▋    | 20/35 [00:21<00:13,  1.11it/s]
# cessing speaker spk_0 track 1 of 1:  60%|██████    | 21/35 [00:22<00:13,  1.05it/s]
# cessing speaker spk_0 track 1 of 1:  63%|██████▎   | 22/35 [00:23<00:10,  1.21it/s]
# cessing speaker spk_0 track 1 of 1:  66%|██████▌   | 23/35 [00:23<00:10,  1.17it/s]
# cessing speaker spk_0 track 1 of 1:  69%|██████▊   | 24/35 [00:24<00:09,  1.20it/s]
# cessing speaker spk_0 track 1 of 1:  71%|███████▏  | 25/35 [00:25<00:08,  1.24it/s]
# cessing speaker spk_0 track 1 of 1:  74%|███████▍  | 26/35 [00:27<00:10,  1.17s/it]
# cessing speaker spk_0 track 1 of 1:  77%|███████▋  | 27/35 [00:28<00:08,  1.02s/it]
# cessing speaker spk_0 track 1 of 1:  80%|████████  | 28/35 [00:29<00:06,  1.02it/s]
# cessing speaker spk_0 track 1 of 1:  83%|████████▎ | 29/35 [00:29<00:05,  1.04it/s]
# cessing speaker spk_0 track 1 of 1:  86%|████████▌ | 30/35 [00:33<00:08,  1.68s/it]
# cessing speaker spk_0 track 1 of 1:  89%|████████▊ | 31/35 [00:34<00:05,  1.43s/it]
# cessing speaker spk_0 track 1 of 1:  91%|█████████▏| 32/35 [00:36<00:04,  1.64s/it]
# cessing speaker spk_0 track 1 of 1:  94%|█████████▍| 33/35 [00:40<00:05,  2.54s/it]
# cessing speaker spk_0 track 1 of 1:  97%|█████████▋| 34/35 [00:45<00:03,  3.05s/it]
# Processing speaker spk_0 track 1 of 1: 100%|██████████| 35/35 [00:46<00:00,  1.32s/it]
# Processing speakers:  17%|█▋        | 1/6 [00:46<03:50, 46.08s/it]
# cessing speaker spk_1 track 1 of 1:   0%|          | 0/40 [00:00<?, ?it/s]
# cessing speaker spk_1 track 1 of 1:   2%|▎         | 1/40 [00:00<00:25,  1.52it/s]
# cessing speaker spk_1 track 1 of 1:   5%|▌         | 2/40 [00:01<00:35,  1.07it/s]
# cessing speaker spk_1 track 1 of 1:   8%|▊         | 3/40 [00:02<00:33,  1.09it/s]
# cessing speaker spk_1 track 1 of 1:  10%|█         | 4/40 [00:03<00:27,  1.31it/s]
# cessing speaker spk_1 track 1 of 1:  12%|█▎        | 5/40 [00:04<00:32,  1.08it/s]
# cessing speaker spk_1 track 1 of 1:  15%|█▌        | 6/40 [00:05<00:30,  1.10it/s]
# cessing speaker spk_1 track 1 of 1:  18%|█▊        | 7/40 [00:05<00:26,  1.24it/s]
# cessing speaker spk_1 track 1 of 1:  20%|██        | 8/40 [00:06<00:25,  1.26it/s]
# cessing speaker spk_1 track 1 of 1:  22%|██▎       | 9/40 [00:07<00:23,  1.35it/s]
# cessing speaker spk_1 track 1 of 1:  25%|██▌       | 10/40 [00:08<00:24,  1.22it/s]
# cessing speaker spk_1 track 1 of 1:  28%|██▊       | 11/40 [00:08<00:21,  1.34it/s]
# cessing speaker spk_1 track 1 of 1:  30%|███       | 12/40 [00:09<00:23,  1.20it/s]
# cessing speaker spk_1 track 1 of 1:  32%|███▎      | 13/40 [00:10<00:22,  1.18it/s]
# cessing speaker spk_1 track 1 of 1:  35%|███▌      | 14/40 [00:11<00:21,  1.19it/s]
# cessing speaker spk_1 track 1 of 1:  38%|███▊      | 15/40 [00:12<00:20,  1.22it/s]
# cessing speaker spk_1 track 1 of 1:  40%|████      | 16/40 [00:13<00:18,  1.27it/s]
# cessing speaker spk_1 track 1 of 1:  42%|████▎     | 17/40 [00:22<01:16,  3.32s/it]
# cessing speaker spk_1 track 1 of 1:  45%|████▌     | 18/40 [00:23<01:00,  2.76s/it]
# cessing speaker spk_1 track 1 of 1:  48%|████▊     | 19/40 [00:24<00:45,  2.16s/it]
# cessing speaker spk_1 track 1 of 1:  50%|█████     | 20/40 [00:25<00:35,  1.77s/it]
# cessing speaker spk_1 track 1 of 1:  52%|█████▎    | 21/40 [00:26<00:28,  1.49s/it]
# cessing speaker spk_1 track 1 of 1:  55%|█████▌    | 22/40 [00:27<00:27,  1.51s/it]
# cessing speaker spk_1 track 1 of 1:  57%|█████▊    | 23/40 [00:38<01:12,  4.28s/it]
# cessing speaker spk_1 track 1 of 1:  60%|██████    | 24/40 [00:40<00:57,  3.62s/it]
# cessing speaker spk_1 track 1 of 1:  62%|██████▎   | 25/40 [00:47<01:07,  4.48s/it]
# cessing speaker spk_1 track 1 of 1:  65%|██████▌   | 26/40 [00:48<00:48,  3.50s/it]
# cessing speaker spk_1 track 1 of 1:  68%|██████▊   | 27/40 [00:54<00:55,  4.30s/it]
# cessing speaker spk_1 track 1 of 1:  70%|███████   | 28/40 [01:00<00:58,  4.89s/it]
# cessing speaker spk_1 track 1 of 1:  72%|███████▎  | 29/40 [01:07<01:01,  5.60s/it]
# cessing speaker spk_1 track 1 of 1:  75%|███████▌  | 30/40 [01:10<00:45,  4.56s/it]
# cessing speaker spk_1 track 1 of 1:  78%|███████▊  | 31/40 [01:11<00:32,  3.56s/it]
# cessing speaker spk_1 track 1 of 1:  80%|████████  | 32/40 [01:13<00:24,  3.06s/it]
# cessing speaker spk_1 track 1 of 1:  82%|████████▎ | 33/40 [01:14<00:17,  2.48s/it]
# cessing speaker spk_1 track 1 of 1:  85%|████████▌ | 34/40 [01:19<00:18,  3.14s/it]
# cessing speaker spk_1 track 1 of 1:  88%|████████▊ | 35/40 [01:21<00:13,  2.80s/it]
# cessing speaker spk_1 track 1 of 1:  90%|█████████ | 36/40 [01:21<00:08,  2.22s/it]
# cessing speaker spk_1 track 1 of 1:  92%|█████████▎| 37/40 [01:22<00:05,  1.79s/it]
# cessing speaker spk_1 track 1 of 1:  95%|█████████▌| 38/40 [01:28<00:05,  2.85s/it]
# cessing speaker spk_1 track 1 of 1:  98%|█████████▊| 39/40 [01:32<00:03,  3.27s/it]
# Processing speaker spk_1 track 1 of 1: 100%|██████████| 40/40 [01:34<00:00,  2.36s/it]
# Processing speakers:  33%|███▎      | 2/6 [02:20<04:58, 74.56s/it]
# Processing speaker spk_2 track 1 of 3: 0it [00:00, ?it/s]
#
# cessing speaker spk_2 track 2 of 3:   0%|          | 0/13 [00:00<?, ?it/s]
# cessing speaker spk_2 track 2 of 3:   8%|▊         | 1/13 [00:00<00:07,  1.58it/s]
# cessing speaker spk_2 track 2 of 3:  15%|█▌        | 2/13 [00:01<00:11,  1.04s/it]
# cessing speaker spk_2 track 2 of 3:  23%|██▎       | 3/13 [00:03<00:12,  1.30s/it]
# cessing speaker spk_2 track 2 of 3:  31%|███       | 4/13 [00:08<00:25,  2.88s/it]
# cessing speaker spk_2 track 2 of 3:  38%|███▊      | 5/13 [00:09<00:17,  2.24s/it]
# cessing speaker spk_2 track 2 of 3:  46%|████▌     | 6/13 [00:13<00:19,  2.77s/it]
# cessing speaker spk_2 track 2 of 3:  54%|█████▍    | 7/13 [00:18<00:20,  3.45s/it]
# cessing speaker spk_2 track 2 of 3:  62%|██████▏   | 8/13 [00:24<00:21,  4.38s/it]
# cessing speaker spk_2 track 2 of 3:  69%|██████▉   | 9/13 [00:26<00:13,  3.36s/it]
# cessing speaker spk_2 track 2 of 3:  77%|███████▋  | 10/13 [00:31<00:12,  4.11s/it]
# cessing speaker spk_2 track 2 of 3:  85%|████████▍ | 11/13 [00:37<00:09,  4.71s/it]
# cessing speaker spk_2 track 2 of 3:  92%|█████████▏| 12/13 [00:50<00:07,  7.12s/it]
# Processing speaker spk_2 track 2 of 3: 100%|██████████| 13/13 [00:51<00:00,  3.98s/it]
#
# cessing speaker spk_2 track 3 of 3:   0%|          | 0/12 [00:00<?, ?it/s]
# cessing speaker spk_2 track 3 of 3:   8%|▊         | 1/12 [00:01<00:11,  1.07s/it]
# cessing speaker spk_2 track 3 of 3:  17%|█▋        | 2/12 [00:02<00:11,  1.17s/it]
# cessing speaker spk_2 track 3 of 3:  25%|██▌       | 3/12 [00:14<00:55,  6.15s/it]
# cessing speaker spk_2 track 3 of 3:  33%|███▎      | 4/12 [00:25<01:05,  8.16s/it]
# cessing speaker spk_2 track 3 of 3:  42%|████▏     | 5/12 [00:31<00:50,  7.16s/it]
# cessing speaker spk_2 track 3 of 3:  50%|█████     | 6/12 [00:32<00:31,  5.22s/it]
# cessing speaker spk_2 track 3 of 3:  58%|█████▊    | 7/12 [00:36<00:24,  4.95s/it]
# cessing speaker spk_2 track 3 of 3:  67%|██████▋   | 8/12 [00:38<00:16,  4.01s/it]
# cessing speaker spk_2 track 3 of 3:  75%|███████▌  | 9/12 [00:40<00:09,  3.25s/it]
# cessing speaker spk_2 track 3 of 3:  83%|████████▎ | 10/12 [00:45<00:07,  3.74s/it]
# cessing speaker spk_2 track 3 of 3:  92%|█████████▏| 11/12 [00:46<00:02,  2.97s/it]
# Processing speaker spk_2 track 3 of 3: 100%|██████████| 12/12 [00:47<00:00,  3.98s/it]
# Processing speakers:  50%|█████     | 3/6 [04:00<04:18, 86.01s/it]
# cessing speaker spk_3 track 1 of 2:   0%|          | 0/18 [00:00<?, ?it/s]
# cessing speaker spk_3 track 1 of 2:   6%|▌         | 1/18 [00:00<00:11,  1.45it/s]
# cessing speaker spk_3 track 1 of 2:  11%|█         | 2/18 [00:01<00:12,  1.33it/s]
# cessing speaker spk_3 track 1 of 2:  17%|█▋        | 3/18 [00:07<00:46,  3.12s/it]
# cessing speaker spk_3 track 1 of 2:  22%|██▏       | 4/18 [00:09<00:38,  2.77s/it]
# cessing speaker spk_3 track 1 of 2:  28%|██▊       | 5/18 [00:14<00:46,  3.55s/it]
# cessing speaker spk_3 track 1 of 2:  33%|███▎      | 6/18 [00:15<00:33,  2.80s/it]
# cessing speaker spk_3 track 1 of 2:  39%|███▉      | 7/18 [00:20<00:38,  3.47s/it]
# cessing speaker spk_3 track 1 of 2:  44%|████▍     | 8/18 [00:23<00:33,  3.35s/it]
# cessing speaker spk_3 track 1 of 2:  50%|█████     | 9/18 [00:27<00:31,  3.50s/it]
# cessing speaker spk_3 track 1 of 2:  56%|█████▌    | 10/18 [00:28<00:21,  2.73s/it]
# cessing speaker spk_3 track 1 of 2:  61%|██████    | 11/18 [00:29<00:15,  2.21s/it]
# cessing speaker spk_3 track 1 of 2:  67%|██████▋   | 12/18 [00:31<00:11,  1.94s/it]
# cessing speaker spk_3 track 1 of 2:  72%|███████▏  | 13/18 [00:35<00:13,  2.79s/it]
# cessing speaker spk_3 track 1 of 2:  78%|███████▊  | 14/18 [00:40<00:13,  3.29s/it]
# cessing speaker spk_3 track 1 of 2:  83%|████████▎ | 15/18 [00:44<00:10,  3.54s/it]
# cessing speaker spk_3 track 1 of 2:  89%|████████▉ | 16/18 [00:45<00:05,  2.93s/it]
# cessing speaker spk_3 track 1 of 2:  94%|█████████▍| 17/18 [00:46<00:02,  2.29s/it]
# Processing speaker spk_3 track 1 of 2: 100%|██████████| 18/18 [00:47<00:00,  2.63s/it]
#
# cessing speaker spk_3 track 2 of 2:   0%|          | 0/14 [00:00<?, ?it/s]
# cessing speaker spk_3 track 2 of 2:   7%|▋         | 1/14 [00:02<00:35,  2.70s/it]
# cessing speaker spk_3 track 2 of 2:  14%|█▍        | 2/14 [00:04<00:27,  2.26s/it]
# cessing speaker spk_3 track 2 of 2:  21%|██▏       | 3/14 [00:05<00:18,  1.66s/it]
# cessing speaker spk_3 track 2 of 2:  29%|██▊       | 4/14 [00:06<00:12,  1.21s/it]
# cessing speaker spk_3 track 2 of 2:  36%|███▌      | 5/14 [00:06<00:09,  1.02s/it]
# cessing speaker spk_3 track 2 of 2:  43%|████▎     | 6/14 [00:07<00:07,  1.06it/s]
# cessing speaker spk_3 track 2 of 2:  50%|█████     | 7/14 [00:12<00:16,  2.39s/it]
# cessing speaker spk_3 track 2 of 2:  57%|█████▋    | 8/14 [00:14<00:12,  2.13s/it]
# cessing speaker spk_3 track 2 of 2:  64%|██████▍   | 9/14 [00:15<00:08,  1.65s/it]
# cessing speaker spk_3 track 2 of 2:  71%|███████▏  | 10/14 [00:15<00:05,  1.34s/it]
# cessing speaker spk_3 track 2 of 2:  79%|███████▊  | 11/14 [00:16<00:03,  1.22s/it]
# cessing speaker spk_3 track 2 of 2:  86%|████████▌ | 12/14 [00:23<00:05,  2.79s/it]
# cessing speaker spk_3 track 2 of 2:  93%|█████████▎| 13/14 [00:25<00:02,  2.57s/it]
# Processing speaker spk_3 track 2 of 2: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Processing speakers:  67%|██████▋   | 4/6 [05:13<02:42, 81.07s/it]
# cessing speaker spk_4 track 1 of 1:   0%|          | 0/26 [00:00<?, ?it/s]
# cessing speaker spk_4 track 1 of 1:   4%|▍         | 1/26 [00:02<01:04,  2.58s/it]
# cessing speaker spk_4 track 1 of 1:   8%|▊         | 2/26 [00:03<00:40,  1.69s/it]
# cessing speaker spk_4 track 1 of 1:  12%|█▏        | 3/26 [00:12<01:58,  5.17s/it]
# cessing speaker spk_4 track 1 of 1:  15%|█▌        | 4/26 [00:26<03:06,  8.49s/it]
# cessing speaker spk_4 track 1 of 1:  19%|█▉        | 5/26 [00:29<02:18,  6.62s/it]
# cessing speaker spk_4 track 1 of 1:  23%|██▎       | 6/26 [00:31<01:41,  5.06s/it]
# cessing speaker spk_4 track 1 of 1:  27%|██▋       | 7/26 [00:33<01:17,  4.07s/it]
# cessing speaker spk_4 track 1 of 1:  31%|███       | 8/26 [00:36<01:05,  3.65s/it]
# cessing speaker spk_4 track 1 of 1:  35%|███▍      | 9/26 [00:38<00:53,  3.16s/it]
# cessing speaker spk_4 track 1 of 1:  38%|███▊      | 10/26 [00:46<01:13,  4.62s/it]
# cessing speaker spk_4 track 1 of 1:  42%|████▏     | 11/26 [00:47<00:53,  3.57s/it]
# cessing speaker spk_4 track 1 of 1:  46%|████▌     | 12/26 [00:48<00:37,  2.69s/it]
# cessing speaker spk_4 track 1 of 1:  50%|█████     | 13/26 [00:49<00:27,  2.11s/it]
# cessing speaker spk_4 track 1 of 1:  54%|█████▍    | 14/26 [00:52<00:29,  2.48s/it]
# cessing speaker spk_4 track 1 of 1:  58%|█████▊    | 15/26 [00:53<00:23,  2.14s/it]
# cessing speaker spk_4 track 1 of 1:  62%|██████▏   | 16/26 [00:54<00:17,  1.72s/it]
# cessing speaker spk_4 track 1 of 1:  65%|██████▌   | 17/26 [00:55<00:13,  1.53s/it]
# cessing speaker spk_4 track 1 of 1:  69%|██████▉   | 18/26 [00:58<00:15,  1.99s/it]
# cessing speaker spk_4 track 1 of 1:  73%|███████▎  | 19/26 [00:59<00:11,  1.71s/it]
# cessing speaker spk_4 track 1 of 1:  77%|███████▋  | 20/26 [01:01<00:10,  1.79s/it]
# cessing speaker spk_4 track 1 of 1:  81%|████████  | 21/26 [01:02<00:07,  1.52s/it]
# cessing speaker spk_4 track 1 of 1:  85%|████████▍ | 22/26 [01:03<00:05,  1.29s/it]
# cessing speaker spk_4 track 1 of 1:  88%|████████▊ | 23/26 [01:04<00:03,  1.10s/it]
# cessing speaker spk_4 track 1 of 1:  92%|█████████▏| 24/26 [01:04<00:02,  1.01s/it]
# cessing speaker spk_4 track 1 of 1:  96%|█████████▌| 25/26 [01:08<00:01,  1.69s/it]
# Processing speaker spk_4 track 1 of 1: 100%|██████████| 26/26 [01:10<00:00,  2.73s/it]
# Processing speakers:  83%|████████▎ | 5/6 [06:24<01:17, 77.40s/it]
# cessing speaker spk_5 track 1 of 1:   0%|          | 0/32 [00:00<?, ?it/s]
# cessing speaker spk_5 track 1 of 1:   3%|▎         | 1/32 [00:01<00:34,  1.11s/it]
# cessing speaker spk_5 track 1 of 1:   6%|▋         | 2/32 [00:05<01:26,  2.88s/it]
# cessing speaker spk_5 track 1 of 1:   9%|▉         | 3/32 [00:07<01:11,  2.45s/it]
# cessing speaker spk_5 track 1 of 1:  12%|█▎        | 4/32 [00:10<01:17,  2.78s/it]
# cessing speaker spk_5 track 1 of 1:  16%|█▌        | 5/32 [00:11<00:56,  2.10s/it]
# cessing speaker spk_5 track 1 of 1:  19%|█▉        | 6/32 [00:14<00:59,  2.29s/it]
# cessing speaker spk_5 track 1 of 1:  22%|██▏       | 7/32 [00:15<00:47,  1.90s/it]
# cessing speaker spk_5 track 1 of 1:  25%|██▌       | 8/32 [00:18<01:00,  2.51s/it]
# cessing speaker spk_5 track 1 of 1:  28%|██▊       | 9/32 [00:20<00:53,  2.34s/it]
# cessing speaker spk_5 track 1 of 1:  31%|███▏      | 10/32 [00:23<00:52,  2.39s/it]
# cessing speaker spk_5 track 1 of 1:  34%|███▍      | 11/32 [00:35<01:49,  5.23s/it]
# cessing speaker spk_5 track 1 of 1:  38%|███▊      | 12/32 [00:38<01:31,  4.60s/it]
# cessing speaker spk_5 track 1 of 1:  41%|████      | 13/32 [00:40<01:14,  3.90s/it]
# cessing speaker spk_5 track 1 of 1:  44%|████▍     | 14/32 [00:41<00:54,  3.01s/it]
# cessing speaker spk_5 track 1 of 1:  47%|████▋     | 15/32 [00:42<00:40,  2.39s/it]
# cessing speaker spk_5 track 1 of 1:  50%|█████     | 16/32 [00:43<00:33,  2.11s/it]
# cessing speaker spk_5 track 1 of 1:  53%|█████▎    | 17/32 [00:46<00:33,  2.23s/it]
# cessing speaker spk_5 track 1 of 1:  56%|█████▋    | 18/32 [00:47<00:28,  2.00s/it]
# cessing speaker spk_5 track 1 of 1:  59%|█████▉    | 19/32 [00:48<00:21,  1.65s/it]
# cessing speaker spk_5 track 1 of 1:  62%|██████▎   | 20/32 [00:50<00:18,  1.56s/it]
# cessing speaker spk_5 track 1 of 1:  66%|██████▌   | 21/32 [00:57<00:37,  3.38s/it]
# cessing speaker spk_5 track 1 of 1:  69%|██████▉   | 22/32 [01:04<00:42,  4.29s/it]
# cessing speaker spk_5 track 1 of 1:  72%|███████▏  | 23/32 [01:07<00:35,  3.96s/it]
# cessing speaker spk_5 track 1 of 1:  75%|███████▌  | 24/32 [01:08<00:24,  3.09s/it]
# cessing speaker spk_5 track 1 of 1:  78%|███████▊  | 25/32 [01:08<00:16,  2.37s/it]
# cessing speaker spk_5 track 1 of 1:  81%|████████▏ | 26/32 [01:12<00:16,  2.72s/it]
# cessing speaker spk_5 track 1 of 1:  84%|████████▍ | 27/32 [01:13<00:11,  2.26s/it]
# cessing speaker spk_5 track 1 of 1:  88%|████████▊ | 28/32 [01:14<00:07,  1.89s/it]
# cessing speaker spk_5 track 1 of 1:  91%|█████████ | 29/32 [01:21<00:09,  3.24s/it]
# cessing speaker spk_5 track 1 of 1:  94%|█████████▍| 30/32 [01:24<00:06,  3.34s/it]
# cessing speaker spk_5 track 1 of 1:  97%|█████████▋| 31/32 [01:25<00:02,  2.62s/it]
# Processing speaker spk_5 track 1 of 1: 100%|██████████| 32/32 [01:27<00:00,  2.73s/it]
# Processing speakers: 100%|██████████| 6/6 [07:51<00:00, 78.66s/it]
# =========================
# Starte Inference für Experiment: E13_stage2_bs8_len20
#   base_model      = cocktail_stage2
#   model_type      = avsr_cocktail
#   checkpoint_path = model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000
#   beam_size       = 8
#   max_length      = 20
#   output_dir_name = output_E13_stage2_bs8_len20
#   session_dir     = data-bin/dev_without_central_videos/dev/session_40
#   comment         = Stage-2-Modell, beam=8, len=20
# Loading avsr_cocktail model...
# Loading model from model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000
# avsr_cocktail model loaded successfully!
# Inferring 1 sessions using avsr_cocktail model
# Processing session session_40
# Processing speakers:   0%|          | 0/6 [00:00<?, ?it/s]
# cessing speaker spk_0 track 1 of 1:   0%|          | 0/35 [00:00<?, ?it/s]
# cessing speaker spk_0 track 1 of 1:   3%|▎         | 1/35 [00:00<00:19,  1.79it/s]
# cessing speaker spk_0 track 1 of 1:   6%|▌         | 2/35 [00:01<00:16,  1.96it/s]
# cessing speaker spk_0 track 1 of 1:   9%|▊         | 3/35 [00:01<00:18,  1.75it/s]
# cessing speaker spk_0 track 1 of 1:  11%|█▏        | 4/35 [00:02<00:16,  1.87it/s]
# cessing speaker spk_0 track 1 of 1:  14%|█▍        | 5/35 [00:02<00:14,  2.00it/s]
# cessing speaker spk_0 track 1 of 1:  17%|█▋        | 6/35 [00:03<00:21,  1.37it/s]
# cessing speaker spk_0 track 1 of 1:  20%|██        | 7/35 [00:08<00:55,  1.98s/it]
# cessing speaker spk_0 track 1 of 1:  23%|██▎       | 8/35 [00:09<00:43,  1.61s/it]
# cessing speaker spk_0 track 1 of 1:  26%|██▌       | 9/35 [00:10<00:39,  1.53s/it]
# cessing speaker spk_0 track 1 of 1:  29%|██▊       | 10/35 [00:11<00:33,  1.34s/it]
# cessing speaker spk_0 track 1 of 1:  31%|███▏      | 11/35 [00:12<00:27,  1.14s/it]
# cessing speaker spk_0 track 1 of 1:  34%|███▍      | 12/35 [00:12<00:22,  1.02it/s]
# cessing speaker spk_0 track 1 of 1:  37%|███▋      | 13/35 [00:14<00:28,  1.31s/it]
# cessing speaker spk_0 track 1 of 1:  40%|████      | 14/35 [00:15<00:22,  1.07s/it]
# cessing speaker spk_0 track 1 of 1:  43%|████▎     | 15/35 [00:15<00:19,  1.05it/s]
# cessing speaker spk_0 track 1 of 1:  46%|████▌     | 16/35 [00:16<00:15,  1.26it/s]
# cessing speaker spk_0 track 1 of 1:  49%|████▊     | 17/35 [00:17<00:13,  1.34it/s]
# cessing speaker spk_0 track 1 of 1:  51%|█████▏    | 18/35 [00:18<00:14,  1.18it/s]
# cessing speaker spk_0 track 1 of 1:  54%|█████▍    | 19/35 [00:19<00:14,  1.09it/s]
# cessing speaker spk_0 track 1 of 1:  57%|█████▋    | 20/35 [00:19<00:12,  1.17it/s]
# cessing speaker spk_0 track 1 of 1:  60%|██████    | 21/35 [00:20<00:12,  1.13it/s]
# cessing speaker spk_0 track 1 of 1:  63%|██████▎   | 22/35 [00:21<00:10,  1.26it/s]
# cessing speaker spk_0 track 1 of 1:  66%|██████▌   | 23/35 [00:22<00:09,  1.30it/s]
# cessing speaker spk_0 track 1 of 1:  69%|██████▊   | 24/35 [00:23<00:08,  1.23it/s]
# cessing speaker spk_0 track 1 of 1:  71%|███████▏  | 25/35 [00:23<00:07,  1.32it/s]
# cessing speaker spk_0 track 1 of 1:  74%|███████▍  | 26/35 [00:25<00:09,  1.06s/it]
# cessing speaker spk_0 track 1 of 1:  77%|███████▋  | 27/35 [00:26<00:07,  1.09it/s]
# cessing speaker spk_0 track 1 of 1:  80%|████████  | 28/35 [00:26<00:06,  1.09it/s]
# cessing speaker spk_0 track 1 of 1:  83%|████████▎ | 29/35 [00:27<00:05,  1.13it/s]
# cessing speaker spk_0 track 1 of 1:  86%|████████▌ | 30/35 [00:30<00:07,  1.52s/it]
# cessing speaker spk_0 track 1 of 1:  89%|████████▊ | 31/35 [00:31<00:05,  1.27s/it]
# cessing speaker spk_0 track 1 of 1:  91%|█████████▏| 32/35 [00:33<00:04,  1.53s/it]
# cessing speaker spk_0 track 1 of 1:  94%|█████████▍| 33/35 [00:38<00:04,  2.42s/it]
# cessing speaker spk_0 track 1 of 1:  97%|█████████▋| 34/35 [00:42<00:02,  2.98s/it]
# Processing speaker spk_0 track 1 of 1: 100%|██████████| 35/35 [00:43<00:00,  1.23s/it]
# Processing speakers:  17%|█▋        | 1/6 [00:43<03:35, 43.12s/it]
# cessing speaker spk_1 track 1 of 1:   0%|          | 0/40 [00:00<?, ?it/s]
# cessing speaker spk_1 track 1 of 1:   2%|▎         | 1/40 [00:00<00:19,  1.98it/s]
# cessing speaker spk_1 track 1 of 1:   5%|▌         | 2/40 [00:01<00:31,  1.19it/s]
# cessing speaker spk_1 track 1 of 1:   8%|▊         | 3/40 [00:02<00:31,  1.19it/s]
# cessing speaker spk_1 track 1 of 1:  10%|█         | 4/40 [00:02<00:26,  1.38it/s]
# cessing speaker spk_1 track 1 of 1:  12%|█▎        | 5/40 [00:04<00:40,  1.16s/it]
# cessing speaker spk_1 track 1 of 1:  15%|█▌        | 6/40 [00:06<00:40,  1.19s/it]
# cessing speaker spk_1 track 1 of 1:  18%|█▊        | 7/40 [00:06<00:32,  1.03it/s]
# cessing speaker spk_1 track 1 of 1:  20%|██        | 8/40 [00:07<00:28,  1.12it/s]
# cessing speaker spk_1 track 1 of 1:  22%|██▎       | 9/40 [00:08<00:25,  1.24it/s]
# cessing speaker spk_1 track 1 of 1:  25%|██▌       | 10/40 [00:08<00:24,  1.22it/s]
# cessing speaker spk_1 track 1 of 1:  28%|██▊       | 11/40 [00:09<00:21,  1.36it/s]
# cessing speaker spk_1 track 1 of 1:  30%|███       | 12/40 [00:10<00:21,  1.31it/s]
# cessing speaker spk_1 track 1 of 1:  32%|███▎      | 13/40 [00:11<00:21,  1.23it/s]
# cessing speaker spk_1 track 1 of 1:  35%|███▌      | 14/40 [00:11<00:20,  1.28it/s]
# cessing speaker spk_1 track 1 of 1:  38%|███▊      | 15/40 [00:12<00:19,  1.29it/s]
# cessing speaker spk_1 track 1 of 1:  40%|████      | 16/40 [00:13<00:17,  1.35it/s]
# cessing speaker spk_1 track 1 of 1:  42%|████▎     | 17/40 [00:22<01:12,  3.15s/it]
# cessing speaker spk_1 track 1 of 1:  45%|████▌     | 18/40 [00:23<00:57,  2.60s/it]
# cessing speaker spk_1 track 1 of 1:  48%|████▊     | 19/40 [00:24<00:43,  2.06s/it]
# cessing speaker spk_1 track 1 of 1:  50%|█████     | 20/40 [00:24<00:32,  1.64s/it]
# cessing speaker spk_1 track 1 of 1:  52%|█████▎    | 21/40 [00:25<00:26,  1.41s/it]
# cessing speaker spk_1 track 1 of 1:  55%|█████▌    | 22/40 [00:27<00:25,  1.42s/it]
# cessing speaker spk_1 track 1 of 1:  57%|█████▊    | 23/40 [00:37<01:12,  4.24s/it]
# cessing speaker spk_1 track 1 of 1:  60%|██████    | 24/40 [00:39<00:56,  3.54s/it]
# cessing speaker spk_1 track 1 of 1:  62%|██████▎   | 25/40 [00:45<01:03,  4.22s/it]
# cessing speaker spk_1 track 1 of 1:  65%|██████▌   | 26/40 [00:46<00:46,  3.29s/it]
# cessing speaker spk_1 track 1 of 1:  68%|██████▊   | 27/40 [00:52<00:53,  4.08s/it]
# cessing speaker spk_1 track 1 of 1:  70%|███████   | 28/40 [00:58<00:55,  4.65s/it]
# cessing speaker spk_1 track 1 of 1:  72%|███████▎  | 29/40 [01:06<01:02,  5.67s/it]
# cessing speaker spk_1 track 1 of 1:  75%|███████▌  | 30/40 [01:08<00:45,  4.54s/it]
# cessing speaker spk_1 track 1 of 1:  78%|███████▊  | 31/40 [01:09<00:32,  3.57s/it]
# cessing speaker spk_1 track 1 of 1:  80%|████████  | 32/40 [01:11<00:24,  3.09s/it]
# cessing speaker spk_1 track 1 of 1:  82%|████████▎ | 33/40 [01:12<00:16,  2.40s/it]
# cessing speaker spk_1 track 1 of 1:  85%|████████▌ | 34/40 [01:17<00:18,  3.01s/it]
# cessing speaker spk_1 track 1 of 1:  88%|████████▊ | 35/40 [01:19<00:13,  2.71s/it]
# cessing speaker spk_1 track 1 of 1:  90%|█████████ | 36/40 [01:19<00:08,  2.13s/it]
# cessing speaker spk_1 track 1 of 1:  92%|█████████▎| 37/40 [01:20<00:05,  1.72s/it]
# cessing speaker spk_1 track 1 of 1:  95%|█████████▌| 38/40 [01:25<00:05,  2.73s/it]
# cessing speaker spk_1 track 1 of 1:  98%|█████████▊| 39/40 [01:29<00:03,  3.14s/it]
# Processing speaker spk_1 track 1 of 1: 100%|██████████| 40/40 [01:32<00:00,  2.30s/it]
# Processing speakers:  33%|███▎      | 2/6 [02:15<04:47, 71.99s/it]
# Processing speaker spk_2 track 1 of 3: 0it [00:00, ?it/s]
#
# cessing speaker spk_2 track 2 of 3:   0%|          | 0/13 [00:00<?, ?it/s]
# cessing speaker spk_2 track 2 of 3:   8%|▊         | 1/13 [00:00<00:05,  2.01it/s]
# cessing speaker spk_2 track 2 of 3:  15%|█▌        | 2/13 [00:01<00:09,  1.15it/s]
# cessing speaker spk_2 track 2 of 3:  23%|██▎       | 3/13 [00:03<00:11,  1.16s/it]
# cessing speaker spk_2 track 2 of 3:  31%|███       | 4/13 [00:07<00:22,  2.55s/it]
# cessing speaker spk_2 track 2 of 3:  38%|███▊      | 5/13 [00:08<00:16,  2.01s/it]
# cessing speaker spk_2 track 2 of 3:  46%|████▌     | 6/13 [00:12<00:17,  2.55s/it]
# cessing speaker spk_2 track 2 of 3:  54%|█████▍    | 7/13 [00:16<00:19,  3.19s/it]
# cessing speaker spk_2 track 2 of 3:  62%|██████▏   | 8/13 [00:22<00:19,  3.99s/it]
# cessing speaker spk_2 track 2 of 3:  69%|██████▉   | 9/13 [00:23<00:12,  3.02s/it]
# cessing speaker spk_2 track 2 of 3:  77%|███████▋  | 10/13 [00:29<00:11,  3.93s/it]
# cessing speaker spk_2 track 2 of 3:  85%|████████▍ | 11/13 [00:33<00:07,  4.00s/it]
# cessing speaker spk_2 track 2 of 3:  92%|█████████▏| 12/13 [00:45<00:06,  6.34s/it]
# Processing speaker spk_2 track 2 of 3: 100%|██████████| 13/13 [00:46<00:00,  3.57s/it]
#
# cessing speaker spk_2 track 3 of 3:   0%|          | 0/12 [00:00<?, ?it/s]
# cessing speaker spk_2 track 3 of 3:   8%|▊         | 1/12 [00:00<00:10,  1.07it/s]
# cessing speaker spk_2 track 3 of 3:  17%|█▋        | 2/12 [00:01<00:08,  1.14it/s]
# cessing speaker spk_2 track 3 of 3:  25%|██▌       | 3/12 [00:13<00:52,  5.84s/it]
# cessing speaker spk_2 track 3 of 3:  33%|███▎      | 4/12 [00:24<01:01,  7.73s/it]
# cessing speaker spk_2 track 3 of 3:  42%|████▏     | 5/12 [00:28<00:45,  6.43s/it]
# cessing speaker spk_2 track 3 of 3:  50%|█████     | 6/12 [00:29<00:28,  4.74s/it]
# cessing speaker spk_2 track 3 of 3:  58%|█████▊    | 7/12 [00:33<00:22,  4.48s/it]
# cessing speaker spk_2 track 3 of 3:  67%|██████▋   | 8/12 [00:35<00:14,  3.66s/it]
# cessing speaker spk_2 track 3 of 3:  75%|███████▌  | 9/12 [00:37<00:08,  2.99s/it]
# cessing speaker spk_2 track 3 of 3:  83%|████████▎ | 10/12 [00:41<00:06,  3.48s/it]
# cessing speaker spk_2 track 3 of 3:  92%|█████████▏| 11/12 [00:42<00:02,  2.74s/it]
# Processing speaker spk_2 track 3 of 3: 100%|██████████| 12/12 [00:43<00:00,  3.66s/it]
# Processing speakers:  50%|█████     | 3/6 [03:45<04:01, 80.38s/it]
# cessing speaker spk_3 track 1 of 2:   0%|          | 0/18 [00:00<?, ?it/s]
# cessing speaker spk_3 track 1 of 2:   6%|▌         | 1/18 [00:00<00:12,  1.35it/s]
# cessing speaker spk_3 track 1 of 2:  11%|█         | 2/18 [00:01<00:10,  1.47it/s]
# cessing speaker spk_3 track 1 of 2:  17%|█▋        | 3/18 [00:08<00:50,  3.40s/it]
# cessing speaker spk_3 track 1 of 2:  22%|██▏       | 4/18 [00:10<00:41,  2.97s/it]
# cessing speaker spk_3 track 1 of 2:  28%|██▊       | 5/18 [00:15<00:47,  3.62s/it]
# cessing speaker spk_3 track 1 of 2:  33%|███▎      | 6/18 [00:16<00:33,  2.80s/it]
# cessing speaker spk_3 track 1 of 2:  39%|███▉      | 7/18 [00:20<00:37,  3.37s/it]
# cessing speaker spk_3 track 1 of 2:  44%|████▍     | 8/18 [00:23<00:32,  3.25s/it]
# cessing speaker spk_3 track 1 of 2:  50%|█████     | 9/18 [00:27<00:29,  3.31s/it]
# cessing speaker spk_3 track 1 of 2:  56%|█████▌    | 10/18 [00:28<00:20,  2.54s/it]
# cessing speaker spk_3 track 1 of 2:  61%|██████    | 11/18 [00:29<00:14,  2.07s/it]
# cessing speaker spk_3 track 1 of 2:  67%|██████▋   | 12/18 [00:30<00:10,  1.82s/it]
# cessing speaker spk_3 track 1 of 2:  72%|███████▏  | 13/18 [00:34<00:13,  2.61s/it]
# cessing speaker spk_3 track 1 of 2:  78%|███████▊  | 14/18 [00:38<00:11,  2.96s/it]
# cessing speaker spk_3 track 1 of 2:  83%|████████▎ | 15/18 [00:42<00:09,  3.17s/it]
# cessing speaker spk_3 track 1 of 2:  89%|████████▉ | 16/18 [00:43<00:05,  2.60s/it]
# cessing speaker spk_3 track 1 of 2:  94%|█████████▍| 17/18 [00:44<00:02,  2.04s/it]
# Processing speaker spk_3 track 1 of 2: 100%|██████████| 18/18 [00:44<00:00,  2.49s/it]
#
# cessing speaker spk_3 track 2 of 2:   0%|          | 0/14 [00:00<?, ?it/s]
# cessing speaker spk_3 track 2 of 2:   7%|▋         | 1/14 [00:02<00:33,  2.57s/it]
# cessing speaker spk_3 track 2 of 2:  14%|█▍        | 2/14 [00:04<00:25,  2.14s/it]
# cessing speaker spk_3 track 2 of 2:  21%|██▏       | 3/14 [00:05<00:16,  1.47s/it]
# cessing speaker spk_3 track 2 of 2:  29%|██▊       | 4/14 [00:05<00:11,  1.10s/it]
# cessing speaker spk_3 track 2 of 2:  36%|███▌      | 5/14 [00:06<00:08,  1.06it/s]
# ...
# cessing speaker spk_4 track 1 of 1:  50%|█████     | 14/28 [00:18<00:18,  1.30s/it]
# cessing speaker spk_4 track 1 of 1:  54%|█████▎    | 15/28 [00:20<00:19,  1.48s/it]
# cessing speaker spk_4 track 1 of 1:  57%|█████▋    | 16/28 [00:20<00:15,  1.31s/it]
# cessing speaker spk_4 track 1 of 1:  61%|██████    | 17/28 [00:22<00:14,  1.32s/it]
# cessing speaker spk_4 track 1 of 1:  64%|██████▍   | 18/28 [00:23<00:11,  1.17s/it]
# cessing speaker spk_4 track 1 of 1:  68%|██████▊   | 19/28 [00:25<00:13,  1.48s/it]
# cessing speaker spk_4 track 1 of 1:  71%|███████▏  | 20/28 [00:28<00:15,  1.96s/it]
# cessing speaker spk_4 track 1 of 1:  75%|███████▌  | 21/28 [00:29<00:11,  1.65s/it]
# cessing speaker spk_4 track 1 of 1:  79%|███████▊  | 22/28 [00:30<00:08,  1.37s/it]
# cessing speaker spk_4 track 1 of 1:  82%|████████▏ | 23/28 [00:31<00:06,  1.35s/it]
# cessing speaker spk_4 track 1 of 1:  86%|████████▌ | 24/28 [00:32<00:04,  1.17s/it]
# cessing speaker spk_4 track 1 of 1:  89%|████████▉ | 25/28 [00:35<00:05,  1.82s/it]
# cessing speaker spk_4 track 1 of 1:  93%|█████████▎| 26/28 [00:37<00:04,  2.00s/it]
# cessing speaker spk_4 track 1 of 1:  96%|█████████▋| 27/28 [00:44<00:03,  3.43s/it]
# Processing speaker spk_4 track 1 of 1: 100%|██████████| 28/28 [00:47<00:00,  1.70s/it]
# Processing speakers: 100%|██████████| 5/5 [05:56<00:00, 71.37s/it]
# =========================
# Starte Inference für Experiment: E13_stage2_bs8_len20
#   base_model      = cocktail_stage2
#   model_type      = avsr_cocktail
#   checkpoint_path = model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000
#   beam_size       = 8
#   max_length      = 20
#   output_dir_name = output_E13_stage2_bs8_len20
#   session_dir     = data-bin/dev_without_central_videos/dev/session_54
#   comment         = Stage-2-Modell, beam=8, len=20
# Loading avsr_cocktail model...
# Loading model from model-bin/avsr_cocktail_mcorec_stage2_lr5e-5_30k/checkpoint-30000
# avsr_cocktail model loaded successfully!
# Inferring 1 sessions using avsr_cocktail model
# Processing session session_54
# Processing speakers:   0%|          | 0/5 [00:00<?, ?it/s]
# cessing speaker spk_0 track 1 of 2:   0%|          | 0/26 [00:00<?, ?it/s]
# cessing speaker spk_0 track 1 of 2:   4%|▍         | 1/26 [00:00<00:22,  1.11it/s]
# cessing speaker spk_0 track 1 of 2:   8%|▊         | 2/26 [00:01<00:15,  1.56it/s]
# cessing speaker spk_0 track 1 of 2:  12%|█▏        | 3/26 [00:01<00:13,  1.74it/s]
# cessing speaker spk_0 track 1 of 2:  15%|█▌        | 4/26 [00:02<00:17,  1.27it/s]
# cessing speaker spk_0 track 1 of 2:  19%|█▉        | 5/26 [00:05<00:26,  1.25s/it]
# cessing speaker spk_0 track 1 of 2:  23%|██▎       | 6/26 [00:07<00:32,  1.61s/it]
# cessing speaker spk_0 track 1 of 2:  27%|██▋       | 7/26 [00:10<00:39,  2.07s/it]
# cessing speaker spk_0 track 1 of 2:  31%|███       | 8/26 [00:12<00:35,  1.96s/it]
# cessing speaker spk_0 track 1 of 2:  35%|███▍      | 9/26 [00:12<00:27,  1.63s/it]
# cessing speaker spk_0 track 1 of 2:  38%|███▊      | 10/26 [00:13<00:21,  1.36s/it]
# cessing speaker spk_0 track 1 of 2:  42%|████▏     | 11/26 [00:14<00:17,  1.13s/it]
# cessing speaker spk_0 track 1 of 2:  46%|████▌     | 12/26 [00:16<00:21,  1.57s/it]
# cessing speaker spk_0 track 1 of 2:  50%|█████     | 13/26 [00:20<00:27,  2.11s/it]
# cessing speaker spk_0 track 1 of 2:  54%|█████▍    | 14/26 [00:20<00:20,  1.67s/it]
# cessing speaker spk_0 track 1 of 2:  58%|█████▊    | 15/26 [00:21<00:14,  1.32s/it]
# cessing speaker spk_0 track 1 of 2:  62%|██████▏   | 16/26 [00:22<00:11,  1.12s/it]
# cessing speaker spk_0 track 1 of 2:  65%|██████▌   | 17/26 [00:24<00:12,  1.40s/it]
# cessing speaker spk_0 track 1 of 2:  69%|██████▉   | 18/26 [00:24<00:09,  1.14s/it]
# cessing speaker spk_0 track 1 of 2:  73%|███████▎  | 19/26 [00:25<00:07,  1.03s/it]
# cessing speaker spk_0 track 1 of 2:  77%|███████▋  | 20/26 [00:31<00:14,  2.46s/it]
# cessing speaker spk_0 track 1 of 2:  81%|████████  | 21/26 [00:36<00:16,  3.22s/it]
# cessing speaker spk_0 track 1 of 2:  85%|████████▍ | 22/26 [00:41<00:15,  3.90s/it]
# cessing speaker spk_0 track 1 of 2:  88%|████████▊ | 23/26 [00:42<00:09,  3.01s/it]
# cessing speaker spk_0 track 1 of 2:  92%|█████████▏| 24/26 [00:45<00:05,  2.89s/it]
# cessing speaker spk_0 track 1 of 2:  96%|█████████▌| 25/26 [00:46<00:02,  2.29s/it]
# Processing speaker spk_0 track 1 of 2: 100%|██████████| 26/26 [00:47<00:00,  1.82s/it]
#
# cessing speaker spk_0 track 2 of 2:   0%|          | 0/5 [00:00<?, ?it/s]
# cessing speaker spk_0 track 2 of 2:  20%|██        | 1/5 [00:04<00:18,  4.52s/it]
# cessing speaker spk_0 track 2 of 2:  40%|████      | 2/5 [00:09<00:15,  5.05s/it]
# cessing speaker spk_0 track 2 of 2:  60%|██████    | 3/5 [00:10<00:06,  3.16s/it]
# cessing speaker spk_0 track 2 of 2:  80%|████████  | 4/5 [00:13<00:02,  2.99s/it]
# Processing speaker spk_0 track 2 of 2: 100%|██████████| 5/5 [00:14<00:00,  2.83s/it]
# Processing speakers:  20%|██        | 1/5 [01:01<04:06, 61.58s/it]
# cessing speaker spk_1 track 1 of 1:   0%|          | 0/27 [00:00<?, ?it/s]
# cessing speaker spk_1 track 1 of 1:   4%|▎         | 1/27 [00:02<01:04,  2.46s/it]
# cessing speaker spk_1 track 1 of 1:   7%|▋         | 2/27 [00:08<01:48,  4.33s/it]
# cessing speaker spk_1 track 1 of 1:  11%|█         | 3/27 [00:15<02:18,  5.76s/it]
# cessing speaker spk_1 track 1 of 1:  15%|█▍        | 4/27 [00:21<02:15,  5.90s/it]
# cessing speaker spk_1 track 1 of 1:  19%|█▊        | 5/27 [00:26<02:04,  5.67s/it]
# cessing speaker spk_1 track 1 of 1:  22%|██▏       | 6/27 [00:31<01:48,  5.17s/it]
# cessing speaker spk_1 track 1 of 1:  26%|██▌       | 7/27 [00:33<01:22,  4.12s/it]
# cessing speaker spk_1 track 1 of 1:  30%|██▉       | 8/27 [00:38<01:25,  4.52s/it]
# cessing speaker spk_1 track 1 of 1:  33%|███▎      | 9/27 [00:43<01:22,  4.59s/it]
# cessing speaker spk_1 track 1 of 1:  37%|███▋      | 10/27 [00:44<00:58,  3.43s/it]
# cessing speaker spk_1 track 1 of 1:  41%|████      | 11/27 [00:44<00:42,  2.66s/it]
# cessing speaker spk_1 track 1 of 1:  44%|████▍     | 12/27 [00:45<00:31,  2.12s/it]
# cessing speaker spk_1 track 1 of 1:  48%|████▊     | 13/27 [00:48<00:32,  2.33s/it]
# cessing speaker spk_1 track 1 of 1:  52%|█████▏    | 14/27 [00:49<00:24,  1.88s/it]
# cessing speaker spk_1 track 1 of 1:  56%|█████▌    | 15/27 [00:50<00:18,  1.54s/it]
# cessing speaker spk_1 track 1 of 1:  59%|█████▉    | 16/27 [00:51<00:15,  1.39s/it]
# cessing speaker spk_1 track 1 of 1:  63%|██████▎   | 17/27 [00:51<00:11,  1.15s/it]
# cessing speaker spk_1 track 1 of 1:  67%|██████▋   | 18/27 [00:53<00:10,  1.16s/it]
# cessing speaker spk_1 track 1 of 1:  70%|███████   | 19/27 [00:53<00:08,  1.01s/it]
# cessing speaker spk_1 track 1 of 1:  74%|███████▍  | 20/27 [00:54<00:06,  1.10it/s]
# cessing speaker spk_1 track 1 of 1:  78%|███████▊  | 21/27 [01:02<00:18,  3.11s/it]
# cessing speaker spk_1 track 1 of 1:  81%|████████▏ | 22/27 [01:10<00:22,  4.43s/it]
# cessing speaker spk_1 track 1 of 1:  85%|████████▌ | 23/27 [01:11<00:14,  3.64s/it]
# cessing speaker spk_1 track 1 of 1:  89%|████████▉ | 24/27 [01:13<00:08,  2.98s/it]
# cessing speaker spk_1 track 1 of 1:  93%|█████████▎| 25/27 [01:15<00:05,  2.60s/it]
# cessing speaker spk_1 track 1 of 1:  96%|█████████▋| 26/27 [01:17<00:02,  2.48s/it]
# Processing speaker spk_1 track 1 of 1: 100%|██████████| 27/27 [01:18<00:00,  2.89s/it]
# Processing speakers:  40%|████      | 2/5 [02:19<03:33, 71.28s/it]
# cessing speaker spk_2 track 1 of 1:   0%|          | 0/32 [00:00<?, ?it/s]
# cessing speaker spk_2 track 1 of 1:   3%|▎         | 1/32 [00:01<00:46,  1.51s/it]
# cessing speaker spk_2 track 1 of 1:   6%|▋         | 2/32 [00:02<00:34,  1.14s/it]
# cessing speaker spk_2 track 1 of 1:   9%|▉         | 3/32 [00:05<00:53,  1.84s/it]
# cessing speaker spk_2 track 1 of 1:  12%|█▎        | 4/32 [00:08<01:06,  2.37s/it]
# cessing speaker spk_2 track 1 of 1:  16%|█▌        | 5/32 [00:08<00:46,  1.72s/it]
# cessing speaker spk_2 track 1 of 1:  19%|█▉        | 6/32 [00:09<00:36,  1.40s/it]
# cessing speaker spk_2 track 1 of 1:  22%|██▏       | 7/32 [00:11<00:42,  1.69s/it]
# cessing speaker spk_2 track 1 of 1:  25%|██▌       | 8/32 [00:14<00:46,  1.94s/it]
# cessing speaker spk_2 track 1 of 1:  28%|██▊       | 9/32 [00:15<00:38,  1.69s/it]
# cessing speaker spk_2 track 1 of 1:  31%|███▏      | 10/32 [00:16<00:31,  1.45s/it]
# cessing speaker spk_2 track 1 of 1:  34%|███▍      | 11/32 [00:17<00:25,  1.20s/it]
# cessing speaker spk_2 track 1 of 1:  38%|███▊      | 12/32 [00:18<00:26,  1.34s/it]
# cessing speaker spk_2 track 1 of 1:  41%|████      | 13/32 [00:19<00:21,  1.15s/it]
# cessing speaker spk_2 track 1 of 1:  44%|████▍     | 14/32 [00:20<00:18,  1.05s/it]
# cessing speaker spk_2 track 1 of 1:  47%|████▋     | 15/32 [00:20<00:14,  1.17it/s]
# cessing speaker spk_2 track 1 of 1:  50%|█████     | 16/32 [00:21<00:12,  1.28it/s]
# cessing speaker spk_2 track 1 of 1:  53%|█████▎    | 17/32 [00:23<00:18,  1.24s/it]
# cessing speaker spk_2 track 1 of 1:  56%|█████▋    | 18/32 [00:28<00:34,  2.49s/it]
# cessing speaker spk_2 track 1 of 1:  59%|█████▉    | 19/32 [00:29<00:25,  1.96s/it]
# cessing speaker spk_2 track 1 of 1:  62%|██████▎   | 20/32 [00:31<00:22,  1.84s/it]
# cessing speaker spk_2 track 1 of 1:  66%|██████▌   | 21/32 [00:32<00:18,  1.69s/it]
# cessing speaker spk_2 track 1 of 1:  69%|██████▉   | 22/32 [00:33<00:14,  1.44s/it]
# cessing speaker spk_2 track 1 of 1:  72%|███████▏  | 23/32 [00:34<00:11,  1.33s/it]
# cessing speaker spk_2 track 1 of 1:  75%|███████▌  | 24/32 [00:35<00:08,  1.12s/it]
# cessing speaker spk_2 track 1 of 1:  78%|███████▊  | 25/32 [00:35<00:06,  1.00it/s]
# cessing speaker spk_2 track 1 of 1:  81%|████████▏ | 26/32 [00:36<00:05,  1.11it/s]
# cessing speaker spk_2 track 1 of 1:  84%|████████▍ | 27/32 [00:39<00:07,  1.46s/it]
# cessing speaker spk_2 track 1 of 1:  88%|████████▊ | 28/32 [00:41<00:06,  1.66s/it]
# cessing speaker spk_2 track 1 of 1:  91%|█████████ | 29/32 [00:46<00:08,  2.73s/it]
# cessing speaker spk_2 track 1 of 1:  94%|█████████▍| 30/32 [00:52<00:07,  3.57s/it]
# cessing speaker spk_2 track 1 of 1:  97%|█████████▋| 31/32 [00:53<00:02,  2.83s/it]
# Processing speaker spk_2 track 1 of 1: 100%|██████████| 32/32 [00:55<00:00,  1.73s/it]
# Processing speakers:  60%|██████    | 3/5 [03:15<02:08, 64.02s/it]
# cessing speaker spk_3 track 1 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# cessing speaker spk_3 track 1 of 1:   3%|▎         | 1/38 [00:00<00:27,  1.36it/s]
# cessing speaker spk_3 track 1 of 1:   5%|▌         | 2/38 [00:02<00:52,  1.46s/it]
# cessing speaker spk_3 track 1 of 1:   8%|▊         | 3/38 [00:03<00:38,  1.09s/it]
# cessing speaker spk_3 track 1 of 1:  11%|█         | 4/38 [00:04<00:31,  1.08it/s]
# cessing speaker spk_3 track 1 of 1:  13%|█▎        | 5/38 [00:05<00:31,  1.04it/s]
# cessing speaker spk_3 track 1 of 1:  16%|█▌        | 6/38 [00:05<00:27,  1.16it/s]
# cessing speaker spk_3 track 1 of 1:  18%|█▊        | 7/38 [00:07<00:37,  1.22s/it]
# cessing speaker spk_3 track 1 of 1:  21%|██        | 8/38 [00:08<00:34,  1.14s/it]
# cessing speaker spk_3 track 1 of 1:  24%|██▎       | 9/38 [00:10<00:41,  1.42s/it]
# cessing speaker spk_3 track 1 of 1:  26%|██▋       | 10/38 [00:13<00:55,  1.99s/it]
# cessing speaker spk_3 track 1 of 1:  29%|██▉       | 11/38 [00:18<01:14,  2.76s/it]
# cessing speaker spk_3 track 1 of 1:  32%|███▏      | 12/38 [00:22<01:19,  3.08s/it]
# cessing speaker spk_3 track 1 of 1:  34%|███▍      | 13/38 [00:25<01:20,  3.21s/it]
# cessing speaker spk_3 track 1 of 1:  37%|███▋      | 14/38 [00:27<01:09,  2.91s/it]
# cessing speaker spk_3 track 1 of 1:  39%|███▉      | 15/38 [00:28<00:52,  2.29s/it]
# cessing speaker spk_3 track 1 of 1:  42%|████▏     | 16/38 [00:33<01:04,  2.93s/it]
# cessing speaker spk_3 track 1 of 1:  45%|████▍     | 17/38 [00:39<01:22,  3.93s/it]
# cessing speaker spk_3 track 1 of 1:  47%|████▋     | 18/38 [00:40<01:00,  3.04s/it]
# cessing speaker spk_3 track 1 of 1:  50%|█████     | 19/38 [00:42<00:50,  2.68s/it]
# cessing speaker spk_3 track 1 of 1:  53%|█████▎    | 20/38 [00:50<01:20,  4.46s/it]
# cessing speaker spk_3 track 1 of 1:  55%|█████▌    | 21/38 [00:52<01:01,  3.61s/it]
# cessing speaker spk_3 track 1 of 1:  58%|█████▊    | 22/38 [00:53<00:42,  2.67s/it]
# cessing speaker spk_3 track 1 of 1:  61%|██████    | 23/38 [00:53<00:32,  2.14s/it]
# cessing speaker spk_3 track 1 of 1:  63%|██████▎   | 24/38 [00:55<00:28,  2.02s/it]
# cessing speaker spk_3 track 1 of 1:  66%|██████▌   | 25/38 [00:57<00:25,  1.98s/it]
# cessing speaker spk_3 track 1 of 1:  68%|██████▊   | 26/38 [01:02<00:33,  2.81s/it]
# cessing speaker spk_3 track 1 of 1:  71%|███████   | 27/38 [01:05<00:33,  3.05s/it]
# cessing speaker spk_3 track 1 of 1:  74%|███████▎  | 28/38 [01:06<00:23,  2.33s/it]
# cessing speaker spk_3 track 1 of 1:  76%|███████▋  | 29/38 [01:07<00:17,  1.97s/it]
# cessing speaker spk_3 track 1 of 1:  79%|███████▉  | 30/38 [01:13<00:24,  3.11s/it]
# cessing speaker spk_3 track 1 of 1:  82%|████████▏ | 31/38 [01:14<00:17,  2.54s/it]
# cessing speaker spk_3 track 1 of 1:  84%|████████▍ | 32/38 [01:15<00:12,  2.14s/it]
# cessing speaker spk_3 track 1 of 1:  87%|████████▋ | 33/38 [01:19<00:12,  2.54s/it]
# cessing speaker spk_3 track 1 of 1:  89%|████████▉ | 34/38 [01:20<00:08,  2.09s/it]
# cessing speaker spk_3 track 1 of 1:  92%|█████████▏| 35/38 [01:21<00:05,  1.71s/it]
# cessing speaker spk_3 track 1 of 1:  95%|█████████▍| 36/38 [01:22<00:03,  1.63s/it]
# cessing speaker spk_3 track 1 of 1:  97%|█████████▋| 37/38 [01:24<00:01,  1.68s/it]
# Processing speaker spk_3 track 1 of 1: 100%|██████████| 38/38 [01:25<00:00,  2.24s/it]
# Processing speakers:  80%|████████  | 4/5 [04:40<01:12, 72.33s/it]
# cessing speaker spk_4 track 1 of 1:   0%|          | 0/28 [00:00<?, ?it/s]
# cessing speaker spk_4 track 1 of 1:   4%|▎         | 1/28 [00:02<00:56,  2.08s/it]
# cessing speaker spk_4 track 1 of 1:   7%|▋         | 2/28 [00:02<00:33,  1.28s/it]
# cessing speaker spk_4 track 1 of 1:  11%|█         | 3/28 [00:03<00:23,  1.05it/s]
# cessing speaker spk_4 track 1 of 1:  14%|█▍        | 4/28 [00:03<00:18,  1.26it/s]
# cessing speaker spk_4 track 1 of 1:  18%|█▊        | 5/28 [00:05<00:25,  1.11s/it]
# cessing speaker spk_4 track 1 of 1:  21%|██▏       | 6/28 [00:06<00:22,  1.04s/it]
# cessing speaker spk_4 track 1 of 1:  25%|██▌       | 7/28 [00:09<00:33,  1.57s/it]
# cessing speaker spk_4 track 1 of 1:  29%|██▊       | 8/28 [00:10<00:26,  1.35s/it]
# cessing speaker spk_4 track 1 of 1:  32%|███▏      | 9/28 [00:11<00:25,  1.37s/it]
# cessing speaker spk_4 track 1 of 1:  36%|███▌      | 10/28 [00:12<00:20,  1.13s/it]
# cessing speaker spk_4 track 1 of 1:  39%|███▉      | 11/28 [00:13<00:21,  1.27s/it]
# cessing speaker spk_4 track 1 of 1:  43%|████▎     | 12/28 [00:14<00:18,  1.18s/it]
# cessing speaker spk_4 track 1 of 1:  46%|████▋     | 13/28 [00:16<00:21,  1.41s/it]
# cessing speaker spk_4 track 1 of 1:  50%|█████     | 14/28 [00:17<00:17,  1.23s/it]
# cessing speaker spk_4 track 1 of 1:  54%|█████▎    | 15/28 [00:19<00:17,  1.38s/it]
# cessing speaker spk_4 track 1 of 1:  57%|█████▋    | 16/28 [00:19<00:14,  1.22s/it]
# cessing speaker spk_4 track 1 of 1:  61%|██████    | 17/28 [00:21<00:13,  1.27s/it]
# cessing speaker spk_4 track 1 of 1:  64%|██████▍   | 18/28 [00:21<00:10,  1.03s/it]
# cessing speaker spk_4 track 1 of 1:  68%|██████▊   | 19/28 [00:25<00:16,  1.78s/it]
# cessing speaker spk_4 track 1 of 1:  71%|███████▏  | 20/28 [00:28<00:16,  2.10s/it]
# cessing speaker spk_4 track 1 of 1:  75%|███████▌  | 21/28 [00:28<00:11,  1.66s/it]
# cessing speaker spk_4 track 1 of 1:  79%|███████▊  | 22/28 [00:29<00:08,  1.37s/it]
# cessing speaker spk_4 track 1 of 1:  82%|████████▏ | 23/28 [00:30<00:06,  1.25s/it]
# cessing speaker spk_4 track 1 of 1:  86%|████████▌ | 24/28 [00:31<00:04,  1.08s/it]
# cessing speaker spk_4 track 1 of 1:  89%|████████▉ | 25/28 [00:34<00:04,  1.65s/it]
# cessing speaker spk_4 track 1 of 1:  93%|█████████▎| 26/28 [00:36<00:03,  1.78s/it]
# cessing speaker spk_4 track 1 of 1:  96%|█████████▋| 27/28 [00:42<00:03,  3.12s/it]
# Processing speaker spk_4 track 1 of 1: 100%|██████████| 28/28 [00:45<00:00,  1.62s/it]
# Processing speakers: 100%|██████████| 5/5 [05:25<00:00, 65.09s/it]

# %% [markdown]
# ## 9 – Evaluation & Aggregation

# %%
# Ergebnisse aller Experimente auswerten und an die gemeinsame CSV anhängen
df_dev = append_eval_results_for_experiments(
    experiments=EXPERIMENTS,
    session_ids=SESSION_IDS,
    target_csv="results_dev_subset_by_session.csv",
)
# Out:
# ########## Evaluate für session_40 ##########
# Starte Evaluate: /home/josch080/Projektgruppe/mcorec_train/bin/python script/evaluate.py --session_dir data-bin/dev_without_central_videos/dev/session_40 --output_dir_name output_ --label_dir_name labels
# Evaluating 1 sessions
#
# === Evaluating session session_40 ===
#
# --- Evaluating output dir: output_E01_bs4_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.564, 'spk_1': 0.4281, 'spk_2': 0.5576, 'spk_3': 0.4283, 'spk_4': 0.4793, 'spk_5': 0.4189}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.282, 'spk_1': 0.21405, 'spk_2': 0.2788, 'spk_3': 0.21415, 'spk_4': 0.23965, 'spk_5': 0.20945}
#
# --- Evaluating output dir: output_E02_bs8_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.561, 'spk_1': 0.4312, 'spk_2': 0.5506, 'spk_3': 0.4283, 'spk_4': 0.5041, 'spk_5': 0.4189}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2805, 'spk_1': 0.2156, 'spk_2': 0.2753, 'spk_3': 0.21415, 'spk_4': 0.25205, 'spk_5': 0.20945}
#
# --- Evaluating output dir: output_E03_bs12_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5793, 'spk_1': 0.4328, 'spk_2': 0.5395, 'spk_3': 0.4264, 'spk_4': 0.5021, 'spk_5': 0.4189}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.28965, 'spk_1': 0.2164, 'spk_2': 0.26975, 'spk_3': 0.2132, 'spk_4': 0.25105, 'spk_5': 0.20945}
#
# --- Evaluating output dir: output_E04_bs4_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.564, 'spk_1': 0.4281, 'spk_2': 0.5368, 'spk_3': 0.4283, 'spk_4': 0.4897, 'spk_5': 0.4208}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.282, 'spk_1': 0.21405, 'spk_2': 0.2684, 'spk_3': 0.21415, 'spk_4': 0.24485, 'spk_5': 0.2104}
#
# --- Evaluating output dir: output_E05_bs8_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.561, 'spk_1': 0.4312, 'spk_2': 0.5326, 'spk_3': 0.4283, 'spk_4': 0.5124, 'spk_5': 0.4131}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2805, 'spk_1': 0.2156, 'spk_2': 0.2663, 'spk_3': 0.21415, 'spk_4': 0.2562, 'spk_5': 0.20655}
#
# --- Evaluating output dir: output_E06_bs12_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5793, 'spk_1': 0.4328, 'spk_2': 0.5215, 'spk_3': 0.4264, 'spk_4': 0.5103, 'spk_5': 0.4131}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.28965, 'spk_1': 0.2164, 'spk_2': 0.26075, 'spk_3': 0.2132, 'spk_4': 0.25515, 'spk_5': 0.20655}
#
# --- Evaluating output dir: output_E07_bs4_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.564, 'spk_1': 0.4204, 'spk_2': 0.5215, 'spk_3': 0.4283, 'spk_4': 0.4979, 'spk_5': 0.4208}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.282, 'spk_1': 0.2102, 'spk_2': 0.26075, 'spk_3': 0.21415, 'spk_4': 0.24895, 'spk_5': 0.2104}
#
# --- Evaluating output dir: output_E08_bs8_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.561, 'spk_1': 0.4266, 'spk_2': 0.5146, 'spk_3': 0.4283, 'spk_4': 0.5124, 'spk_5': 0.4131}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2805, 'spk_1': 0.2133, 'spk_2': 0.2573, 'spk_3': 0.21415, 'spk_4': 0.2562, 'spk_5': 0.20655}
#
# --- Evaluating output dir: output_E09_bs12_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5793, 'spk_1': 0.4297, 'spk_2': 0.5035, 'spk_3': 0.4264, 'spk_4': 0.5103, 'spk_5': 0.4131}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.28965, 'spk_1': 0.21485, 'spk_2': 0.25175, 'spk_3': 0.2132, 'spk_4': 0.25515, 'spk_5': 0.20655}
#
# --- Evaluating output dir: output_E10_bs8_len10 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.6098, 'spk_1': 0.5997, 'spk_2': 0.6117, 'spk_3': 0.5382, 'spk_4': 0.5062, 'spk_5': 0.4942}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.3049, 'spk_1': 0.29985, 'spk_2': 0.30585, 'spk_3': 0.2691, 'spk_4': 0.2531, 'spk_5': 0.2471}
#
# --- Evaluating output dir: output_E11_stage2_bs3_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.7104, 'spk_1': 0.4822, 'spk_2': 0.6477, 'spk_3': 0.4842, 'spk_4': 0.5413, 'spk_5': 0.4633}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.3552, 'spk_1': 0.2411, 'spk_2': 0.32385, 'spk_3': 0.2421, 'spk_4': 0.27065, 'spk_5': 0.23165}
#
# --- Evaluating output dir: output_E12_stage2_bs12_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.686, 'spk_1': 0.4699, 'spk_2': 0.5964, 'spk_3': 0.4823, 'spk_4': 0.5393, 'spk_5': 0.4054}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.343, 'spk_1': 0.23495, 'spk_2': 0.2982, 'spk_3': 0.24115, 'spk_4': 0.26965, 'spk_5': 0.2027}
#
# --- Evaluating output dir: output_E13_stage2_bs8_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.686, 'spk_1': 0.4699, 'spk_2': 0.5825, 'spk_3': 0.486, 'spk_4': 0.531, 'spk_5': 0.4054}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.343, 'spk_1': 0.23495, 'spk_2': 0.29125, 'spk_3': 0.243, 'spk_4': 0.2655, 'spk_5': 0.2027}
#
# --- Evaluating output dir: output_auto_avsr ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.8445, 'spk_1': 0.847, 'spk_2': 0.8946, 'spk_3': 0.8957, 'spk_4': 0.8388, 'spk_5': 0.8417}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.42225, 'spk_1': 0.4235, 'spk_2': 0.4473, 'spk_3': 0.44785, 'spk_4': 0.4194, 'spk_5': 0.42085}
#
# --- Evaluating output dir: output_avsr_cocktail ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5671, 'spk_1': 0.3138, 'spk_2': 0.5978, 'spk_3': 0.4469, 'spk_4': 0.5351, 'spk_5': 0.4112}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.28355, 'spk_1': 0.1569, 'spk_2': 0.2989, 'spk_3': 0.22345, 'spk_4': 0.26755, 'spk_5': 0.2056}
#
# --- Evaluating output dir: output_avsr_cocktail_finetuned ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5732, 'spk_1': 0.4359, 'spk_2': 0.5603, 'spk_3': 0.4264, 'spk_4': 0.4773, 'spk_5': 0.4344}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2866, 'spk_1': 0.21795, 'spk_2': 0.28015, 'spk_3': 0.2132, 'spk_4': 0.23865, 'spk_5': 0.2172}
#
# --- Evaluating output dir: output_muavic_en ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.7805, 'spk_1': 0.643, 'spk_2': 0.7809, 'spk_3': 0.743, 'spk_4': 0.6983, 'spk_5': 0.6158}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.39025, 'spk_1': 0.3215, 'spk_2': 0.39045, 'spk_3': 0.3715, 'spk_4': 0.34915, 'spk_5': 0.3079}
#
# ================= SUMMARY =================
#
# Results for output dir prefix variant 'output_E01_bs4_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.47936666666666666
#   Average Joint ASR-Clustering Error Rate: 0.23968333333333333
#
# Results for output dir prefix variant 'output_E02_bs8_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.48235
#   Average Joint ASR-Clustering Error Rate: 0.241175
#
# Results for output dir prefix variant 'output_E03_bs12_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4831666666666667
#   Average Joint ASR-Clustering Error Rate: 0.24158333333333334
#
# Results for output dir prefix variant 'output_E04_bs4_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.47795000000000004
#   Average Joint ASR-Clustering Error Rate: 0.23897500000000002
#
# Results for output dir prefix variant 'output_E05_bs8_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4797666666666667
#   Average Joint ASR-Clustering Error Rate: 0.23988333333333334
#
# Results for output dir prefix variant 'output_E06_bs12_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.48056666666666664
#   Average Joint ASR-Clustering Error Rate: 0.24028333333333332
#
# Results for output dir prefix variant 'output_E07_bs4_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4754833333333333
#   Average Joint ASR-Clustering Error Rate: 0.23774166666666666
#
# Results for output dir prefix variant 'output_E08_bs8_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.476
#   Average Joint ASR-Clustering Error Rate: 0.238
#
# Results for output dir prefix variant 'output_E09_bs12_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.47705000000000003
#   Average Joint ASR-Clustering Error Rate: 0.23852500000000001
#
# Results for output dir prefix variant 'output_E10_bs8_len10':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.5599666666666666
#   Average Joint ASR-Clustering Error Rate: 0.2799833333333333
#
# Results for output dir prefix variant 'output_E11_stage2_bs3_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.55485
#   Average Joint ASR-Clustering Error Rate: 0.277425
#
# Results for output dir prefix variant 'output_E12_stage2_bs12_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.5298833333333333
#   Average Joint ASR-Clustering Error Rate: 0.26494166666666663
#
# Results for output dir prefix variant 'output_E13_stage2_bs8_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.5268
#   Average Joint ASR-Clustering Error Rate: 0.2634
#
# Results for output dir prefix variant 'output_auto_avsr':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.8603833333333335
#   Average Joint ASR-Clustering Error Rate: 0.43019166666666675
#
# Results for output dir prefix variant 'output_avsr_cocktail':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.47865
#   Average Joint ASR-Clustering Error Rate: 0.239325
#
# Results for output dir prefix variant 'output_avsr_cocktail_finetuned':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.48458333333333337
#   Average Joint ASR-Clustering Error Rate: 0.24229166666666668
#
# Results for output dir prefix variant 'output_muavic_en':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.7102499999999999
#   Average Joint ASR-Clustering Error Rate: 0.35512499999999997
#
#   -> Skippe bereits vorhandenes Ergebnis für session_40, E11_stage2_bs3_len15
#   -> Skippe bereits vorhandenes Ergebnis für session_40, E12_stage2_bs12_len20
#   -> Skippe bereits vorhandenes Ergebnis für session_40, E13_stage2_bs8_len20
#
# ########## Evaluate für session_43 ##########
# Starte Evaluate: /home/josch080/Projektgruppe/mcorec_train/bin/python script/evaluate.py --session_dir data-bin/dev_without_central_videos/dev/session_43 --output_dir_name output_ --label_dir_name labels
# Evaluating 1 sessions
#
# === Evaluating session session_43 ===
#
# --- Evaluating output dir: output_E01_bs4_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.2941, 'spk_1': 0.6012, 'spk_2': 0.4855, 'spk_3': 0.4039, 'spk_4': 0.5011, 'spk_5': 0.5601}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.14705, 'spk_1': 0.3006, 'spk_2': 0.24275, 'spk_3': 0.20195, 'spk_4': 0.25055, 'spk_5': 0.28005}
#
# --- Evaluating output dir: output_E02_bs8_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.2912, 'spk_1': 0.5951, 'spk_2': 0.4855, 'spk_3': 0.4024, 'spk_4': 0.4989, 'spk_5': 0.5464}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.1456, 'spk_1': 0.29755, 'spk_2': 0.24275, 'spk_3': 0.2012, 'spk_4': 0.24945, 'spk_5': 0.2732}
#
# --- Evaluating output dir: output_E03_bs12_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.2912, 'spk_1': 0.5951, 'spk_2': 0.4816, 'spk_3': 0.4024, 'spk_4': 0.4989, 'spk_5': 0.5464}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.1456, 'spk_1': 0.29755, 'spk_2': 0.2408, 'spk_3': 0.2012, 'spk_4': 0.24945, 'spk_5': 0.2732}
#
# --- Evaluating output dir: output_E04_bs4_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.3185, 'spk_1': 0.6012, 'spk_2': 0.4603, 'spk_3': 0.4009, 'spk_4': 0.5011, 'spk_5': 0.5601}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.15925, 'spk_1': 0.3006, 'spk_2': 0.23015, 'spk_3': 0.20045, 'spk_4': 0.25055, 'spk_5': 0.28005}
#
# --- Evaluating output dir: output_E05_bs8_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.3156, 'spk_1': 0.5951, 'spk_2': 0.4584, 'spk_3': 0.4009, 'spk_4': 0.4989, 'spk_5': 0.5464}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.1578, 'spk_1': 0.29755, 'spk_2': 0.2292, 'spk_3': 0.20045, 'spk_4': 0.24945, 'spk_5': 0.2732}
#
# --- Evaluating output dir: output_E06_bs12_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.3156, 'spk_1': 0.5951, 'spk_2': 0.4545, 'spk_3': 0.4009, 'spk_4': 0.4989, 'spk_5': 0.5464}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.1578, 'spk_1': 0.29755, 'spk_2': 0.22725, 'spk_3': 0.20045, 'spk_4': 0.24945, 'spk_5': 0.2732}
#
# --- Evaluating output dir: output_E07_bs4_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.3185, 'spk_1': 0.6012, 'spk_2': 0.4449, 'spk_3': 0.4069, 'spk_4': 0.5011, 'spk_5': 0.5601}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.15925, 'spk_1': 0.3006, 'spk_2': 0.22245, 'spk_3': 0.20345, 'spk_4': 0.25055, 'spk_5': 0.28005}
#
# --- Evaluating output dir: output_E08_bs8_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.3156, 'spk_1': 0.5951, 'spk_2': 0.4487, 'spk_3': 0.4084, 'spk_4': 0.4989, 'spk_5': 0.5464}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.1578, 'spk_1': 0.29755, 'spk_2': 0.22435, 'spk_3': 0.2042, 'spk_4': 0.24945, 'spk_5': 0.2732}
#
# --- Evaluating output dir: output_E09_bs12_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.3156, 'spk_1': 0.5951, 'spk_2': 0.4487, 'spk_3': 0.4084, 'spk_4': 0.4989, 'spk_5': 0.5464}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.1578, 'spk_1': 0.29755, 'spk_2': 0.22435, 'spk_3': 0.2042, 'spk_4': 0.24945, 'spk_5': 0.2732}
#
# --- Evaluating output dir: output_E10_bs8_len10 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.3515, 'spk_1': 0.6074, 'spk_2': 0.6015, 'spk_3': 0.5, 'spk_4': 0.5806, 'spk_5': 0.5546}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.17575, 'spk_1': 0.3037, 'spk_2': 0.30075, 'spk_3': 0.25, 'spk_4': 0.2903, 'spk_5': 0.2773}
#
# --- Evaluating output dir: output_E11_stage2_bs3_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.4821, 'spk_1': 0.6411, 'spk_2': 0.5648, 'spk_3': 0.4625, 'spk_4': 0.521, 'spk_5': 0.6831}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.24105, 'spk_1': 0.32055, 'spk_2': 0.2824, 'spk_3': 0.23125, 'spk_4': 0.2605, 'spk_5': 0.34155}
#
# --- Evaluating output dir: output_E12_stage2_bs12_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.4046, 'spk_1': 0.6656, 'spk_2': 0.53, 'spk_3': 0.4685, 'spk_4': 0.5011, 'spk_5': 0.6885}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2023, 'spk_1': 0.3328, 'spk_2': 0.265, 'spk_3': 0.23425, 'spk_4': 0.25055, 'spk_5': 0.34425}
#
# --- Evaluating output dir: output_E13_stage2_bs8_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.4448, 'spk_1': 0.6472, 'spk_2': 0.53, 'spk_3': 0.4715, 'spk_4': 0.5077, 'spk_5': 0.6885}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2224, 'spk_1': 0.3236, 'spk_2': 0.265, 'spk_3': 0.23575, 'spk_4': 0.25385, 'spk_5': 0.34425}
#
# --- Evaluating output dir: output_auto_avsr ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.8809, 'spk_1': 0.8773, 'spk_2': 0.6905, 'spk_3': 0.8498, 'spk_4': 0.8631, 'spk_5': 0.8934}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.44045, 'spk_1': 0.43865, 'spk_2': 0.34525, 'spk_3': 0.4249, 'spk_4': 0.43155, 'spk_5': 0.4467}
#
# --- Evaluating output dir: output_avsr_cocktail ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.3286, 'spk_1': 0.6963, 'spk_2': 0.4043, 'spk_3': 0.4324, 'spk_4': 0.6556, 'spk_5': 0.5601}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.1643, 'spk_1': 0.34815, 'spk_2': 0.20215, 'spk_3': 0.2162, 'spk_4': 0.3278, 'spk_5': 0.28005}
#
# --- Evaluating output dir: output_avsr_cocktail_finetuned ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.2984, 'spk_1': 0.6135, 'spk_2': 0.4874, 'spk_3': 0.4009, 'spk_4': 0.5188, 'spk_5': 0.5383}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.1492, 'spk_1': 0.30675, 'spk_2': 0.2437, 'spk_3': 0.20045, 'spk_4': 0.2594, 'spk_5': 0.26915}
#
# --- Evaluating output dir: output_muavic_en ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.6585, 'spk_1': 0.8466, 'spk_2': 0.7002, 'spk_3': 0.7117, 'spk_4': 0.8124, 'spk_5': 0.7459}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.32925, 'spk_1': 0.4233, 'spk_2': 0.3501, 'spk_3': 0.35585, 'spk_4': 0.4062, 'spk_5': 0.37295}
#
# ================= SUMMARY =================
#
# Results for output dir prefix variant 'output_E01_bs4_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4743166666666667
#   Average Joint ASR-Clustering Error Rate: 0.23715833333333336
#
# Results for output dir prefix variant 'output_E02_bs8_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4699166666666666
#   Average Joint ASR-Clustering Error Rate: 0.2349583333333333
#
# Results for output dir prefix variant 'output_E03_bs12_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.46926666666666667
#   Average Joint ASR-Clustering Error Rate: 0.23463333333333333
#
# Results for output dir prefix variant 'output_E04_bs4_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4736833333333334
#   Average Joint ASR-Clustering Error Rate: 0.2368416666666667
#
# Results for output dir prefix variant 'output_E05_bs8_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4692166666666666
#   Average Joint ASR-Clustering Error Rate: 0.2346083333333333
#
# Results for output dir prefix variant 'output_E06_bs12_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.46856666666666663
#   Average Joint ASR-Clustering Error Rate: 0.23428333333333332
#
# Results for output dir prefix variant 'output_E07_bs4_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4721166666666667
#   Average Joint ASR-Clustering Error Rate: 0.23605833333333334
#
# Results for output dir prefix variant 'output_E08_bs8_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.46884999999999993
#   Average Joint ASR-Clustering Error Rate: 0.23442499999999997
#
# Results for output dir prefix variant 'output_E09_bs12_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.46884999999999993
#   Average Joint ASR-Clustering Error Rate: 0.23442499999999997
#
# Results for output dir prefix variant 'output_E10_bs8_len10':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.5326
#   Average Joint ASR-Clustering Error Rate: 0.2663
#
# Results for output dir prefix variant 'output_E11_stage2_bs3_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.5591
#   Average Joint ASR-Clustering Error Rate: 0.27955
#
# Results for output dir prefix variant 'output_E12_stage2_bs12_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.54305
#   Average Joint ASR-Clustering Error Rate: 0.271525
#
# Results for output dir prefix variant 'output_E13_stage2_bs8_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.5482833333333333
#   Average Joint ASR-Clustering Error Rate: 0.2741416666666667
#
# Results for output dir prefix variant 'output_auto_avsr':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.8424999999999999
#   Average Joint ASR-Clustering Error Rate: 0.42124999999999996
#
# Results for output dir prefix variant 'output_avsr_cocktail':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.5128833333333334
#   Average Joint ASR-Clustering Error Rate: 0.2564416666666667
#
# Results for output dir prefix variant 'output_avsr_cocktail_finetuned':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4762166666666667
#   Average Joint ASR-Clustering Error Rate: 0.23810833333333334
#
# Results for output dir prefix variant 'output_muavic_en':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.7458833333333333
#   Average Joint ASR-Clustering Error Rate: 0.37294166666666667
#
#   -> Skippe bereits vorhandenes Ergebnis für session_43, E11_stage2_bs3_len15
#   -> Skippe bereits vorhandenes Ergebnis für session_43, E12_stage2_bs12_len20
#   -> Skippe bereits vorhandenes Ergebnis für session_43, E13_stage2_bs8_len20
#
# ########## Evaluate für session_49 ##########
# Starte Evaluate: /home/josch080/Projektgruppe/mcorec_train/bin/python script/evaluate.py --session_dir data-bin/dev_without_central_videos/dev/session_49 --output_dir_name output_ --label_dir_name labels
# Evaluating 1 sessions
#
# === Evaluating session session_49 ===
#
# --- Evaluating output dir: output_E01_bs4_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5306, 'spk_1': 0.4038, 'spk_2': 0.4436, 'spk_3': 0.3179, 'spk_4': 0.3773, 'spk_5': 0.5602}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2653, 'spk_1': 0.2019, 'spk_2': 0.2218, 'spk_3': 0.15895, 'spk_4': 0.18865, 'spk_5': 0.2801}
#
# --- Evaluating output dir: output_E02_bs8_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5442, 'spk_1': 0.4038, 'spk_2': 0.4493, 'spk_3': 0.3179, 'spk_4': 0.3798, 'spk_5': 0.5486}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2721, 'spk_1': 0.2019, 'spk_2': 0.22465, 'spk_3': 0.15895, 'spk_4': 0.1899, 'spk_5': 0.2743}
#
# --- Evaluating output dir: output_E03_bs12_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5442, 'spk_1': 0.4075, 'spk_2': 0.4493, 'spk_3': 0.3179, 'spk_4': 0.3824, 'spk_5': 0.5556}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2721, 'spk_1': 0.20375, 'spk_2': 0.22465, 'spk_3': 0.15895, 'spk_4': 0.1912, 'spk_5': 0.2778}
#
# --- Evaluating output dir: output_E04_bs4_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5306, 'spk_1': 0.4038, 'spk_2': 0.4436, 'spk_3': 0.3179, 'spk_4': 0.3773, 'spk_5': 0.5602}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2653, 'spk_1': 0.2019, 'spk_2': 0.2218, 'spk_3': 0.15895, 'spk_4': 0.18865, 'spk_5': 0.2801}
#
# --- Evaluating output dir: output_E05_bs8_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5442, 'spk_1': 0.4038, 'spk_2': 0.4493, 'spk_3': 0.3179, 'spk_4': 0.3695, 'spk_5': 0.5486}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2721, 'spk_1': 0.2019, 'spk_2': 0.22465, 'spk_3': 0.15895, 'spk_4': 0.18475, 'spk_5': 0.2743}
#
# --- Evaluating output dir: output_E06_bs12_len18 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5442, 'spk_1': 0.4075, 'spk_2': 0.4493, 'spk_3': 0.3179, 'spk_4': 0.3695, 'spk_5': 0.5556}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2721, 'spk_1': 0.20375, 'spk_2': 0.22465, 'spk_3': 0.15895, 'spk_4': 0.18475, 'spk_5': 0.2778}
#
# --- Evaluating output dir: output_E07_bs4_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5306, 'spk_1': 0.4075, 'spk_2': 0.4436, 'spk_3': 0.3179, 'spk_4': 0.3773, 'spk_5': 0.5532}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2653, 'spk_1': 0.20375, 'spk_2': 0.2218, 'spk_3': 0.15895, 'spk_4': 0.18865, 'spk_5': 0.2766}
#
# --- Evaluating output dir: output_E08_bs8_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5442, 'spk_1': 0.4075, 'spk_2': 0.4493, 'spk_3': 0.3179, 'spk_4': 0.3695, 'spk_5': 0.5347}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2721, 'spk_1': 0.20375, 'spk_2': 0.22465, 'spk_3': 0.15895, 'spk_4': 0.18475, 'spk_5': 0.26735}
#
# --- Evaluating output dir: output_E09_bs12_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5442, 'spk_1': 0.4075, 'spk_2': 0.4493, 'spk_3': 0.3179, 'spk_4': 0.3695, 'spk_5': 0.544}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2721, 'spk_1': 0.20375, 'spk_2': 0.22465, 'spk_3': 0.15895, 'spk_4': 0.18475, 'spk_5': 0.272}
#
# --- Evaluating output dir: output_E10_bs8_len10 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.6327, 'spk_1': 0.5283, 'spk_2': 0.4608, 'spk_3': 0.3902, 'spk_4': 0.4264, 'spk_5': 0.5231}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.31635, 'spk_1': 0.26415, 'spk_2': 0.2304, 'spk_3': 0.1951, 'spk_4': 0.2132, 'spk_5': 0.26155}
#
# --- Evaluating output dir: output_E11_stage2_bs3_len15 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.585, 'spk_1': 0.4415, 'spk_2': 0.501, 'spk_3': 0.3526, 'spk_4': 0.4057, 'spk_5': 0.5579}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2925, 'spk_1': 0.22075, 'spk_2': 0.2505, 'spk_3': 0.1763, 'spk_4': 0.20285, 'spk_5': 0.27895}
#
# --- Evaluating output dir: output_E12_stage2_bs12_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.585, 'spk_1': 0.4528, 'spk_2': 0.4685, 'spk_3': 0.3555, 'spk_4': 0.3824, 'spk_5': 0.544}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2925, 'spk_1': 0.2264, 'spk_2': 0.23425, 'spk_3': 0.17775, 'spk_4': 0.1912, 'spk_5': 0.272}
#
# --- Evaluating output dir: output_E13_stage2_bs8_len20 ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.585, 'spk_1': 0.4566, 'spk_2': 0.4685, 'spk_3': 0.3584, 'spk_4': 0.385, 'spk_5': 0.5556}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2925, 'spk_1': 0.2283, 'spk_2': 0.23425, 'spk_3': 0.1792, 'spk_4': 0.1925, 'spk_5': 0.2778}
#
# --- Evaluating output dir: output_auto_avsr ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.7619, 'spk_1': 0.6868, 'spk_2': 0.782, 'spk_3': 0.6936, 'spk_4': 0.8837, 'spk_5': 0.8241}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.38095, 'spk_1': 0.3434, 'spk_2': 0.391, 'spk_3': 0.3468, 'spk_4': 0.44185, 'spk_5': 0.41205}
#
# --- Evaluating output dir: output_avsr_cocktail ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5782, 'spk_1': 0.4264, 'spk_2': 0.4551, 'spk_3': 0.4162, 'spk_4': 0.4832, 'spk_5': 0.6366}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2891, 'spk_1': 0.2132, 'spk_2': 0.22755, 'spk_3': 0.2081, 'spk_4': 0.2416, 'spk_5': 0.3183}
#
# --- Evaluating output dir: output_avsr_cocktail_finetuned ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.5306, 'spk_1': 0.4113, 'spk_2': 0.4512, 'spk_3': 0.3179, 'spk_4': 0.3747, 'spk_5': 0.5602}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2653, 'spk_1': 0.20565, 'spk_2': 0.2256, 'spk_3': 0.15895, 'spk_4': 0.18735, 'spk_5': 0.2801}
#
# --- Evaluating output dir: output_muavic_en ---
# Conversation clustering F1 score: 1.0
# Speaker to WER: {'spk_0': 0.6871, 'spk_1': 0.6038, 'spk_2': 0.6883, 'spk_3': 0.5723, 'spk_4': 0.7313, 'spk_5': 0.7407}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 1.0, 'spk_3': 1.0, 'spk_4': 1.0, 'spk_5': 1.0}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.34355, 'spk_1': 0.3019, 'spk_2': 0.34415, 'spk_3': 0.28615, 'spk_4': 0.36565, 'spk_5': 0.37035}
#
# ================= SUMMARY =================
#
# Results for output dir prefix variant 'output_E01_bs4_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4389
#   Average Joint ASR-Clustering Error Rate: 0.21945
#
# Results for output dir prefix variant 'output_E02_bs8_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.44060000000000005
#   Average Joint ASR-Clustering Error Rate: 0.22030000000000002
#
# Results for output dir prefix variant 'output_E03_bs12_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4428166666666667
#   Average Joint ASR-Clustering Error Rate: 0.22140833333333335
#
# Results for output dir prefix variant 'output_E04_bs4_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4389
#   Average Joint ASR-Clustering Error Rate: 0.21945
#
# Results for output dir prefix variant 'output_E05_bs8_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.43888333333333335
#   Average Joint ASR-Clustering Error Rate: 0.21944166666666667
#
# Results for output dir prefix variant 'output_E06_bs12_len18':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4406666666666667
#   Average Joint ASR-Clustering Error Rate: 0.22033333333333335
#
# Results for output dir prefix variant 'output_E07_bs4_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.43835
#   Average Joint ASR-Clustering Error Rate: 0.219175
#
# Results for output dir prefix variant 'output_E08_bs8_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4371833333333333
#   Average Joint ASR-Clustering Error Rate: 0.21859166666666666
#
# Results for output dir prefix variant 'output_E09_bs12_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.43873333333333336
#   Average Joint ASR-Clustering Error Rate: 0.21936666666666668
#
# Results for output dir prefix variant 'output_E10_bs8_len10':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.4935833333333333
#   Average Joint ASR-Clustering Error Rate: 0.24679166666666666
#
# Results for output dir prefix variant 'output_E11_stage2_bs3_len15':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.47395000000000004
#   Average Joint ASR-Clustering Error Rate: 0.23697500000000002
#
# Results for output dir prefix variant 'output_E12_stage2_bs12_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.46469999999999995
#   Average Joint ASR-Clustering Error Rate: 0.23234999999999997
#
# Results for output dir prefix variant 'output_E13_stage2_bs8_len20':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.46818333333333334
#   Average Joint ASR-Clustering Error Rate: 0.23409166666666667
#
# Results for output dir prefix variant 'output_auto_avsr':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.7720166666666667
#   Average Joint ASR-Clustering Error Rate: 0.38600833333333334
#
# Results for output dir prefix variant 'output_avsr_cocktail':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.49928333333333336
#   Average Joint ASR-Clustering Error Rate: 0.24964166666666668
#
# Results for output dir prefix variant 'output_avsr_cocktail_finetuned':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.44098333333333334
#   Average Joint ASR-Clustering Error Rate: 0.22049166666666667
#
# Results for output dir prefix variant 'output_muavic_en':
#   Average Conversation Clustering F1 score: 1.0
#   Average Speaker WER: 0.6705833333333334
#   Average Joint ASR-Clustering Error Rate: 0.3352916666666667
#
#   -> Skippe bereits vorhandenes Ergebnis für session_49, E11_stage2_bs3_len15
#   -> Skippe bereits vorhandenes Ergebnis für session_49, E12_stage2_bs12_len20
#   -> Skippe bereits vorhandenes Ergebnis für session_49, E13_stage2_bs8_len20
#
# ########## Evaluate für session_50 ##########
# Starte Evaluate: /home/josch080/Projektgruppe/mcorec_train/bin/python script/evaluate.py --session_dir data-bin/dev_without_central_videos/dev/session_50 --output_dir_name output_ --label_dir_name labels
# Evaluating 1 sessions
#
# === Evaluating session session_50 ===
#
# --- Evaluating output dir: output_E01_bs4_len15 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.7008, 'spk_1': 0.4601, 'spk_2': 0.5792, 'spk_3': 0.5625, 'spk_4': 0.5849, 'spk_5': 0.3369}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5647, 'spk_1': 0.44435, 'spk_2': 0.5039, 'spk_3': 0.49555, 'spk_4': 0.50675, 'spk_5': 0.38275}
#
# --- Evaluating output dir: output_E02_bs8_len15 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.7087, 'spk_1': 0.3732, 'spk_2': 0.5738, 'spk_3': 0.5604, 'spk_4': 0.5597, 'spk_5': 0.3391}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.56865, 'spk_1': 0.4009, 'spk_2': 0.5012, 'spk_3': 0.4945, 'spk_4': 0.49415, 'spk_5': 0.38385}
#
# --- Evaluating output dir: output_E03_bs12_len15 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.7087, 'spk_1': 0.3732, 'spk_2': 0.5738, 'spk_3': 0.5625, 'spk_4': 0.5472, 'spk_5': 0.3391}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.56865, 'spk_1': 0.4009, 'spk_2': 0.5012, 'spk_3': 0.49555, 'spk_4': 0.4879, 'spk_5': 0.38385}
#
# --- Evaluating output dir: output_E04_bs4_len18 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.6982, 'spk_1': 0.4601, 'spk_2': 0.5847, 'spk_3': 0.5437, 'spk_4': 0.5849, 'spk_5': 0.3305}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5634, 'spk_1': 0.44435, 'spk_2': 0.50665, 'spk_3': 0.48614999999999997, 'spk_4': 0.50675, 'spk_5': 0.37955}
#
# --- Evaluating output dir: output_E05_bs8_len18 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.7034, 'spk_1': 0.3732, 'spk_2': 0.5792, 'spk_3': 0.5458, 'spk_4': 0.5597, 'spk_5': 0.3326}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5660000000000001, 'spk_1': 0.4009, 'spk_2': 0.5039, 'spk_3': 0.48719999999999997, 'spk_4': 0.49415, 'spk_5': 0.3806}
#
# --- Evaluating output dir: output_E06_bs12_len18 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.6982, 'spk_1': 0.3732, 'spk_2': 0.5792, 'spk_3': 0.55, 'spk_4': 0.5472, 'spk_5': 0.3326}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5634, 'spk_1': 0.4009, 'spk_2': 0.5039, 'spk_3': 0.4893, 'spk_4': 0.4879, 'spk_5': 0.3806}
#
# --- Evaluating output dir: output_E07_bs4_len20 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.6982, 'spk_1': 0.4674, 'spk_2': 0.5847, 'spk_3': 0.5437, 'spk_4': 0.5849, 'spk_5': 0.3218}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5634, 'spk_1': 0.44799999999999995, 'spk_2': 0.50665, 'spk_3': 0.48614999999999997, 'spk_4': 0.50675, 'spk_5': 0.3752}
#
# --- Evaluating output dir: output_E08_bs8_len20 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.7034, 'spk_1': 0.3732, 'spk_2': 0.5792, 'spk_3': 0.5458, 'spk_4': 0.5597, 'spk_5': 0.324}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5660000000000001, 'spk_1': 0.4009, 'spk_2': 0.5039, 'spk_3': 0.48719999999999997, 'spk_4': 0.49415, 'spk_5': 0.37629999999999997}
#
# --- Evaluating output dir: output_E09_bs12_len20 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.6982, 'spk_1': 0.3768, 'spk_2': 0.5792, 'spk_3': 0.55, 'spk_4': 0.5472, 'spk_5': 0.324}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5634, 'spk_1': 0.4027, 'spk_2': 0.5039, 'spk_3': 0.4893, 'spk_4': 0.4879, 'spk_5': 0.37629999999999997}
#
# --- Evaluating output dir: output_E10_bs8_len10 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.748, 'spk_1': 0.4022, 'spk_2': 0.5792, 'spk_3': 0.5625, 'spk_4': 0.5975, 'spk_5': 0.3413}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5883, 'spk_1': 0.4154, 'spk_2': 0.5039, 'spk_3': 0.49555, 'spk_4': 0.51305, 'spk_5': 0.38495}
#
# --- Evaluating output dir: output_E11_stage2_bs3_len15 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.7375, 'spk_1': 0.4601, 'spk_2': 0.6284, 'spk_3': 0.6, 'spk_4': 0.673, 'spk_5': 0.3607}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5830500000000001, 'spk_1': 0.44435, 'spk_2': 0.5285, 'spk_3': 0.5143, 'spk_4': 0.5508, 'spk_5': 0.39465}
#
# --- Evaluating output dir: output_E12_stage2_bs12_len20 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.727, 'spk_1': 0.4457, 'spk_2': 0.6284, 'spk_3': 0.5896, 'spk_4': 0.6792, 'spk_5': 0.3477}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5778, 'spk_1': 0.43715, 'spk_2': 0.5285, 'spk_3': 0.5091, 'spk_4': 0.5539000000000001, 'spk_5': 0.38815}
#
# --- Evaluating output dir: output_E13_stage2_bs8_len20 ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.727, 'spk_1': 0.4457, 'spk_2': 0.6284, 'spk_3': 0.5896, 'spk_4': 0.673, 'spk_5': 0.3477}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5778, 'spk_1': 0.43715, 'spk_2': 0.5285, 'spk_3': 0.5091, 'spk_4': 0.5508, 'spk_5': 0.38815}
#
# --- Evaluating output dir: output_auto_avsr ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.7822, 'spk_1': 0.7536, 'spk_2': 0.9071, 'spk_3': 0.7521, 'spk_4': 0.9434, 'spk_5': 0.6868}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.6053999999999999, 'spk_1': 0.5911, 'spk_2': 0.66785, 'spk_3': 0.5903499999999999, 'spk_4': 0.6859999999999999, 'spk_5': 0.5577}
#
# --- Evaluating output dir: output_avsr_cocktail ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.5906, 'spk_1': 0.4928, 'spk_2': 0.765, 'spk_3': 0.6021, 'spk_4': 0.7799, 'spk_5': 0.3348}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5096, 'spk_1': 0.4607, 'spk_2': 0.5968, 'spk_3': 0.51535, 'spk_4': 0.60425, 'spk_5': 0.3817}
#
# --- Evaluating output dir: output_avsr_cocktail_finetuned ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.6982, 'spk_1': 0.4638, 'spk_2': 0.5792, 'spk_3': 0.5646, 'spk_4': 0.5849, 'spk_5': 0.3369}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5634, 'spk_1': 0.4462, 'spk_2': 0.5039, 'spk_3': 0.4966, 'spk_4': 0.50675, 'spk_5': 0.38275}
#
# --- Evaluating output dir: output_muavic_en ---
# Conversation clustering F1 score: 0.5714285714285715
# Speaker to WER: {'spk_0': 0.6982, 'spk_1': 0.6884, 'spk_2': 0.8798, 'spk_3': 0.6396, 'spk_4': 0.8428, 'spk_5': 0.6717}
# Speaker clustering F1 score: {'spk_0': 0.5714, 'spk_1': 0.5714, 'spk_2': 0.5714, 'spk_3': 0.5714, 'spk_4': 0.5714, 'spk_5': 0.5714}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.5634, 'spk_1': 0.5585, 'spk_2': 0.6542, 'spk_3': 0.5341, 'spk_4': 0.6356999999999999, 'spk_5': 0.5501499999999999}
#
# ================= SUMMARY =================
#
# Results for output dir prefix variant 'output_E01_bs4_len15':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5374
#   Average Joint ASR-Clustering Error Rate: 0.48300000000000004
#
# Results for output dir prefix variant 'output_E02_bs8_len15':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.51915
#   Average Joint ASR-Clustering Error Rate: 0.4738749999999999
#
# Results for output dir prefix variant 'output_E03_bs12_len15':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5174166666666667
#   Average Joint ASR-Clustering Error Rate: 0.4730083333333333
#
# Results for output dir prefix variant 'output_E04_bs4_len18':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5336833333333333
#   Average Joint ASR-Clustering Error Rate: 0.48114166666666663
#
# Results for output dir prefix variant 'output_E05_bs8_len18':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5156499999999999
#   Average Joint ASR-Clustering Error Rate: 0.47212499999999996
#
# Results for output dir prefix variant 'output_E06_bs12_len18':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5134000000000002
#   Average Joint ASR-Clustering Error Rate: 0.47100000000000003
#
# Results for output dir prefix variant 'output_E07_bs4_len20':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.53345
#   Average Joint ASR-Clustering Error Rate: 0.48102500000000004
#
# Results for output dir prefix variant 'output_E08_bs8_len20':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5142166666666667
#   Average Joint ASR-Clustering Error Rate: 0.4714083333333334
#
# Results for output dir prefix variant 'output_E09_bs12_len20':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5125666666666667
#   Average Joint ASR-Clustering Error Rate: 0.47058333333333335
#
# Results for output dir prefix variant 'output_E10_bs8_len10':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.53845
#   Average Joint ASR-Clustering Error Rate: 0.48352500000000004
#
# Results for output dir prefix variant 'output_E11_stage2_bs3_len15':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5766166666666667
#   Average Joint ASR-Clustering Error Rate: 0.5026083333333332
#
# Results for output dir prefix variant 'output_E12_stage2_bs12_len20':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5696
#   Average Joint ASR-Clustering Error Rate: 0.49910000000000004
#
# Results for output dir prefix variant 'output_E13_stage2_bs8_len20':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5685666666666667
#   Average Joint ASR-Clustering Error Rate: 0.4985833333333333
#
# Results for output dir prefix variant 'output_auto_avsr':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.8041999999999999
#   Average Joint ASR-Clustering Error Rate: 0.6164
#
# Results for output dir prefix variant 'output_avsr_cocktail':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5942000000000001
#   Average Joint ASR-Clustering Error Rate: 0.5114
#
# Results for output dir prefix variant 'output_avsr_cocktail_finetuned':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.5379333333333333
#   Average Joint ASR-Clustering Error Rate: 0.4832666666666667
#
# Results for output dir prefix variant 'output_muavic_en':
#   Average Conversation Clustering F1 score: 0.5714285714285715
#   Average Speaker WER: 0.7367499999999999
#   Average Joint ASR-Clustering Error Rate: 0.5826749999999999
#
#   -> Skippe bereits vorhandenes Ergebnis für session_50, E11_stage2_bs3_len15
#   -> Skippe bereits vorhandenes Ergebnis für session_50, E12_stage2_bs12_len20
#   -> Skippe bereits vorhandenes Ergebnis für session_50, E13_stage2_bs8_len20
#
# ########## Evaluate für session_54 ##########
# Starte Evaluate: /home/josch080/Projektgruppe/mcorec_train/bin/python script/evaluate.py --session_dir data-bin/dev_without_central_videos/dev/session_54 --output_dir_name output_ --label_dir_name labels
# Evaluating 1 sessions
#
# === Evaluating session session_54 ===
#
# --- Evaluating output dir: output_E01_bs4_len15 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4434, 'spk_1': 0.3333, 'spk_2': 0.4641, 'spk_3': 0.4095, 'spk_4': 1.267}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2217, 'spk_1': 0.16665, 'spk_2': 0.39870000000000005, 'spk_3': 0.70475, 'spk_4': 0.8001499999999999}
#
# --- Evaluating output dir: output_E02_bs8_len15 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4434, 'spk_1': 0.3311, 'spk_2': 0.4641, 'spk_3': 0.4111, 'spk_4': 1.267}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2217, 'spk_1': 0.16555, 'spk_2': 0.39870000000000005, 'spk_3': 0.70555, 'spk_4': 0.8001499999999999}
#
# --- Evaluating output dir: output_E03_bs12_len15 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4434, 'spk_1': 0.3356, 'spk_2': 0.4641, 'spk_3': 0.4079, 'spk_4': 1.2513}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2217, 'spk_1': 0.1678, 'spk_2': 0.39870000000000005, 'spk_3': 0.70395, 'spk_4': 0.7923}
#
# --- Evaluating output dir: output_E04_bs4_len18 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4387, 'spk_1': 0.3288, 'spk_2': 0.4641, 'spk_3': 0.4095, 'spk_4': 1.267}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.21935, 'spk_1': 0.1644, 'spk_2': 0.39870000000000005, 'spk_3': 0.70475, 'spk_4': 0.8001499999999999}
#
# --- Evaluating output dir: output_E05_bs8_len18 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4434, 'spk_1': 0.3265, 'spk_2': 0.4641, 'spk_3': 0.4111, 'spk_4': 1.267}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2217, 'spk_1': 0.16325, 'spk_2': 0.39870000000000005, 'spk_3': 0.70555, 'spk_4': 0.8001499999999999}
#
# --- Evaluating output dir: output_E06_bs12_len18 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4434, 'spk_1': 0.3311, 'spk_2': 0.4641, 'spk_3': 0.4079, 'spk_4': 1.2513}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2217, 'spk_1': 0.16555, 'spk_2': 0.39870000000000005, 'spk_3': 0.70395, 'spk_4': 0.7923}
#
# --- Evaluating output dir: output_E07_bs4_len20 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4387, 'spk_1': 0.3288, 'spk_2': 0.4641, 'spk_3': 0.4111, 'spk_4': 1.267}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.21935, 'spk_1': 0.1644, 'spk_2': 0.39870000000000005, 'spk_3': 0.70555, 'spk_4': 0.8001499999999999}
#
# --- Evaluating output dir: output_E08_bs8_len20 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4434, 'spk_1': 0.3265, 'spk_2': 0.4641, 'spk_3': 0.4127, 'spk_4': 1.267}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2217, 'spk_1': 0.16325, 'spk_2': 0.39870000000000005, 'spk_3': 0.70635, 'spk_4': 0.8001499999999999}
#
# --- Evaluating output dir: output_E09_bs12_len20 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4434, 'spk_1': 0.3311, 'spk_2': 0.4641, 'spk_3': 0.4095, 'spk_4': 1.2513}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2217, 'spk_1': 0.16555, 'spk_2': 0.39870000000000005, 'spk_3': 0.70475, 'spk_4': 0.7923}
#
# --- Evaluating output dir: output_E10_bs8_len10 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4505, 'spk_1': 0.3311, 'spk_2': 0.5487, 'spk_3': 0.5238, 'spk_4': 1.2618}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.22525, 'spk_1': 0.16555, 'spk_2': 0.441, 'spk_3': 0.7619, 'spk_4': 0.79755}
#
# --- Evaluating output dir: output_E11_stage2_bs3_len15 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4458, 'spk_1': 0.3605, 'spk_2': 0.5103, 'spk_3': 0.4508, 'spk_4': 1.0942}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2229, 'spk_1': 0.18025, 'spk_2': 0.4218, 'spk_3': 0.7254, 'spk_4': 0.7137500000000001}
#
# --- Evaluating output dir: output_E12_stage2_bs12_len20 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4434, 'spk_1': 0.322, 'spk_2': 0.5077, 'spk_3': 0.446, 'spk_4': 1.0209}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2217, 'spk_1': 0.161, 'spk_2': 0.42050000000000004, 'spk_3': 0.723, 'spk_4': 0.6771}
#
# --- Evaluating output dir: output_E13_stage2_bs8_len20 ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.441, 'spk_1': 0.3288, 'spk_2': 0.5077, 'spk_3': 0.454, 'spk_4': 1.0209}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.2205, 'spk_1': 0.1644, 'spk_2': 0.42050000000000004, 'spk_3': 0.727, 'spk_4': 0.6771}
#
# --- Evaluating output dir: output_auto_avsr ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.8113, 'spk_1': 0.9274, 'spk_2': 0.7795, 'spk_3': 0.7556, 'spk_4': 1.2304}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.40565, 'spk_1': 0.4637, 'spk_2': 0.5564, 'spk_3': 0.8778, 'spk_4': 0.7818499999999999}
#
# --- Evaluating output dir: output_avsr_cocktail ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.5967, 'spk_1': 0.585, 'spk_2': 0.5744, 'spk_3': 0.4921, 'spk_4': 1.801}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.29835, 'spk_1': 0.2925, 'spk_2': 0.45385000000000003, 'spk_3': 0.74605, 'spk_4': 1.06715}
#
# --- Evaluating output dir: output_avsr_cocktail_finetuned ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.4363, 'spk_1': 0.3447, 'spk_2': 0.4641, 'spk_3': 0.4159, 'spk_4': 1.2932}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.21815, 'spk_1': 0.17235, 'spk_2': 0.39870000000000005, 'spk_3': 0.70795, 'spk_4': 0.81325}
#
# --- Evaluating output dir: output_muavic_en ---
# Conversation clustering F1 score: 0.6666666666666666
# Speaker to WER: {'spk_0': 0.658, 'spk_1': 0.746, 'spk_2': 0.741, 'spk_3': 0.7254, 'spk_4': 1.2304}
# Speaker clustering F1 score: {'spk_0': 1.0, 'spk_1': 1.0, 'spk_2': 0.6667, 'spk_3': 0.0, 'spk_4': 0.6667}
# Joint ASR-Clustering Error Rate: {'spk_0': 0.329, 'spk_1': 0.373, 'spk_2': 0.53715, 'spk_3': 0.8627, 'spk_4': 0.7818499999999999}
#
# ================= SUMMARY =================
#
# Results for output dir prefix variant 'output_E01_bs4_len15':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.58346
#   Average Joint ASR-Clustering Error Rate: 0.45838999999999996
#
# Results for output dir prefix variant 'output_E02_bs8_len15':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.58334
#   Average Joint ASR-Clustering Error Rate: 0.45832999999999996
#
# Results for output dir prefix variant 'output_E03_bs12_len15':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.5804600000000001
#   Average Joint ASR-Clustering Error Rate: 0.45689
#
# Results for output dir prefix variant 'output_E04_bs4_len18':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.58162
#   Average Joint ASR-Clustering Error Rate: 0.45747
#
# Results for output dir prefix variant 'output_E05_bs8_len18':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.5824199999999999
#   Average Joint ASR-Clustering Error Rate: 0.45786999999999994
#
# Results for output dir prefix variant 'output_E06_bs12_len18':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.5795600000000001
#   Average Joint ASR-Clustering Error Rate: 0.45644
#
# Results for output dir prefix variant 'output_E07_bs4_len20':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.58194
#   Average Joint ASR-Clustering Error Rate: 0.45763
#
# Results for output dir prefix variant 'output_E08_bs8_len20':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.58274
#   Average Joint ASR-Clustering Error Rate: 0.45803000000000005
#
# Results for output dir prefix variant 'output_E09_bs12_len20':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.57988
#   Average Joint ASR-Clustering Error Rate: 0.4566
#
# Results for output dir prefix variant 'output_E10_bs8_len10':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.62318
#   Average Joint ASR-Clustering Error Rate: 0.47825000000000006
#
# Results for output dir prefix variant 'output_E11_stage2_bs3_len15':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.57232
#   Average Joint ASR-Clustering Error Rate: 0.45282
#
# Results for output dir prefix variant 'output_E12_stage2_bs12_len20':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.548
#   Average Joint ASR-Clustering Error Rate: 0.4406600000000001
#
# Results for output dir prefix variant 'output_E13_stage2_bs8_len20':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.55048
#   Average Joint ASR-Clustering Error Rate: 0.44190000000000007
#
# Results for output dir prefix variant 'output_auto_avsr':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.9008400000000002
#   Average Joint ASR-Clustering Error Rate: 0.61708
#
# Results for output dir prefix variant 'output_avsr_cocktail':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.80984
#   Average Joint ASR-Clustering Error Rate: 0.57158
#
# Results for output dir prefix variant 'output_avsr_cocktail_finetuned':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.59084
#   Average Joint ASR-Clustering Error Rate: 0.46208
#
# Results for output dir prefix variant 'output_muavic_en':
#   Average Conversation Clustering F1 score: 0.6666666666666666
#   Average Speaker WER: 0.8201599999999999
#   Average Joint ASR-Clustering Error Rate: 0.5767399999999999
#
#   -> Skippe bereits vorhandenes Ergebnis für session_54, E11_stage2_bs3_len15
#   -> Skippe bereits vorhandenes Ergebnis für session_54, E12_stage2_bs12_len20
#   -> Skippe bereits vorhandenes Ergebnis für session_54, E13_stage2_bs8_len20
#
# Keine neuen Zeilen – alles schon vorhanden oder keine passenden Modelle.

# %% [markdown]
# ## 10 – Rohergebnisse (pro Session)
#
# Vollständige Tabelle aller Stage-2-Experimente aufgeschlüsselt nach Session.

# %%
import pandas as pd

# gemeinsame Ergebnis-CSV laden
df = pd.read_csv("results_dev_subset_by_session.csv")

stage2_models = [
    "E11_stage2_bs3_len15",
    "E12_stage2_bs12_len20",
    "E13_stage2_bs8_len20",
]

# Nur Stage-2-Zeilen filtern und nach Modell + Session sortieren
stage2_df = (
    df[df["model"].isin(stage2_models)]
    .sort_values(["model", "session"])
)

display(stage2_df)
# Out:
#        session                           exp  avg_conv_f1  avg_speaker_wer  \
# 10  session_40   output_E11_stage2_bs3_len15     1.000000         0.554850
# 23  session_43   output_E11_stage2_bs3_len15     1.000000         0.559100
# 36  session_49   output_E11_stage2_bs3_len15     1.000000         0.473950
# 49  session_50   output_E11_stage2_bs3_len15     0.571429         0.576617
# 62  session_54   output_E11_stage2_bs3_len15     0.666667         0.572320
# 11  session_40  output_E12_stage2_bs12_len20     1.000000         0.529883
# 24  session_43  output_E12_stage2_bs12_len20     1.000000         0.543050
# 37  session_49  output_E12_stage2_bs12_len20     1.000000         0.464700
# 50  session_50  output_E12_stage2_bs12_len20     0.571429         0.569600
# 63  session_54  output_E12_stage2_bs12_len20     0.666667         0.548000
# 12  session_40   output_E13_stage2_bs8_len20     1.000000         0.526800
# 25  session_43   output_E13_stage2_bs8_len20     1.000000         0.548283
# 38  session_49   output_E13_stage2_bs8_len20     1.000000         0.468183
# 51  session_50   output_E13_stage2_bs8_len20     0.571429         0.568567
# 64  session_54   output_E13_stage2_bs8_len20     0.666667         0.550480
#
#     avg_joint_error                  model            timestamp
# 10         0.277425   E11_stage2_bs3_len15  2025-11-30T14:02:31
# 23         0.279550   E11_stage2_bs3_len15  2025-11-30T14:02:45
# 36         0.236975   E11_stage2_bs3_len15  2025-11-30T14:02:58
# 49         0.502608   E11_stage2_bs3_len15  2025-11-30T14:03:11
# 62         0.452820   E11_stage2_bs3_len15  2025-11-30T14:03:24
# 11         0.264942  E12_stage2_bs12_len20  2025-11-30T14:02:31
# 24         0.271525  E12_stage2_bs12_len20  2025-11-30T14:02:45
# 37         0.232350  E12_stage2_bs12_len20  2025-11-30T14:02:58
# 50         0.499100  E12_stage2_bs12_len20  2025-11-30T14:03:11
# 63         0.440660  E12_stage2_bs12_len20  2025-11-30T14:03:24
# 12         0.263400   E13_stage2_bs8_len20  2025-11-30T14:02:31
# 25         0.274142   E13_stage2_bs8_len20  2025-11-30T14:02:45
# 38         0.234092   E13_stage2_bs8_len20  2025-11-30T14:02:58
# 51         0.498583   E13_stage2_bs8_len20  2025-11-30T14:03:11
# 64         0.441900   E13_stage2_bs8_len20  2025-11-30T14:03:24

# %% [markdown]
# ## 11 – Vergleich Stage-2 vs. BL4
#
# Stage-2-Ergebnisse werden mit den BL4-Ergebnissen bei gleichen Hyperparametern verglichen.
# Positive Δ-Werte bedeuten, dass Stage-2 *schlechter* als BL4 ist.

# %%
import pandas as pd

# CSV laden
dev_df = pd.read_csv("results_dev_subset_by_session.csv")

# Stage-2-Ergebnisse über alle Sessions mitteln
stage2_models = list(EXPERIMENTS.keys())
stage2_df = dev_df[dev_df["model"].isin(stage2_models)].copy()

stage2_by_model = (
    stage2_df
    .groupby("model")[["avg_conv_f1", "avg_speaker_wer", "avg_joint_error"]]
    .mean()
    .reset_index()
)

# Hyperparameter aus EXPERIMENTS-Dict in neue Spalten mappen
stage2_by_model["beam_size"] = stage2_by_model["model"].map(
    lambda m: EXPERIMENTS_STAGE2[m]["beam_size"]
)
stage2_by_model["max_length"] = stage2_by_model["model"].map(
    lambda m: EXPERIMENTS_STAGE2[m]["max_length"]
)

# Finetuned-Experimente (E01..E10) aggregieren
# Beam/Length direkt aus dem Modellnamen parsen.

ft_df = dev_df[dev_df["model"].str.startswith("E0")].copy()

def parse_beam_len(model_name: str):
    # Beispiel: "E08_bs8_len20" -> beam=8, length=20
    parts = model_name.split("_")
    beam = int(parts[1].replace("bs", ""))
    length = int(parts[2].replace("len", ""))
    return beam, length

# pd.Series erlaubt das Entpacken des Tupels in zwei Spalten per apply()
ft_df[["beam_size", "max_length"]] = ft_df["model"].apply(
    lambda m: pd.Series(parse_beam_len(m))
)

# BL4-Ergebnisse über Sessions mitteln
ft_agg = (
    ft_df
    .groupby(["model", "beam_size", "max_length"])[["avg_speaker_wer", "avg_joint_error"]]
    .mean()
    .reset_index()
)

# Stage-2 und BL4 per (beam_size, max_length) zusammenführen
comparison = pd.merge(
    stage2_by_model,
    ft_agg,
    on=["beam_size", "max_length"],
    how="left",
    suffixes=("_stage2", "_ft"),
)

# Δ-Spalten: positiv = Stage-2 schlechter als BL4
comparison["Δ_WER_stage2_minus_ft"] = (
    comparison["avg_speaker_wer_stage2"] - comparison["avg_speaker_wer_ft"]
)
comparison["Δ_JER_stage2_minus_ft"] = (
    comparison["avg_joint_error_stage2"] - comparison["avg_joint_error_ft"]
)

# Spalten hübsch sortieren
comparison_table = comparison[
    [
        "model_stage2", "beam_size", "max_length",
        "model_ft", "avg_speaker_wer_ft", "avg_joint_error_ft",
        "avg_speaker_wer_stage2", "avg_joint_error_stage2",
        "Δ_WER_stage2_minus_ft", "Δ_JER_stage2_minus_ft",
    ]
].sort_values(["max_length", "beam_size"])

print("Vergleich Stage-2 vs. finetuned (gleiche beam/max_length, aus results_dev_subset_by_session):")
display(comparison_table)
# Out:
# Vergleich Stage-2 vs. finetuned (gleiche beam/max_length, aus results_dev_subset_by_session):
#             model_stage2  beam_size  max_length        model_ft  \
# 0   E11_stage2_bs3_len15          3          15             NaN
# 2   E13_stage2_bs8_len20          8          20   E08_bs8_len20
# 1  E12_stage2_bs12_len20         12          20  E09_bs12_len20
#
#    avg_speaker_wer_ft  avg_joint_error_ft  avg_speaker_wer_stage2  \
# 0                 NaN                 NaN                0.547367
# 2            0.495798            0.324091                0.532463
# 1            0.495416            0.323900                0.531047
#
#    avg_joint_error_stage2  Δ_WER_stage2_minus_ft  Δ_JER_stage2_minus_ft
# 0                0.349876                    NaN                    NaN
# 2                0.342423               0.036665               0.018332
# 1                0.341715               0.035631               0.017815

# %% [markdown]
# ## 12 – Interpretation
#
# | Konfiguration | WER BL4 | WER Stage-2 | Δ WER | JER BL4 | JER Stage-2 | Δ JER |
# |---------------|---------|-------------|-------|---------|-------------|-------|
# | beam=8,  len=20 | 0.4958 | 0.5325 | +0.037 | 0.3241 | 0.3424 | +0.018 |
# | beam=12, len=20 | 0.4954 | 0.5310 | +0.036 | 0.3239 | 0.3417 | +0.018 |
#
# Das Stage-2-Modell ist in beiden getesteten Konfigurationen konsistent **schlechter** als BL4.
#
# **Erklärung:** BL4 wurde bereits umfangreich auf MCoRec optimiert. Das weitere Fine-Tuning
# mit 30 000 Schritten und LR 5·10⁻⁵ hat das Modell überanpasst – es hat sich von der
# besser generalisierenden Lösung wegbewegt, ohne neue Informationen zu lernen.
#
# **Schlussfolgerung:** Stage-2-Fine-Tuning wird nicht weiterverfolgt. BL4 bleibt das
# Referenzmodell für alle weiteren Experimente.
